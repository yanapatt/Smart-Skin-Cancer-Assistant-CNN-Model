# %% [markdown]
# <a href="https://colab.research.google.com/github/yanapatt/Smart-Skin-Cancer-Assistant-CNN-Model/blob/main/Benchmark_(ResNet50)_FineTuning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Benchmark CNN Model**
# ---
# **คำอธิบาย**
# ไฟล์ Jupyter notebook ใช้สำหรับการ Train CNN Model
#
# ---
# **Group Oscar Do Everything**
# **หัวข้อ Smart Skin Cancer Assistant CNN Model**
# **สมาชิก**
#
# * 66102010137	นายณัฐนนท์ หลิมเหล็ก
# * 66102010145	นายพชรดนัย กุระกนก
# * 66102010153	นายศิลายุชย์ โชติธรรมาภรณ์
# * 66102010236	นายญาณภัทร ปานเกษม
#
# **รายวิชา**
# **CP461 Introduction to Computer Vision**
#
# **Main Reference : An Interpretable Deep Learning Approach for Skin Cancer Categorization**
#
# **Paper Link:** https://arxiv.org/abs/2312.10696
# **GitHub:** https://github.com/Faysal-MD/An-Interpretable-Deep-Learning-Approach-for-Skin-Cancer-Categorization-IEEE2023?utm_source=chatgpt.com

# %% [markdown]
# ## **Section 0: Import important library**

# %%
# !pip install tf-keras-vis
# Out:
# Collecting tf-keras-vis
#   Downloading tf_keras_vis-0.8.7-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from tf-keras-vis) (1.16.2)
# Requirement already satisfied: pillow in /usr/local/lib/python3.12/dist-packages (from tf-keras-vis) (11.3.0)
# Collecting deprecated (from tf-keras-vis)
#   Downloading Deprecated-1.2.18-py2.py3-none-any.whl.metadata (5.7 kB)
# Requirement already satisfied: imageio in /usr/local/lib/python3.12/dist-packages (from tf-keras-vis) (2.37.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from tf-keras-vis) (25.0)
# Collecting wrapt<2,>=1.10 (from deprecated->tf-keras-vis)
#   Downloading wrapt-1.17.3-cp312-cp312-manylinux1_x86_64.manylinux_2_28_x86_64.manylinux_2_5_x86_64.whl.metadata (6.4 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from imageio->tf-keras-vis) (2.0.2)
# Downloading tf_keras_vis-0.8.7-py3-none-any.whl (52 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.5/52.5 kB 4.4 MB/s eta 0:00:00
# Downloading Deprecated-1.2.18-py2.py3-none-any.whl (10.0 kB)
# Downloading wrapt-1.17.3-cp312-cp312-manylinux1_x86_64.manylinux_2_28_x86_64.manylinux_2_5_x86_64.whl (88 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.0/88.0 kB 9.6 MB/s eta 0:00:00
# Installing collected packages: wrapt, deprecated, tf-keras-vis
#   Attempting uninstall: wrapt
#     Found existing installation: wrapt 2.0.0
#     Uninstalling wrapt-2.0.0:
#       Successfully uninstalled wrapt-2.0.0
# Successfully installed deprecated-1.2.18 tf-keras-vis-0.8.7 wrapt-1.17.3

# %%
import os
import itertools
import time
from psutil import virtual_memory

import pandas as pd
import numpy as np
import random as rd

import tensorflow as tf
from tf_keras_vis.utils.model_modifiers import ReplaceToLinear
from tf_keras_vis.utils.scores import CategoricalScore
from tf_keras_vis.scorecam import Scorecam
from tf_keras_vis.saliency import Saliency
import tf_keras_vis
import keras
os.environ["KERAS_BACKEND"] = "tensorflow"
import sklearn
import joblib

import matplotlib.pyplot as plt
import matplotlib.font_manager as fm
import seaborn as sns
import cv2
import albumentations as A

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ### **Setting a seed system environment**

# %%
def set_seed(seed):
    """
        ใช้สำหรับการตั้งค่า Seed Environment เพื่อให้ผลลัพธ์สามารถ Reproduce ได้
        Arg:
            seed คือ ค่า Integer สำหรับกำหนด Seed
    """
    tf.random.set_seed(seed)
    tf.config.experimental.enable_op_determinism()
    keras.utils.set_random_seed(seed)

    np.random.seed(seed)
    rd.seed(seed)

    os.environ["PYTHONHASHSEED"] = str(seed)
    os.environ["TF_DETERMINISTIC_OPS"] = "1"

    print(f"The seed number has been set at {seed}")

# %%
SEED = 42
set_seed(SEED)
# Out:
# The seed number has been set at 42

# %%
gpu_info = !nvidia-smi
gpu_info = "\n".join(gpu_info)
if gpu_info.find("failed") >= 0:
  print("Not connected to a GPU")
else:
  print(gpu_info)

ram_gb = virtual_memory().total / 1e9
print(f"Your runtime has {ram_gb:.1f} gigabytes of available RAM")
print(f"Tensorflow version: {tf.__version__}")
print(f"Keras version: {keras.__version__}")
# Out:
# Tue Oct 28 12:10:07 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.54.15              Driver Version: 550.54.15      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA L4                      Off |   00000000:00:03.0 Off |                    0 |
# | N/A   30C    P8             11W /   72W |       0MiB /  23034MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI        PID   Type   Process name                              GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |  No running processes found                                                             |
# +-----------------------------------------------------------------------------------------+
# Your runtime has 56.9 gigabytes of available RAM
# Tensorflow version: 2.19.0
# Keras version: 3.10.0

# %% [markdown]
# ## **Section 1: Preparing the directory for dataset and model**

# %% [markdown]
# ### **In G-Drive Directory**

# %%
DRIVE_DIR = "/content/drive/MyDrive/CP461/mainProject" # Drive Directory
ASSETS_PATH = f"{DRIVE_DIR}/assets" # Assets Path
DATASET_ZIP_PATH = f"{DRIVE_DIR}/datasets/ham10000DatasetOversampling.zip"
INDEX_SETTING = f"{DRIVE_DIR}/datasets/indexSetting"

# %%
# Setting font
fm.fontManager.addfont(f"{ASSETS_PATH}/fonts/OPTITimes-Roman.otf")
font_prop = fm.FontProperties(fname=f"{ASSETS_PATH}/fonts/OPTITimes-Roman.otf")
font_name = font_prop.get_name()
plt.rcParams["font.family"] = font_name

# %%
MODEL_PATH = f"{DRIVE_DIR}/models" # <= สำหรับเก็บ Log Model ต่าง ๆ
MODEL_NAME = "ResNet50" # <= Model อะไร
OPTIMIZER_NAME = "Adam" # <= Optimizer อะไร
TYPE = "Fine Tuned" # <= Fine-Tuned หรือ Feature Extraction
ROUND_NUM = 1 # <= รันครั้งที่เท่าไหร่
MODEL_FULL_PATH = f"{MODEL_PATH}/{MODEL_NAME}_{TYPE}_{OPTIMIZER_NAME}_{ROUND_NUM}"
ASSETS_FOR_MODEL_PATH = f"{MODEL_FULL_PATH}/assets" # <= สำหรับเก็บรูปภาพต่าง ๆ จากโมเดล

os.makedirs(MODEL_FULL_PATH, exist_ok=True)
os.makedirs(ASSETS_FOR_MODEL_PATH, exist_ok=True)

# %%
MODEL_KERAS_PATH = f"{MODEL_FULL_PATH}/{MODEL_NAME}.keras"
MODEL_H5_PATH = f"{MODEL_FULL_PATH}/{MODEL_NAME}.h5"
MODEL_TFLITE_PATH = f"{MODEL_FULL_PATH}/{MODEL_NAME}.tflite"
MODEL_CHECKPOINT_PATH = f"{MODEL_FULL_PATH}/{MODEL_NAME}_best.keras"
MODEL_TENSORBOARD_PATH = f"{MODEL_FULL_PATH}/{MODEL_NAME}_tensorboard.logs"
MODEL_HISTORY_PATH = f"{MODEL_FULL_PATH}/{MODEL_NAME}_history.csv"
MODEL_JSON_PATH = f"{MODEL_FULL_PATH}/{MODEL_NAME}_json.json"
MODEL_REPORT_PATH = f"{MODEL_FULL_PATH}/{MODEL_NAME}_report.csv"

# %% [markdown]
# ### **In Runtime Directory**

# %%
# !unzip /content/drive/MyDrive/CP461/mainProject/datasets/ham10000DatasetOversampling.zip -d /content/ham10000DatasetOversampling
# Out:
# เอาต์พุตของการสตรีมมีการตัดเหลือเพียง 5000 บรรทัดสุดท้าย
#   inflating: /content/ham10000DatasetOversampling/train/mel/ISIC_0027797_aug_1990.jpg
#   inflating: /content/ham10000DatasetOversampling/train/mel/ISIC_0028965_aug_3148.jpg
#   inflating: /content/ham10000DatasetOversampling/train/mel/ISIC_0034134.jpg
#   inflating: /content/ham10000DatasetOversampling/train/mel/ISIC_0034243_aug_1087.jpg
#   inflating: /content/ham10000DatasetOversampling/train/mel/ISIC_0033496_aug_2153.jpg
#   inflating: /content/ham10000DatasetOversampling/train/mel/ISIC_0033216_aug_215.jpg
#   inflating: /content/ham10000DatasetOversampling/train/mel/ISIC_0032522.jpg
#   inflating: /content/ham10000DatasetOversampling/train/mel/ISIC_0032408_aug_2136.jpg
#   inflating: /content/ham10000DatasetOversampling/train/mel/ISIC_0034275_aug_1075.jpg
#   inflating: /content/ham10000DatasetOversampling/train/mel/ISIC_0030417.jpg
#   inflating: /content/ham10000DatasetOversampling/train/mel/ISIC_0032214_aug_685.jpg
#   inflating: /content/ham10000DatasetOversampling/train/mel/ISIC_0033424_aug_3075.jpg
#   inflating: /content/ham10000DatasetOversampling/train/mel/ISIC_0033754_aug_2984.jpg
#   inflating: /content/ham10000DatasetOversampling/train/mel/ISIC_0028022.jpg
#   inflating: /content/ham10000DatasetOversampling/train/mel/ISIC_0029651_aug_2717.jpg
#   inflating: /content/ham10000DatasetOversampling/train/mel/ISIC_0025512_aug_2456.jpg
#   inflating: /content/ham10000DatasetOversampling/train/mel/ISIC_0024911_aug_2112.jpg
#   inflating: /content/ham10000DatasetOversampling/train/mel/ISIC_0032214_aug_2013.jpg
#   inflating: /content/ham10000DatasetOversampling/train/mel/ISIC_0032081.jpg
#   inflating: /content/ham10000DatasetOversampling/train/mel/ISIC_0024586.jpg
#   inflating: /content/ham10000DatasetOversampling/train/mel/ISIC_0034170_aug_1731.jpg
#   inflating: /content/ham10000DatasetOversampling/train/mel/ISIC_0033193_aug_319.jpg
#   inflating: /content/ham10000DatasetOversampling/train/mel/ISIC_0033999_aug_2437.jpg
#   inflating: /content/ham10000DatasetOversampling/train/mel/ISIC_0029353.jpg
#   inflating: /content/ham10000DatasetOversampling/train/mel/ISIC_0026045_aug_1283.jpg
#   inflating: /content/ham10000DatasetOversampling/train/mel/ISIC_0030255_aug_587.jpg
#   inflating: /content/ham10000DatasetOversampling/train/mel/ISIC_0028087_aug_2785.jpg
#   inflating: /content/ham10000DatasetOversampling/train/mel/ISIC_0027300_aug_2150.jpg
#   inflating: /content/ham10000DatasetOversampling/train/mel/ISIC_0032847_aug_1497.jpg
#   inflating: /content/ham10000DatasetOversampling/train/mel/ISIC_0032716.jpg
#   inflating: /content/ham10000DatasetOversampling/train/mel/ISIC_0033245_aug_1046.jpg
#   inflating: /content/ham10000DatasetOversampling/train/mel/ISIC_0032372_aug_1880.jpg
#   inflating: /content/ham10000DatasetOversampling/train/mel/ISIC_0032596_aug_2309.jpg
#   inflating: /content/ham10000DatasetOversampling/train/mel/ISIC_0033630_aug_939.jpg
#   inflating: /content/ham10000DatasetOversampling/train/mel/ISIC_0027261_aug_2746.jpg
#   inflating: /content/ham10000DatasetOversampling/train/mel/ISIC_0033302_aug_433.jpg
#   inflating: /content/ham10000DatasetOversampling/train/mel/ISIC_0025904_aug_2721.jpg
#   inflating: /content/ham10000DatasetOversampling/train/mel/ISIC_0027797.jpg
#   inflating: /content/ham10000DatasetOversampling/train/mel/ISIC_0028288_aug_1857.jpg
#   inflating: /content/ham10000DatasetOversampling/train/mel/ISIC_0034313_aug_2878.jpg
#   inflating: /content/ham10000DatasetOversampling/train/mel/ISIC_0033394_aug_2420.jpg
#   inflating: /content/ham10000DatasetOversampling/train/mel/ISIC_0030784_aug_545.jpg
#   inflating: /content/ham10000DatasetOversampling/train/mel/ISIC_0030031_aug_1005.jpg
#   inflating: /content/ham10000DatasetOversampling/train/mel/ISIC_0034087_aug_2194.jpg
#   inflating: /content/ham10000DatasetOversampling/train/mel/ISIC_0030246_aug_1256.jpg
#   inflating: /content/ham10000DatasetOversampling/train/mel/ISIC_0031778_aug_3288.jpg
#   inflating: /content/ham10000DatasetOversampling/train/mel/ISIC_0033848_aug_2273.jpg
#   inflating: /content/ham10000DatasetOversampling/train/mel/ISIC_0029281_aug_688.jpg
#   inflating: /content/ham10000DatasetOversampling/train/mel/ISIC_0034118_aug_2182.jpg
#   inflating: /content/ham10000DatasetOversampling/train/mel/ISIC_0032522_aug_253.jpg
#   inflating: /content/ham10000DatasetOversampling/train/mel/ISIC_0033362_aug_1532.jpg
#   inflating: /content/ham10000DatasetOversampling/train/mel/ISIC_0027742_aug_1875.jpg
#   inflating: /content/ham10000DatasetOversampling/train/mel/ISIC_0
jpg
#   inflating: /content/ham10000DatasetOversampling/train/nv/ISIC_0026312.jpg
#   inflating: /content/ham10000DatasetOversampling/train/nv/ISIC_0027661.jpg
#   inflating: /content/ham10000DatasetOversampling/train/nv/ISIC_0032954.jpg
#   inflating: /content/ham10000DatasetOversampling/train/nv/ISIC_0027687.jpg
#   inflating: /content/ham10000DatasetOversampling/train/nv/ISIC_0026414.jpg
#   inflating: /content/ham10000DatasetOversampling/train/nv/ISIC_0030505.jpg
#   inflating: /content/ham10000DatasetOversampling/train/nv/ISIC_0027003.jpg
#   inflating: /content/ham10000DatasetOversampling/train/nv/ISIC_0026285.jpg
#   inflating: /content/ham10000DatasetOversampling/train/nv/ISIC_0031605.jpg
#   inflating: /content/ham10000DatasetOversampling/train/nv/ISIC_0028944.jpg
#   inflating: /content/ham10000DatasetOversampling/train/nv/ISIC_0028999.jpg
#   inflating: /content/ham10000DatasetOversampling/train/nv/ISIC_0027411.jpg
#   inflating: /content/ham10000DatasetOversampling/train/nv/ISIC_0028829.jpg
#   inflating: /content/ham10000DatasetOversampling/train/nv/ISIC_0031213.jpg
#   inflating: /content/ham10000DatasetOversampling/train/nv/ISIC_0033800.jpg
#   inflating: /content/ham10000DatasetOversampling/train/nv/ISIC_0025974.jpg
#   inflating: /content/ham10000DatasetOversampling/train/nv/ISIC_0031440.jpg
#   inflating: /content/ham10000DatasetOversampling/train/nv/ISIC_0030068.jpg
#   inflating: /content/ham10000DatasetOversampling/train/nv/ISIC_0026933.jpg
#   inflating: /content/ham10000DatasetOversampling/train/nv/ISIC_0030193.jpg
#   inflating: /content/ham10000DatasetOversampling/train/nv/ISIC_0027961.jpg
#   inflating: /content/ham10000DatasetOversampling/train/nv/ISIC_0031582.jpg
#   inflating: /content/ham10000DatasetOversampling/train/nv/ISIC_0027516.jpg
#   inflating: /content/ham10000DatasetOversampling/train/nv/ISIC_0029038.jpg
#   inflating: /content/ham10000DatasetOversampling/train/nv/ISIC_0031320.jpg
#   inflating: /content/ham10000DatasetOversampling/train/nv/ISIC_0026979.jpg
#   inflating: /content/ham10000DatasetOversampling/train/nv/ISIC_0027944.jpg
#   inflating: /content/ham10000DatasetOversampling/train/nv/ISIC_0028706.jpg
#   inflating: /content/ham10000DatasetOversampling/train/nv/ISIC_0027066.jpg
#   inflating: /content/ham10000DatasetOversampling/train/nv/ISIC_0025673.jpg
#   inflating: /content/ham10000DatasetOversampling/train/nv/ISIC_0029164.jpg
#   inflating: /content/ham10000DatasetOversampling/train/nv/ISIC_0032942.jpg
#   inflating: /content/ham10000DatasetOversampling/train/nv/ISIC_0031176.jpg
#   inflating: /content/ham10000DatasetOversampling/train/nv/ISIC_0034192.jpg
#   inflating: /content/ham10000DatasetOversampling/train/nv/ISIC_0024975.jpg
#   inflating: /content/ham10000DatasetOversampling/train/nv/ISIC_0026093.jpg
#   inflating: /content/ham10000DatasetOversampling/train/nv/ISIC_0025498.jpg
#   inflating: /content/ham10000DatasetOversampling/train/nv/ISIC_0027510.jpg
#   inflating: /content/ham10000DatasetOversampling/train/nv/ISIC_0027714.jpg
#   inflating: /content/ham10000DatasetOversampling/train/nv/ISIC_0027644.jpg
#   inflating: /content/ham10000DatasetOversampling/train/nv/ISIC_0030097.jpg
#   inflating: /content/ham10000DatasetOversampling/train/nv/ISIC_0030958.jpg
#   inflating: /content/ham10000DatasetOversampling/train/nv/ISIC_0028101.jpg
#   inflating: /content/ham10000DatasetOversampling/train/nv/ISIC_0029497.jpg
#   inflating: /content/ham10000DatasetOversampling/train/nv/ISIC_0028102.jpg
#   inflating: /content/ham10000DatasetOversampling/train/nv/ISIC_0025447.jpg
#   inflating: /content/ham10000DatasetOversampling/train/nv/ISIC_0030449.jpg
#   inflating: /content/ham10000DatasetOversampling/train/nv/ISIC_0028130.jpg
#   inflating: /content/ham10000DatasetOversampling/train/nv/ISIC_0032337.jpg
#   inflating: /content/ham10000DatasetOversampling/train/nv/ISIC_0025522.jpg
#   inflating: /content/ham10000DatasetOversampling/train/nv/ISIC_0029098.jpg
#   inflating: /content/ham10000DatasetOversampling/train/nv/ISIC_0031067.jpg
#   inflating: /content/ham10000DatasetOversampling/train/nv/ISIC_0033384.jpg
#   inflating: /content/ham10000DatasetOversampling/train/nv/ISIC_0026758.jpg
#   inflating: /content/ham10000DatasetOversampling/train/nv/ISIC_0032621.jpg
#   inflating: /content/ham10000DatasetOversampling/train/nv/ISIC_0026550.jpg
#   inflating: /content/ham10000DatasetOversampling/train/nv/ISIC_0030527.jpg
#   inflating: /content/ham10000DatasetOversampling/train/nv/ISIC_0026863.jpg
#   inflating: /content/ham10000DatasetOversampling/train/nv/ISIC_0028440.jpg
#   inflating: /content/ham10000DatasetOversampling/train/nv/ISIC_0027153.jpg
#   inflating: /content/ham10000DatasetOversampling/train/nv/ISIC_0029109.jpg
#   inflating: /content/ham10000DatasetOversampling/train/nv/ISIC_0025555.jpg
#   inflating: /content/ham10000DatasetOversampling/train/nv/ISIC_0033904.jpg
#   inflating: /content/ham10000DatasetOversampling/train/nv/ISIC_0029411.jpg
#   inflating: /content/ham10000DatasetOversampling/train/nv/ISIC_0033326.jpg
#   inflating: /content/ham10000DatasetOversampling/train/nv/ISIC_0029142.jpg
#   inflating: /content/ham10000DatasetOversampling/train/nv/ISIC_0028535.jpg
#   inflating: /content/ham10000DatasetOversampling/train/nv/ISIC_0031297.jpg
#   inflating: /content/ham10000DatasetOversampling/train/nv/ISIC_0030156.jpg
#   inflating: /content/ham10000DatasetOversampling/train/nv/ISIC_0026184.jpg
#   inflating: /content/ham10000DatasetOversampling/train/nv/ISIC_0026911.jpg
#   inflating: /content/ham10000DatasetOversampling/train/nv/ISIC_0024441.jpg
#   inflating: /content/ham10000DatasetOversampling/train/nv/ISIC_0033557.jpg
#   inflating: /content/ham10000DatasetOversampling/train/nv/ISIC_0030127.jpg
#   inflating: /content/ham10000DatasetOversampling/train/nv/ISIC_0026801.jpg
#   inflating: /content/ham10000DatasetOversampling/train/nv/ISIC_0029287.jpg
#   inflating: /content/ham10000DatasetOversampling/train/nv/ISIC_0028732.jpg
#   inflating: /content/ham10000DatasetOversampling/train/nv/ISIC_0024600.jpg
#   inflating: /content/ham10000DatasetOversampling/train/nv/ISIC_0028630.jpg
#   inflating: /content/ham10000DatasetOversampling/train/nv/ISIC_0024818.jpg
#   inflating: /content/ham10000DatasetOversampling/train/nv/ISIC_0029334.jpg
#   inflating: /content/ham10000DatasetOversampling/train/nv/ISIC_0031425.jpg
#   inflating: /content/ham10000DatasetOversampling/train/nv/ISIC_0026772.jpg
#   inflating: /content/ham10000DatasetOversampling/train/nv/ISIC_0033989.jpg
#   inflating: /content/ham10000DatasetOversampling/train/nv/ISIC_0028635.jpg
#   inflating: /content/ham10000DatasetOversampling/train/nv/ISIC_0024821.jpg
#   inflating: /content/ham10000DatasetOversampling/train/nv/ISIC_0026431.jpg
#   inflating: /content/ham10000DatasetOversampling/train/nv/ISIC_0032228.jpg
#   inflating: /content/ham10000DatasetOversampling/train/nv/ISIC_0027942.jpg
#   inflating: /content/ham10000DatasetOversampling/train/nv/ISIC_0033194.jpg
#   inflating: /content/ham10000DatasetOversampling/train/nv/ISIC_0032224.jpg
#   inflating: /content/ham10000DatasetOversampling/train/nv/ISIC_0024854.jpg
#   inflating: /content/ham10000DatasetOversampling/train/nv/ISIC_0025759.jpg
#   inflating: /content/ham10000DatasetOversampling/train/nv/ISIC_0029090.jpg
#   inflating: /content/ham10000DatasetOversampling/train/nv/ISIC_0027782.jpg
#   inflating: /content/ham10000DatasetOversampling/train/nv/ISIC_0033694.jpg
#   inflating: /content/ham10000DatasetOversampling/train/nv/ISIC_0033948.jpg
#   inflating: /content/ham10000DatasetOversampling/train/nv/ISIC_0025956.jpg
#   inflating: /content/ham10000DatasetOversampling/train/nv/ISIC_0029560.jpg
#   inflating: /content/ham10000DatasetOversampling/train/nv/ISIC_0032052.jpg
#   inflating: /content/ham10000DatasetOversampling/train/nv/ISIC_0032137.jpg
#   inflating: /content/ham10000DatasetOversampling/train/nv/ISIC_0027443.jpg
#   inflating: /content/ham10000DatasetOversampling/train/nv/ISIC_0027621.jpg
#   inflating: /content/ham10000DatasetOversampling/train/nv/ISIC_0028461.jpg
#   inflating: /content/ham10000DatasetOversampling/train/nv/ISIC_0025412.jpg
#   inflating: /content/ham10000DatasetOversampling/train/nv/ISIC_0031612.jpg
#   inflating: /content/ham10000DatasetOversampling/train/nv/ISIC_0031572.jpg
#   inflating: /content/ham10000DatasetOversampling/train/nv/ISIC_0026385.jpg
#   inflating: /content/ham10000DatasetOversampling/train/nv/ISIC_0027211.jpg
#   inflating: /content/ham10000DatasetOversampling/train/nv/ISIC_0032020.jpg
#   inflating: /content/ham10000DatasetOversampling/train/nv/ISIC_0031397.jpg
#   inflating: /content/ham10000DatasetOversampling/train/nv/ISIC_0028740.jpg
#   inflating: /content/ham10000DatasetOversampling/train/nv/ISIC_0032412.jpg
#   inflating: /content/ham10000DatasetOversampling/train/nv/ISIC_0024920.jpg
#   inflating: /content/ham10000DatasetOversampling/train/nv/ISIC_0029821.jpg
#   inflating: /content/ham10000DatasetOversampling/train/nv/ISIC_0028761.jpg
#   inflating: /content/ham10000DatasetOversampling/train/nv/ISIC_0024750.jpg
#   inflating: /content/ham10000DatasetOversampling/train/nv/ISIC_0025284.jpg
#   inflating: /content/ham10000DatasetOversampling/train/nv/ISIC_0027968.jpg
#   inflating: /content/ham10000DatasetOversampling/train/nv/ISIC_0026633.jpg
#   inflating: /content/ham10000DatasetOversampling/train/nv/ISIC_0025730.jpg
#   inflating: /content/ham10000DatasetOversampling/train/nv/ISIC_0031509.jpg
#   inflating: /content/ham10000DatasetOversampling/train/nv/ISIC_0030049.jpg
#   inflating: /content/ham10000DatasetOversampling/train/nv/ISIC_0031899.jpg
#   inflating: /content/ham10000DatasetOversampling/train/nv/ISIC_0024631.jpg
#   inflating: /content/ham10000DatasetOversampling/train/nv/ISIC_0024421.jpg
#   inflating: /content/ham10000DatasetOversampling/train/nv/ISIC_0033598.jpg
#   inflating: /content/ham10000DatasetOversampling/train/nv/ISIC_0030484.jpg
#   inflating: /content/ham10000DatasetOversampling/train/nv/ISIC_0030692.jpg
#   inflating: /content/ham10000DatasetOversampling/train/nv/ISIC_0031227.jpg
#   inflating: /content/ham10000DatasetOversampling/train/nv/ISIC_0029797.jpg
#   inflating: /content/ham10000DatasetOversampling/train/nv/ISIC_0027200.jpg
#   inflating: /content/ham10000DatasetOversampling/train/nv/ISIC_0033355.jpg
#   inflating: /content/ham10000DatasetOversampling/train/nv/ISIC_0026401.jpg
#   inflating: /content/ham10000DatasetOversampling/train/nv/ISIC_0027635.jpg
#   inflating: /content/ham10000DatasetOversampling/train/nv/ISIC_0034226.jpg
#   inflating: /content/ham10000DatasetOversampling/train/nv/ISIC_0033296.jpg
#   inflating: /content/ham10000DatasetOversampling/train/nv/ISIC_0030132.jpg
#   inflating: /content/ham10000DatasetOversampling/train/nv/ISIC_0026031.jpg
#   inflating: /content/ham10000DatasetOversampling/train/nv/ISIC_0025460.jpg
#   inflating: /content/ham10000DatasetOversampling/train/nv/ISIC_0027720.jpg
#   inflating: /content/ham10000DatasetOversampling/train/nv/ISIC_0030968.jpg
#   inflating: /content/ham10000DatasetOversampling/train/nv/ISIC_0032309.jpg
#   inflating: /content/ham10000DatasetOversampling/train/nv/ISIC_0033425.jpg
#   inflating: /content/ham10000DatasetOversampling/train/nv/ISIC_0030593.jpg
#   inflating: /content/ham10000DatasetOversampling/train/nv/ISIC_0032212.jpg
#   inflating: /content/ham10000DatasetOversampling/train/nv/ISIC_0032717.jpg
#   inflating: /content/ham10000DatasetOversampling/train/nv/ISIC_0031315.jpg
#   inflating: /content/ham10000DatasetOversampling/train/nv/ISIC_0030022.jpg
#   inflating: /content/ham10000DatasetOversampling/train/nv/ISIC_0030762.jpg
#   inflating: /content/ham10000DatasetOversampling/train/nv/ISIC_0032066.jpg
#   inflating: /content/ham10000DatasetOversampling/train/nv/ISIC_0030239.jpg
#   inflating: /content/ham10000DatasetOversampling/train/nv/ISIC_0028601.jpg
#   inflating: /content/ham10000DatasetOversampling/train/nv/ISIC_0028896.jpg
#   inflating: /content/ham10000DatasetOversampling/train/nv/ISIC_0030048.jpg
#   inflating: /content/ham10000DatasetOversampling/train/nv/ISIC_0033917.jpg
#   inflating: /content/ham10000DatasetOversampling/train/nv/ISIC_0027524.jpg
#   inflating: /content/ham10000DatasetOversampling/train/nv/ISIC_0029529.jpg
#   inflating: /content/ham10000DatasetOversampling/train/nv/ISIC_0027924.jpg
#   inflating: /content/ham10000DatasetOversampling/train/nv/ISIC_0030724.jpg
#   inflating: /content/ham10000DatasetOversampling/train/nv/ISIC_0026551.jpg
#   inflating: /content/ham10000DatasetOversampling/train/nv/ISIC_0032125.jpg
#   inflating: /content/ham10000DatasetOversampling/train/nv/ISIC_0028541.jpg
#   inflating: /content/ham10000DatasetOversampling/train/nv/ISIC_0032328.jpg
#   inflating: /content/ham10000DatasetOversampling/train/nv/ISIC_0024905.jpg
#   inflating: /content/ham10000DatasetOversampling/train/nv/ISIC_0026338.jpg
#   inflating: /content/ham10000DatasetOversampling/train/nv/ISIC_0026585.jpg
#   inflating: /content/ham10000DatasetOversampling/train/nv/ISIC_0032784.jpg
#   inflating: /content/ham10000DatasetOversampling/train/nv/ISIC_0030061.jpg
#   inflating: /content/ham10000DatasetOversampling/train/nv/ISIC_0026910.jpg
#   inflating: /content/ham10000DatasetOversampling/train/nv/ISIC_0024406.jpg
#   inflating: /content/ham10000DatasetOversampling/train/nv/ISIC_0030336.jpg

# %%
DATASET_DIR = "/content/ham10000DatasetOversampling"

# %% [markdown]
# ## **Section 2: Preprocessing and augmentaion images**

# %% [markdown]
# ### **Load dataset**

# %%
class MultiModelDatasetPipeline:
    def __init__(self,
                 transform=None,
                 rescale=None,
                 preprocess_input=None
                 ):
        self.transform = transform
        self.rescale = rescale
        self.preprocess_input = preprocess_input
        self.AUTOTUNE = tf.data.AUTOTUNE
        self.class_names = None

    def _transform_function(self, img_numpy):
        raw_img = {"image": img_numpy}
        transform_img = self.transform(**raw_img)
        return transform_img["image"].astype(np.float32)

    @tf.function
    def _apply_transform(self, img_tensor, img_size):
        transformed = tf.numpy_function(
            func=self._transform_function,
            inp=[img_tensor],
            Tout=tf.float32
        )
        transformed.set_shape([img_size[0], img_size[1], 3])
        return transformed

    def _load_and_resize(self, filepath, metadata, label, img_size):
        img = tf.io.read_file(filepath)
        img = tf.image.decode_jpeg(img, channels=3)
        img = tf.image.resize(img, img_size)
        return img, metadata, label

    def _finalize_data(self, img, metadata, label,
                    num_classes, img_size, meta_shape=17,
                    is_training=False, class_mode="categorical"):

        if is_training and self.transform:
            img = self._apply_transform(img, img_size)

        if self.preprocess_input:
            img = self.preprocess_input(img)
        elif self.rescale:
            img = img * self.rescale

        label = tf.cast(label, tf.int32)
        if class_mode == "categorical":
            label = tf.one_hot(label, num_classes)
        elif class_mode != "sparse":
            raise ValueError(f"Unknown class_mode: {class_mode}")

        if metadata is None:
            return img, label

        metadata = tf.cast(metadata, tf.float32)
        return ((img, metadata), label)

    def flow_from_dataframe(
            self,
            df,
            X_cols,
            X_meta=None,
            y_cols=None,
            num_classes=None,
            class_name_col=None,
            target_size=(224, 224),
            batch_size=32,
            is_training=False,
            seed=42,
            class_mode="categorical"
            ):

        num_files = len(df)

        if is_training and class_name_col and self.class_names is None:
            try:
                mapping_df = df[[y_cols, class_name_col]].drop_duplicates().sort_values(by=y_cols)
                self.class_names = mapping_df[class_name_col].tolist()
                if len(self.class_names) != num_classes:
                     print(f"Warning: Found {len(self.class_names)} unique names, but num_classes={num_classes}.")
            except Exception as e:
                print(f"Could not build class name list from '{class_name_col}': {e}. Defaulting to numeric names.")
                self.class_names = [str(i) for i in range(num_classes)]
        elif self.class_names is None:
             self.class_names = [str(i) for i in range(num_classes)]

        class_indices = dict(enumerate(self.class_names))
        print(f"Found {num_files} files belonging to {num_classes} classes.")
        print(f"Class indices: {class_indices}")

        if X_meta is None:
            X_meta_data = [None] * len(df)
        else:
            X_meta_data = X_meta

        dataset = tf.data.Dataset.from_tensor_slices(
            (df[X_cols].values, X_meta_data, df[y_cols].values)
        )

        dataset = dataset.map(
            lambda f, m, l: self._load_and_resize(f, m, l, target_size),
            num_parallel_calls=self.AUTOTUNE
        )
        dataset = dataset.cache()

        map_func = lambda img, m, l: self._finalize_data(
            img, m, l, num_classes, target_size,
            meta_shape=17,
            is_training=is_training,
            class_mode=class_mode
        )

        if is_training:
            dataset = dataset.shuffle(buffer_size=len(df), seed=seed, reshuffle_each_iteration=True)

        dataset = (
            dataset
            .map(map_func, num_parallel_calls=self.AUTOTUNE)
            .batch(batch_size)
            .prefetch(buffer_size=self.AUTOTUNE)
        )
        return dataset

# %%
df_train = pd.read_csv(f"{INDEX_SETTING}/metadata_train_new.csv")
df_val = pd.read_csv(f"{INDEX_SETTING}/metadata_val_new.csv")
df_test = pd.read_csv(f"{INDEX_SETTING}/metadata_test_new.csv")
metadata_preprocessing = joblib.load(f"{INDEX_SETTING}/metadata_preprocessing_new.joblib")

print("Check shape of dataframe")
print(f"Train shape: {df_train.shape}")
print(f"Validation shape: {df_val.shape}")
print(f"Test shape: {df_test.shape}")
# Out:
# Check shape of dataframe
# Train shape: (15626, 10)
# Validation shape: (1979, 10)
# Test shape: (1956, 10)

# %%
X_meta_train = metadata_preprocessing.transform(df_train)
X_meta_val = metadata_preprocessing.transform(df_val)
X_meta_test = metadata_preprocessing.transform(df_test)
print("Transform complete.")

print("Check shape of metadata")
print(f"X Train metadata shape: {X_meta_train.shape}")
print(f"X Validation metadata shape: {X_meta_val.shape}")
print(f"X Test metadata shape: {X_meta_test.shape}")
# Out:
# Transform complete.
# Check shape of metadata
# X Train metadata shape: (15626, 17)
# X Validation metadata shape: (1979, 17)
# X Test metadata shape: (1956, 17)

# %%
META_SHAPE = (X_meta_train.shape[1], )
print(f"Metadata shape: {META_SHAPE}")
# Out:
# Metadata shape: (17,)

# %%
def select_preprocess_input(model_name):
    if model_name == "ResNet50":
        preprocess_input = keras.applications.resnet50.preprocess_input
    elif model_name == "MobileNetV3Large" or model_name == "MobileNetV3Small":
        preprocess_input = keras.applications.mobilenet_v3.preprocess_input
    elif model_name == "Xception":
        preprocess_input = keras.applications.xception.preprocess_input
    else:
        preprocess_input = None
    return preprocess_input

# %%
preprocess_input = select_preprocess_input(MODEL_NAME)
IMAGE_HEIGHT = 224
IMAGE_WIDTH = 224
IMAGE_SIZE = (IMAGE_HEIGHT, IMAGE_WIDTH)
INPUT_SHAPE = IMAGE_SIZE + (3, )
BATCH_SIZE = 64
EPOCHS = 30

# %%
class_names = ["akiec", "bcc", "bkl", "df", "mel", "nv", "vasc"]
idx_to_class = {idx: name for idx, name in enumerate(class_names)}
NUM_CLASSES = len(class_names)
print(f"Index to class: {idx_to_class}")
print(f"Number of classes: {NUM_CLASSES}")
# Out:
# Index to class: {0: 'akiec', 1: 'bcc', 2: 'bkl', 3: 'df', 4: 'mel', 5: 'nv', 6: 'vasc'}
# Number of classes: 7

# %%
transform = A.Compose([
    A.ColorJitter(
        brightness=0.2,
        contrast=0.2,
        saturation=0.05,
        hue=0.02,
        p=0.3
    )
], seed=SEED)

pipeline = MultiModelDatasetPipeline(
    transform=transform,
    rescale=None,
    preprocess_input=preprocess_input
)

# %%
ds_train = pipeline.flow_from_dataframe(
    df=df_train,
    X_cols="filepaths",
    X_meta=X_meta_train,
    y_cols="cell_type_idx",
    num_classes=NUM_CLASSES,
    class_name_col="dx",
    is_training=True,
    batch_size=BATCH_SIZE,
    seed=SEED
)

ds_val = pipeline.flow_from_dataframe(
    df=df_val,
    X_cols="filepaths",
    X_meta=X_meta_val,
    y_cols="cell_type_idx",
    num_classes=NUM_CLASSES,
    class_name_col="dx",
    is_training=False,
    batch_size=BATCH_SIZE
)

ds_test = pipeline.flow_from_dataframe(
    df=df_test,
    X_cols="filepaths",
    X_meta=X_meta_test,
    y_cols="cell_type_idx",
    num_classes=NUM_CLASSES,
    class_name_col="dx",
    is_training=False,
    batch_size=BATCH_SIZE
)
# Out:
# Found 15626 files belonging to 7 classes.
# Class indices: {0: 'akiec', 1: 'bcc', 2: 'bkl', 3: 'df', 4: 'mel', 5: 'nv', 6: 'vasc'}
# Found 1979 files belonging to 7 classes.
# Class indices: {0: 'akiec', 1: 'bcc', 2: 'bkl', 3: 'df', 4: 'mel', 5: 'nv', 6: 'vasc'}
# Found 1956 files belonging to 7 classes.
# Class indices: {0: 'akiec', 1: 'bcc', 2: 'bkl', 3: 'df', 4: 'mel', 5: 'nv', 6: 'vasc'}

# %% [markdown]
# ## **Section 3: Preparing the model**

# %% [markdown]
# ### **Define callback function**

# %%
reduce_lr = keras.callbacks.ReduceLROnPlateau(
    monitor="val_accuracy",
    factor=0.1,
    patience=5,
    mode="max",
    min_lr=1e-08,
    verbose=1
) # Reduce learning rate callback

model_checkpoint = keras.callbacks.ModelCheckpoint(
    filepath=MODEL_CHECKPOINT_PATH,
    monitor="val_accuracy",
    mode="max",
    save_best_only=True,
    save_weights_only=False,
    verbose=1
) # Model checkpoint for save best model file

tensorboard = keras.callbacks.TensorBoard(
    log_dir=MODEL_TENSORBOARD_PATH,
    histogram_freq=1,
    write_graph=True,
    write_images=True
) # Tensorboard file

callback_list = [reduce_lr, model_checkpoint, tensorboard]

# %% [markdown]
# ### **Model parameters**

# %%
import tensorflow as tf
from tensorflow import keras

def build_model(input_shape, meta_shape, num_classes, trainable=False):
    image_input = keras.layers.Input(shape=input_shape, name="image_input")
    meta_input = keras.layers.Input(shape=meta_shape, name="metadata_input")

    base_model = keras.applications.ResNet50(
        input_tensor=image_input,
        include_top=False,
        weights="imagenet"
    )
    for layer in base_model.layers:
        layer.trainable = trainable

    # ===== Image branch =====
    image_features = keras.layers.GlobalAveragePooling2D(name="avg_pool")(base_model.output)
    image_features = keras.layers.BatchNormalization(name="norm_1")(image_features)
    image_features = keras.layers.Dense(256, activation="relu", name="img_fc1")(image_features)
    image_features = keras.layers.Dropout(0.3, name="img_dropout")(image_features)
    image_features = keras.layers.Dense(128, activation="relu", name="img_fc2")(image_features)

    # ===== Metadata branch =====
    meta_features = keras.layers.Dense(64, activation="relu", name="meta_fc1")(meta_input)
    meta_features = keras.layers.BatchNormalization(name="norm_2")(meta_features)
    meta_features = keras.layers.Dense(32, activation="relu", name="meta_fc2")(meta_features)
    meta_features = keras.layers.Dropout(0.2, name="meta_dropout")(meta_features)

    # ===== Metadata Attention =====
    attn_meta = keras.layers.Dense(32, activation="sigmoid", name="meta_attention")(meta_features)
    meta_features = keras.layers.Multiply(name="meta_attention_multi")([meta_features, attn_meta])

    # ===== Combine branches =====
    combined = keras.layers.Concatenate(name="concat_features")([image_features, meta_features])
    combined = keras.layers.BatchNormalization(name="norm_3")(combined)

    # ===== Combined Attention =====
    attn_combined = keras.layers.Dense(
        tf.keras.backend.int_shape(combined)[-1],
        activation="sigmoid",
        name="combined_attention"
    )(combined)
    combined = keras.layers.Multiply(name="combined_attention_multi")([combined, attn_combined])

    # ===== Head =====
    x = keras.layers.Dropout(0.5, name="head_dropout")(combined)
    x = keras.layers.Dense(128, activation="relu", name="head_fc1")(x)
    x = keras.layers.BatchNormalization(name="norm_4")(x)
    x = keras.layers.Dense(64, activation="relu", name="head_fc2")(x)
    predictions = keras.layers.Dense(num_classes, activation="softmax", name="predictions")(x)

    model = keras.models.Model(inputs=[image_input, meta_input], outputs=predictions)
    return model

# %%
model = build_model(
    input_shape=INPUT_SHAPE,
    meta_shape=META_SHAPE,
    num_classes=NUM_CLASSES,
    trainable=True
)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94765736/94765736 ━━━━━━━━━━━━━━━━━━━━ 5s 0us/step

# %%
model.compile(
    optimizer = keras.optimizers.AdamW(
        learning_rate=1e-04,
        weight_decay=1e-05,
        beta_1=0.9,
        beta_2=0.999,
        epsilon=1e-07,
        name="Adam"
    ),
    loss = keras.losses.CategoricalCrossentropy(name="loss"),
    metrics = [
        keras.metrics.CategoricalAccuracy(name="accuracy"),
        keras.metrics.Recall(name="recall"),
        keras.metrics.Precision(name="precision")
        ]
)

model.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ image_input         │ (None, 224, 224,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1_pad           │ (None, 230, 230,  │          0 │ image_input[0][0] │
# │ (ZeroPadding2D)     │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1_conv (Conv2D) │ (None, 112, 112,  │      9,472 │ conv1_pad[0][0]   │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1_bn            │ (None, 112, 112,  │        256 │ conv1_conv[0][0]  │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1_relu          │ (None, 112, 112,  │          0 │ conv1_bn[0][0]    │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ pool1_pad           │ (None, 114, 114,  │          0 │ conv1_relu[0][0]  │
# │ (ZeroPadding2D)     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ pool1_pool          │ (None, 56, 56,    │          0 │ pool1_pad[0][0]   │
# │ (MaxPooling2D)      │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block1_1_conv │ (None, 56, 56,    │      4,160 │ pool1_pool[0][0]  │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block1_1_bn   │ (None, 56, 56,    │        256 │ conv2_block1_1_c… │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block1_1_relu │ (None, 56, 56,    │          0 │ conv2_block1_1_b… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block1_2_conv │ (None, 56, 56,    │     36,928 │ conv2_block1_1_r… │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block1_2_bn   │ (None, 56, 56,    │        256 │ conv2_block1_2_c… │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block1_2_relu │ (None, 56, 56,    │          0 │ conv2_block1_2_b… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block1_0_conv │ (None, 56, 56,    │     16,640 │ pool1_pool[0][0]  │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block1_3_conv │ (None, 56, 56,    │     16,640 │ conv2_block1_2_r… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block1_0_bn   │ (None, 56, 56,    │      1,024 │ conv2_block1_0_c… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block1_3_bn   │ (None, 56, 56,    │      1,024 │ conv2_block1_3_c… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block1_add    │ (None, 56, 56,    │          0 │ conv2_block1_0_b… │
# │ (Add)               │ 256)              │            │ conv2_block1_3_b… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block1_out    │ (None, 56, 56,    │          0 │ conv2_block1_add… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block2_1_conv │ (None, 56, 56,    │     16,448 │ conv2_block1_out… │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block2_1_bn   │ (None, 56, 56,    │        256 │ conv2_block2_1_c… │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block2_1_relu │ (None, 56, 56,    │          0 │ conv2_block2_1_b… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block2_2_conv │ (None, 56, 56,    │     36,928 │ conv2_block2_1_r… │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block2_2_bn   │ (None, 56, 56,    │        256 │ conv2_block2_2_c… │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block2_2_relu │ (None, 56, 56,    │          0 │ conv2_block2_2_b… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block2_3_conv │ (None, 56, 56,    │     16,640 │ conv2_block2_2_r… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block2_3_bn   │ (None, 56, 56,    │      1,024 │ conv2_block2_3_c… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block2_add    │ (None, 56, 56,    │          0 │ conv2_block1_out… │
# │ (Add)               │ 256)              │            │ conv2_block2_3_b… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block2_out    │ (None, 56, 56,    │          0 │ conv2_block2_add… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block3_1_conv │ (None, 56, 56,    │     16,448 │ conv2_block2_out… │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block3_1_bn   │ (None, 56, 56,    │        256 │ conv2_block3_1_c… │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block3_1_relu │ (None, 56, 56,    │          0 │ conv2_block3_1_b… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block3_2_conv │ (None, 56, 56,    │     36,928 │ conv2_block3_1_r… │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block3_2_bn   │ (None, 56, 56,    │        256 │ conv2_block3_2_c… │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block3_2_relu │ (None, 56, 56,    │          0 │ conv2_block3_2_b… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block3_3_conv │ (None, 56, 56,    │     16,640 │ conv2_block3_2_r… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block3_3_bn   │ (None, 56, 56,    │      1,024 │ conv2_block3_3_c… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block3_add    │ (None, 56, 56,    │          0 │ conv2_block2_out… │
# │ (Add)               │ 256)              │            │ conv2_block3_3_b… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block3_out    │ (None, 56, 56,    │          0 │ conv2_block3_add… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block1_1_conv │ (None, 28, 28,    │     32,896 │ conv2_block3_out… │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block1_1_bn   │ (None, 28, 28,    │        512 │ conv3_block1_1_c… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block1_1_relu │ (None, 28, 28,    │          0 │ conv3_block1_1_b… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block1_2_conv │ (None, 28, 28,    │    147,584 │ conv3_block1_1_r… │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block1_2_bn   │ (None, 28, 28,    │        512 │ conv3_block1_2_c… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block1_2_relu │ (None, 28, 28,    │          0 │ conv3_block1_2_b… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block1_0_conv │ (None, 28, 28,    │    131,584 │ conv2_block3_out… │
# │ (Conv2D)            │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block1_3_conv │ (None, 28, 28,    │     66,048 │ conv3_block1_2_r… │
# │ (Conv2D)            │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block1_0_bn   │ (None, 28, 28,    │      2,048 │ conv3_block1_0_c… │
# │ (BatchNormalizatio… │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block1_3_bn   │ (None, 28, 28,    │      2,048 │ conv3_block1_3_c… │
# │ (BatchNormalizatio… │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block1_add    │ (None, 28, 28,    │          0 │ conv3_block1_0_b… │
# │ (Add)               │ 512)              │            │ conv3_block1_3_b… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block1_out    │ (None, 28, 28,    │          0 │ conv3_block1_add… │
# │ (Activation)        │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block2_1_conv │ (None, 28, 28,    │     65,664 │ conv3_block1_out… │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block2_1_bn   │ (None, 28, 28,    │        512 │ conv3_block2_1_c… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block2_1_relu │ (None, 28, 28,    │          0 │ conv3_block2_1_b… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block2_2_conv │ (None, 28, 28,    │    147,584 │ conv3_block2_1_r… │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block2_2_bn   │ (None, 28, 28,    │        512 │ conv3_block2_2_c… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block2_2_relu │ (None, 28, 28,    │          0 │ conv3_block2_2_b… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block2_3_conv │ (None, 28, 28,    │     66,048 │ conv3_block2_2_r… │
# │ (Conv2D)            │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block2_3_bn   │ (None, 28, 28,    │      2,048 │ conv3_block2_3_c… │
# │ (BatchNormalizatio… │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block2_add    │ (None, 28, 28,    │          0 │ conv3_block1_out… │
# │ (Add)               │ 512)              │            │ conv3_block2_3_b… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block2_out    │ (None, 28, 28,    │          0 │ conv3_block2_add… │
# │ (Activation)        │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block3_1_conv │ (None, 28, 28,    │     65,664 │ conv3_block2_out… │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block3_1_bn   │ (None, 28, 28,    │        512 │ conv3_block3_1_c… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block3_1_relu │ (None, 28, 28,    │          0 │ conv3_block3_1_b… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block3_2_conv │ (None, 28, 28,    │    147,584 │ conv3_block3_1_r… │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block3_2_bn   │ (None, 28, 28,    │        512 │ conv3_block3_2_c… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block3_2_relu │ (None, 28, 28,    │          0 │ conv3_block3_2_b… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block3_3_conv │ (None, 28, 28,    │     66,048 │ conv3_block3_2_r… │
# │ (Conv2D)            │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block3_3_bn   │ (None, 28, 28,    │      2,048 │ conv3_block3_3_c… │
# │ (BatchNormalizatio… │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block3_add    │ (None, 28, 28,    │          0 │ conv3_block2_out… │
# │ (Add)               │ 512)              │            │ conv3_block3_3_b… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block3_out    │ (None, 28, 28,    │          0 │ conv3_block3_add… │
# │ (Activation)        │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block4_1_conv │ (None, 28, 28,    │     65,664 │ conv3_block3_out… │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block4_1_bn   │ (None, 28, 28,    │        512 │ conv3_block4_1_c… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block4_1_relu │ (None, 28, 28,    │          0 │ conv3_block4_1_b… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block4_2_conv │ (None, 28, 28,    │    147,584 │ conv3_block4_1_r… │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block4_2_bn   │ (None, 28, 28,    │        512 │ conv3_block4_2_c… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block4_2_relu │ (None, 28, 28,    │          0 │ conv3_block4_2_b… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block4_3_conv │ (None, 28, 28,    │     66,048 │ conv3_block4_2_r… │
# │ (Conv2D)            │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block4_3_bn   │ (None, 28, 28,    │      2,048 │ conv3_block4_3_c… │
# │ (BatchNormalizatio… │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block4_add    │ (None, 28, 28,    │          0 │ conv3_block3_out… │
# │ (Add)               │ 512)              │            │ conv3_block4_3_b… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block4_out    │ (None, 28, 28,    │          0 │ conv3_block4_add… │
# │ (Activation)        │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block1_1_conv │ (None, 14, 14,    │    131,328 │ conv3_block4_out… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block1_1_bn   │ (None, 14, 14,    │      1,024 │ conv4_block1_1_c… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block1_1_relu │ (None, 14, 14,    │          0 │ conv4_block1_1_b… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block1_2_conv │ (None, 14, 14,    │    590,080 │ conv4_block1_1_r… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block1_2_bn   │ (None, 14, 14,    │      1,024 │ conv4_block1_2_c… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block1_2_relu │ (None, 14, 14,    │          0 │ conv4_block1_2_b… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block1_0_conv │ (None, 14, 14,    │    525,312 │ conv3_block4_out… │
# │ (Conv2D)            │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block1_3_conv │ (None, 14, 14,    │    263,168 │ conv4_block1_2_r… │
# │ (Conv2D)            │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block1_0_bn   │ (None, 14, 14,    │      4,096 │ conv4_block1_0_c… │
# │ (BatchNormalizatio… │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block1_3_bn   │ (None, 14, 14,    │      4,096 │ conv4_block1_3_c… │
# │ (BatchNormalizatio… │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block1_add    │ (None, 14, 14,    │          0 │ conv4_block1_0_b… │
# │ (Add)               │ 1024)             │            │ conv4_block1_3_b… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block1_out    │ (None, 14, 14,    │          0 │ conv4_block1_add… │
# │ (Activation)        │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block2_1_conv │ (None, 14, 14,    │    262,400 │ conv4_block1_out… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block2_1_bn   │ (None, 14, 14,    │      1,024 │ conv4_block2_1_c… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block2_1_relu │ (None, 14, 14,    │          0 │ conv4_block2_1_b… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block2_2_conv │ (None, 14, 14,    │    590,080 │ conv4_block2_1_r… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block2_2_bn   │ (None, 14, 14,    │      1,024 │ conv4_block2_2_c… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block2_2_relu │ (None, 14, 14,    │          0 │ conv4_block2_2_b… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block2_3_conv │ (None, 14, 14,    │    263,168 │ conv4_block2_2_r… │
# │ (Conv2D)            │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block2_3_bn   │ (None, 14, 14,    │      4,096 │ conv4_block2_3_c… │
# │ (BatchNormalizatio… │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block2_add    │ (None, 14, 14,    │          0 │ conv4_block1_out… │
# │ (Add)               │ 1024)             │            │ conv4_block2_3_b… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block2_out    │ (None, 14, 14,    │          0 │ conv4_block2_add… │
# │ (Activation)        │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block3_1_conv │ (None, 14, 14,    │    262,400 │ conv4_block2_out… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block3_1_bn   │ (None, 14, 14,    │      1,024 │ conv4_block3_1_c… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block3_1_relu │ (None, 14, 14,    │          0 │ conv4_block3_1_b… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block3_2_conv │ (None, 14, 14,    │    590,080 │ conv4_block3_1_r… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block3_2_bn   │ (None, 14, 14,    │      1,024 │ conv4_block3_2_c… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block3_2_relu │ (None, 14, 14,    │          0 │ conv4_block3_2_b… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block3_3_conv │ (None, 14, 14,    │    263,168 │ conv4_block3_2_r… │
# │ (Conv2D)            │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block3_3_bn   │ (None, 14, 14,    │      4,096 │ conv4_block3_3_c… │
# │ (BatchNormalizatio… │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block3_add    │ (None, 14, 14,    │          0 │ conv4_block2_out… │
# │ (Add)               │ 1024)             │            │ conv4_block3_3_b… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block3_out    │ (None, 14, 14,    │          0 │ conv4_block3_add… │
# │ (Activation)        │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block4_1_conv │ (None, 14, 14,    │    262,400 │ conv4_block3_out… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block4_1_bn   │ (None, 14, 14,    │      1,024 │ conv4_block4_1_c… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block4_1_relu │ (None, 14, 14,    │          0 │ conv4_block4_1_b… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block4_2_conv │ (None, 14, 14,    │    590,080 │ conv4_block4_1_r… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block4_2_bn   │ (None, 14, 14,    │      1,024 │ conv4_block4_2_c… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block4_2_relu │ (None, 14, 14,    │          0 │ conv4_block4_2_b… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block4_3_conv │ (None, 14, 14,    │    263,168 │ conv4_block4_2_r… │
# │ (Conv2D)            │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block4_3_bn   │ (None, 14, 14,    │      4,096 │ conv4_block4_3_c… │
# │ (BatchNormalizatio… │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block4_add    │ (None, 14, 14,    │          0 │ conv4_block3_out… │
# │ (Add)               │ 1024)             │            │ conv4_block4_3_b… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block4_out    │ (None, 14, 14,    │          0 │ conv4_block4_add… │
# │ (Activation)        │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block5_1_conv │ (None, 14, 14,    │    262,400 │ conv4_block4_out… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block5_1_bn   │ (None, 14, 14,    │      1,024 │ conv4_block5_1_c… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block5_1_relu │ (None, 14, 14,    │          0 │ conv4_block5_1_b… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block5_2_conv │ (None, 14, 14,    │    590,080 │ conv4_block5_1_r… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block5_2_bn   │ (None, 14, 14,    │      1,024 │ conv4_block5_2_c… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block5_2_relu │ (None, 14, 14,    │          0 │ conv4_block5_2_b… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block5_3_conv │ (None, 14, 14,    │    263,168 │ conv4_block5_2_r… │
# │ (Conv2D)            │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block5_3_bn   │ (None, 14, 14,    │      4,096 │ conv4_block5_3_c… │
# │ (BatchNormalizatio… │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block5_add    │ (None, 14, 14,    │          0 │ conv4_block4_out… │
# │ (Add)               │ 1024)             │            │ conv4_block5_3_b… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block5_out    │ (None, 14, 14,    │          0 │ conv4_block5_add… │
# │ (Activation)        │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block6_1_conv │ (None, 14, 14,    │    262,400 │ conv4_block5_out… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block6_1_bn   │ (None, 14, 14,    │      1,024 │ conv4_block6_1_c… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block6_1_relu │ (None, 14, 14,    │          0 │ conv4_block6_1_b… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block6_2_conv │ (None, 14, 14,    │    590,080 │ conv4_block6_1_r… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block6_2_bn   │ (None, 14, 14,    │      1,024 │ conv4_block6_2_c… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block6_2_relu │ (None, 14, 14,    │          0 │ conv4_block6_2_b… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block6_3_conv │ (None, 14, 14,    │    263,168 │ conv4_block6_2_r… │
# │ (Conv2D)            │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block6_3_bn   │ (None, 14, 14,    │      4,096 │ conv4_block6_3_c… │
# │ (BatchNormalizatio… │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block6_add    │ (None, 14, 14,    │          0 │ conv4_block5_out… │
# │ (Add)               │ 1024)             │            │ conv4_block6_3_b… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block6_out    │ (None, 14, 14,    │          0 │ conv4_block6_add… │
# │ (Activation)        │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block1_1_conv │ (None, 7, 7, 512) │    524,800 │ conv4_block6_out… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block1_1_bn   │ (None, 7, 7, 512) │      2,048 │ conv5_block1_1_c… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block1_1_relu │ (None, 7, 7, 512) │          0 │ conv5_block1_1_b… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block1_2_conv │ (None, 7, 7, 512) │  2,359,808 │ conv5_block1_1_r… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block1_2_bn   │ (None, 7, 7, 512) │      2,048 │ conv5_block1_2_c… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block1_2_relu │ (None, 7, 7, 512) │          0 │ conv5_block1_2_b… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block1_0_conv │ (None, 7, 7,      │  2,099,200 │ conv4_block6_out… │
# │ (Conv2D)            │ 2048)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block1_3_conv │ (None, 7, 7,      │  1,050,624 │ conv5_block1_2_r… │
# │ (Conv2D)            │ 2048)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block1_0_bn   │ (None, 7, 7,      │      8,192 │ conv5_block1_0_c… │
# │ (BatchNormalizatio… │ 2048)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block1_3_bn   │ (None, 7, 7,      │      8,192 │ conv5_block1_3_c… │
# │ (BatchNormalizatio… │ 2048)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block1_add    │ (None, 7, 7,      │          0 │ conv5_block1_0_b… │
# │ (Add)               │ 2048)             │            │ conv5_block1_3_b… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block1_out    │ (None, 7, 7,      │          0 │ conv5_block1_add… │
# │ (Activation)        │ 2048)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block2_1_conv │ (None, 7, 7, 512) │  1,049,088 │ conv5_block1_out… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block2_1_bn   │ (None, 7, 7, 512) │      2,048 │ conv5_block2_1_c… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block2_1_relu │ (None, 7, 7, 512) │          0 │ conv5_block2_1_b… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block2_2_conv │ (None, 7, 7, 512) │  2,359,808 │ conv5_block2_1_r… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block2_2_bn   │ (None, 7, 7, 512) │      2,048 │ conv5_block2_2_c… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block2_2_relu │ (None, 7, 7, 512) │          0 │ conv5_block2_2_b… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block2_3_conv │ (None, 7, 7,      │  1,050,624 │ conv5_block2_2_r… │
# │ (Conv2D)            │ 2048)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block2_3_bn   │ (None, 7, 7,      │      8,192 │ conv5_block2_3_c… │
# │ (BatchNormalizatio… │ 2048)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block2_add    │ (None, 7, 7,      │          0 │ conv5_block1_out… │
# │ (Add)               │ 2048)             │            │ conv5_block2_3_b… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block2_out    │ (None, 7, 7,      │          0 │ conv5_block2_add… │
# │ (Activation)        │ 2048)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block3_1_conv │ (None, 7, 7, 512) │  1,049,088 │ conv5_block2_out… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block3_1_bn   │ (None, 7, 7, 512) │      2,048 │ conv5_block3_1_c… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block3_1_relu │ (None, 7, 7, 512) │          0 │ conv5_block3_1_b… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block3_2_conv │ (None, 7, 7, 512) │  2,359,808 │ conv5_block3_1_r… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block3_2_bn   │ (None, 7, 7, 512) │      2,048 │ conv5_block3_2_c… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block3_2_relu │ (None, 7, 7, 512) │          0 │ conv5_block3_2_b… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block3_3_conv │ (None, 7, 7,      │  1,050,624 │ conv5_block3_2_r… │
# │ (Conv2D)            │ 2048)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block3_3_bn   │ (None, 7, 7,      │      8,192 │ conv5_block3_3_c… │
# │ (BatchNormalizatio… │ 2048)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block3_add    │ (None, 7, 7,      │          0 │ conv5_block2_out… │
# │ (Add)               │ 2048)             │            │ conv5_block3_3_b… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ metadata_input      │ (None, 17)        │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block3_out    │ (None, 7, 7,      │          0 │ conv5_block3_add… │
# │ (Activation)        │ 2048)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ meta_fc1 (Dense)    │ (None, 64)        │      1,152 │ metadata_input[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ avg_pool            │ (None, 2048)      │          0 │ conv5_block3_out… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ norm_2              │ (None, 64)        │        256 │ meta_fc1[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ norm_1              │ (None, 2048)      │      8,192 │ avg_pool[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ meta_fc2 (Dense)    │ (None, 32)        │      2,080 │ norm_2[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ img_fc1 (Dense)     │ (None, 256)       │    524,544 │ norm_1[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ meta_dropout        │ (None, 32)        │          0 │ meta_fc2[0][0]    │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ img_dropout         │ (None, 256)       │          0 │ img_fc1[0][0]     │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ meta_attention      │ (None, 32)        │      1,056 │ meta_dropout[0][… │
# │ (Dense)             │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ img_fc2 (Dense)     │ (None, 128)       │     32,896 │ img_dropout[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ meta_attention_mul… │ (None, 32)        │          0 │ meta_dropout[0][… │
# │ (Multiply)          │                   │            │ meta_attention[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concat_features     │ (None, 160)       │          0 │ img_fc2[0][0],    │
# │ (Concatenate)       │                   │            │ meta_attention_m… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ norm_3              │ (None, 160)       │        640 │ concat_features[… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ combined_attention  │ (None, 160)       │     25,760 │ norm_3[0][0]      │
# │ (Dense)             │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ combined_attention… │ (None, 160)       │          0 │ norm_3[0][0],     │
# │ (Multiply)          │                   │            │ combined_attenti… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ head_dropout        │ (None, 160)       │          0 │ combined_attenti… │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ head_fc1 (Dense)    │ (None, 128)       │     20,608 │ head_dropout[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ norm_4              │ (None, 128)       │        512 │ head_fc1[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ head_fc2 (Dense)    │ (None, 64)        │      8,256 │ norm_4[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ predictions (Dense) │ (None, 7)         │        455 │ head_fc2[0][0]    │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 24,214,119 (92.37 MB)
#  Trainable params: 24,156,199 (92.15 MB)
#  Non-trainable params: 57,920 (226.25 KB)

# %% [markdown]
# ## **Section 4: Training the model**

# %%
training_start = time.time()

history = model.fit(
    ds_train,
    validation_data=ds_val,
    epochs=EPOCHS,
    callbacks=callback_list,
    verbose=1
)

training_end = time.time()
training_time = training_end - training_start
print(f"\n Training completed in {training_time:.4f} seconds")
# Out:
# Epoch 1/30
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 0s 804ms/step - accuracy: 0.2598 - loss: 1.9938 - precision: 0.3588 - recall: 0.0911
# Epoch 1: val_accuracy improved from -inf to 0.71753, saving model to /content/drive/MyDrive/CP461/mainProject/models/ResNet50_Fine Tuned_Adam_1/ResNet50_best.keras
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 309s 869ms/step - accuracy: 0.2602 - loss: 1.9925 - precision: 0.3598 - recall: 0.0914 - val_accuracy: 0.7175 - val_loss: 0.8210 - val_precision: 0.8184 - val_recall: 0.5968 - learning_rate: 1.0000e-04
# Epoch 2/30
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 0s 811ms/step - accuracy: 0.5739 - loss: 1.1462 - precision: 0.7983 - recall: 0.3941
# Epoch 2: val_accuracy improved from 0.71753 to 0.78575, saving model to /content/drive/MyDrive/CP461/mainProject/models/ResNet50_Fine Tuned_Adam_1/ResNet50_best.keras
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 212s 864ms/step - accuracy: 0.5740 - loss: 1.1460 - precision: 0.7983 - recall: 0.3943 - val_accuracy: 0.7858 - val_loss: 0.7121 - val_precision: 0.8471 - val_recall: 0.7332 - learning_rate: 1.0000e-04
# Epoch 3/30
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 0s 812ms/step - accuracy: 0.6484 - loss: 0.9467 - precision: 0.8471 - recall: 0.5125
# Epoch 3: val_accuracy improved from 0.78575 to 0.81405, saving model to /content/drive/MyDrive/CP461/mainProject/models/ResNet50_Fine Tuned_Adam_1/ResNet50_best.keras
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 212s 866ms/step - accuracy: 0.6485 - loss: 0.9466 - precision: 0.8472 - recall: 0.5125 - val_accuracy: 0.8140 - val_loss: 0.5980 - val_precision: 0.8483 - val_recall: 0.7772 - learning_rate: 1.0000e-04
# Epoch 4/30
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 0s 812ms/step - accuracy: 0.7022 - loss: 0.8166 - precision: 0.8827 - recall: 0.5811
# Epoch 4: val_accuracy did not improve from 0.81405
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 210s 858ms/step - accuracy: 0.7022 - loss: 0.8165 - precision: 0.8827 - recall: 0.5812 - val_accuracy: 0.7948 - val_loss: 0.7782 - val_precision: 0.8140 - val_recall: 0.7761 - learning_rate: 1.0000e-04
# Epoch 5/30
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 0s 814ms/step - accuracy: 0.7248 - loss: 0.7455 - precision: 0.8932 - recall: 0.6229
# Epoch 5: val_accuracy did not improve from 0.81405
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 211s 860ms/step - accuracy: 0.7248 - loss: 0.7455 - precision: 0.8932 - recall: 0.6229 - val_accuracy: 0.7211 - val_loss: 0.9744 - val_precision: 0.7452 - val_recall: 0.6872 - learning_rate: 1.0000e-04
# Epoch 6/30
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 0s 812ms/step - accuracy: 0.7429 - loss: 0.6884 - precision: 0.8952 - recall: 0.6461
# Epoch 6: val_accuracy did not improve from 0.81405
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 210s 858ms/step - accuracy: 0.7429 - loss: 0.6883 - precision: 0.8953 - recall: 0.6461 - val_accuracy: 0.7878 - val_loss: 0.8330 - val_precision: 0.8055 - val_recall: 0.7721 - learning_rate: 1.0000e-04
# Epoch 7/30
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 0s 814ms/step - accuracy: 0.7571 - loss: 0.6535 - precision: 0.9147 - recall: 0.6571
# Epoch 7: val_accuracy improved from 0.81405 to 0.82769, saving model to /content/drive/MyDrive/CP461/mainProject/models/ResNet50_Fine Tuned_Adam_1/ResNet50_best.keras
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 213s 867ms/step - accuracy: 0.7571 - loss: 0.6535 - precision: 0.9147 - recall: 0.6571 - val_accuracy: 0.8277 - val_loss: 0.6362 - val_precision: 0.8431 - val_recall: 0.8146 - learning_rate: 1.0000e-04
# Epoch 8/30
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 0s 814ms/step - accuracy: 0.7719 - loss: 0.6078 - precision: 0.9202 - recall: 0.6786
# Epoch 8: val_accuracy improved from 0.82769 to 0.82921, saving model to /content/drive/MyDrive/CP461/mainProject/models/ResNet50_Fine Tuned_Adam_1/ResNet50_best.keras
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 213s 868ms/step - accuracy: 0.7720 - loss: 0.6077 - precision: 0.9202 - recall: 0.6786 - val_accuracy: 0.8292 - val_loss: 0.6209 - val_precision: 0.8454 - val_recall: 0.8236 - learning_rate: 1.0000e-04
# Epoch 9/30
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 0s 814ms/step - accuracy: 0.7907 - loss: 0.5528 - precision: 0.9420 - recall: 0.7079
# Epoch 9: val_accuracy did not improve from 0.82921
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 211s 860ms/step - accuracy: 0.7906 - loss: 0.5528 - precision: 0.9420 - recall: 0.7078 - val_accuracy: 0.8029 - val_loss: 0.8521 - val_precision: 0.8130 - val_recall: 0.7928 - learning_rate: 1.0000e-04
# Epoch 10/30
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 0s 814ms/step - accuracy: 0.7864 - loss: 0.5604 - precision: 0.9395 - recall: 0.6969
# Epoch 10: val_accuracy improved from 0.82921 to 0.83274, saving model to /content/drive/MyDrive/CP461/mainProject/models/ResNet50_Fine Tuned_Adam_1/ResNet50_best.keras
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 212s 867ms/step - accuracy: 0.7865 - loss: 0.5604 - precision: 0.9395 - recall: 0.6969 - val_accuracy: 0.8327 - val_loss: 0.6962 - val_precision: 0.8397 - val_recall: 0.8231 - learning_rate: 1.0000e-04
# Epoch 11/30
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 0s 813ms/step - accuracy: 0.7901 - loss: 0.5527 - precision: 0.9331 - recall: 0.7025
# Epoch 11: val_accuracy did not improve from 0.83274
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 210s 859ms/step - accuracy: 0.7901 - loss: 0.5527 - precision: 0.9331 - recall: 0.7025 - val_accuracy: 0.8085 - val_loss: 0.8052 - val_precision: 0.8195 - val_recall: 0.8009 - learning_rate: 1.0000e-04
# Epoch 12/30
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 0s 812ms/step - accuracy: 0.7939 - loss: 0.5412 - precision: 0.9316 - recall: 0.7067
# Epoch 12: val_accuracy did not improve from 0.83274
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 210s 858ms/step - accuracy: 0.7939 - loss: 0.5412 - precision: 0.9316 - recall: 0.7067 - val_accuracy: 0.7903 - val_loss: 0.8903 - val_precision: 0.8019 - val_recall: 0.7852 - learning_rate: 1.0000e-04
# Epoch 13/30
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 0s 812ms/step - accuracy: 0.7892 - loss: 0.5445 - precision: 0.9320 - recall: 0.7052
# Epoch 13: val_accuracy improved from 0.83274 to 0.83578, saving model to /content/drive/MyDrive/CP461/mainProject/models/ResNet50_Fine Tuned_Adam_1/ResNet50_best.keras
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 212s 865ms/step - accuracy: 0.7892 - loss: 0.5445 - precision: 0.9320 - recall: 0.7052 - val_accuracy: 0.8358 - val_loss: 0.6776 - val_precision: 0.8426 - val_recall: 0.8307 - learning_rate: 1.0000e-04
# Epoch 14/30
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 0s 814ms/step - accuracy: 0.7957 - loss: 0.5378 - precision: 0.9346 - recall: 0.7152
# Epoch 14: val_accuracy did not improve from 0.83578
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 211s 860ms/step - accuracy: 0.7957 - loss: 0.5378 - precision: 0.9346 - recall: 0.7152 - val_accuracy: 0.7878 - val_loss: 0.9584 - val_precision: 0.7996 - val_recall: 0.7822 - learning_rate: 1.0000e-04
# Epoch 15/30
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 0s 813ms/step - accuracy: 0.7750 - loss: 0.6174 - precision: 0.9076 - recall: 0.6841
# Epoch 15: val_accuracy did not improve from 0.83578
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 211s 860ms/step - accuracy: 0.7750 - loss: 0.6172 - precision: 0.9076 - recall: 0.6841 - val_accuracy: 0.8211 - val_loss: 0.7793 - val_precision: 0.8294 - val_recall: 0.8156 - learning_rate: 1.0000e-04
# Epoch 16/30
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 0s 814ms/step - accuracy: 0.8015 - loss: 0.5148 - precision: 0.9416 - recall: 0.7157
# Epoch 16: val_accuracy did not improve from 0.83578
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 211s 860ms/step - accuracy: 0.8015 - loss: 0.5148 - precision: 0.9416 - recall: 0.7156 - val_accuracy: 0.8267 - val_loss: 0.6884 - val_precision: 0.8348 - val_recall: 0.8196 - learning_rate: 1.0000e-04
# Epoch 17/30
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 0s 813ms/step - accuracy: 0.8158 - loss: 0.4806 - precision: 0.9484 - recall: 0.7299
# Epoch 17: val_accuracy did not improve from 0.83578
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 210s 858ms/step - accuracy: 0.8158 - loss: 0.4806 - precision: 0.9484 - recall: 0.7299 - val_accuracy: 0.7852 - val_loss: 0.9942 - val_precision: 0.7920 - val_recall: 0.7812 - learning_rate: 1.0000e-04
# Epoch 18/30
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 0s 812ms/step - accuracy: 0.8016 - loss: 0.5018 - precision: 0.9489 - recall: 0.7140
# Epoch 18: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-06.
#
# Epoch 18: val_accuracy did not improve from 0.83578
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 210s 858ms/step - accuracy: 0.8016 - loss: 0.5018 - precision: 0.9489 - recall: 0.7140 - val_accuracy: 0.7984 - val_loss: 0.9239 - val_precision: 0.8050 - val_recall: 0.7948 - learning_rate: 1.0000e-04
# Epoch 19/30
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 0s 812ms/step - accuracy: 0.8140 - loss: 0.4863 - precision: 0.9471 - recall: 0.7257
# Epoch 19: val_accuracy improved from 0.83578 to 0.83881, saving model to /content/drive/MyDrive/CP461/mainProject/models/ResNet50_Fine Tuned_Adam_1/ResNet50_best.keras
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 212s 865ms/step - accuracy: 0.8140 - loss: 0.4863 - precision: 0.9471 - recall: 0.7258 - val_accuracy: 0.8388 - val_loss: 0.6604 - val_precision: 0.8468 - val_recall: 0.8353 - learning_rate: 1.0000e-05
# Epoch 20/30
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 0s 816ms/step - accuracy: 0.8118 - loss: 0.4793 - precision: 0.9569 - recall: 0.7252
# Epoch 20: val_accuracy improved from 0.83881 to 0.84083, saving model to /content/drive/MyDrive/CP461/mainProject/models/ResNet50_Fine Tuned_Adam_1/ResNet50_best.keras
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 213s 869ms/step - accuracy: 0.8118 - loss: 0.4793 - precision: 0.9569 - recall: 0.7252 - val_accuracy: 0.8408 - val_loss: 0.6683 - val_precision: 0.8484 - val_recall: 0.8373 - learning_rate: 1.0000e-05
# Epoch 21/30
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 0s 814ms/step - accuracy: 0.8179 - loss: 0.4647 - precision: 0.9580 - recall: 0.7308
# Epoch 21: val_accuracy improved from 0.84083 to 0.84336, saving model to /content/drive/MyDrive/CP461/mainProject/models/ResNet50_Fine Tuned_Adam_1/ResNet50_best.keras
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 213s 868ms/step - accuracy: 0.8179 - loss: 0.4647 - precision: 0.9580 - recall: 0.7308 - val_accuracy: 0.8434 - val_loss: 0.6722 - val_precision: 0.8493 - val_recall: 0.8373 - learning_rate: 1.0000e-05
# Epoch 22/30
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 0s 813ms/step - accuracy: 0.8187 - loss: 0.4598 - precision: 0.9608 - recall: 0.7326
# Epoch 22: val_accuracy improved from 0.84336 to 0.84487, saving model to /content/drive/MyDrive/CP461/mainProject/models/ResNet50_Fine Tuned_Adam_1/ResNet50_best.keras
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 212s 867ms/step - accuracy: 0.8187 - loss: 0.4599 - precision: 0.9608 - recall: 0.7326 - val_accuracy: 0.8449 - val_loss: 0.6698 - val_precision: 0.8503 - val_recall: 0.8408 - learning_rate: 1.0000e-05
# Epoch 23/30
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 0s 814ms/step - accuracy: 0.8241 - loss: 0.4551 - precision: 0.9623 - recall: 0.7383
# Epoch 23: val_accuracy improved from 0.84487 to 0.84639, saving model to /content/drive/MyDrive/CP461/mainProject/models/ResNet50_Fine Tuned_Adam_1/ResNet50_best.keras
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 212s 867ms/step - accuracy: 0.8241 - loss: 0.4551 - precision: 0.9623 - recall: 0.7383 - val_accuracy: 0.8464 - val_loss: 0.6917 - val_precision: 0.8523 - val_recall: 0.8428 - learning_rate: 1.0000e-05
# Epoch 24/30
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 0s 812ms/step - accuracy: 0.8181 - loss: 0.4652 - precision: 0.9614 - recall: 0.7309
# Epoch 24: val_accuracy did not improve from 0.84639
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 210s 858ms/step - accuracy: 0.8181 - loss: 0.4652 - precision: 0.9614 - recall: 0.7309 - val_accuracy: 0.8423 - val_loss: 0.7189 - val_precision: 0.8475 - val_recall: 0.8368 - learning_rate: 1.0000e-05
# Epoch 25/30
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 0s 812ms/step - accuracy: 0.8206 - loss: 0.4506 - precision: 0.9645 - recall: 0.7398
# Epoch 25: val_accuracy improved from 0.84639 to 0.84992, saving model to /content/drive/MyDrive/CP461/mainProject/models/ResNet50_Fine Tuned_Adam_1/ResNet50_best.keras
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 212s 867ms/step - accuracy: 0.8206 - loss: 0.4506 - precision: 0.9644 - recall: 0.7398 - val_accuracy: 0.8499 - val_loss: 0.6987 - val_precision: 0.8558 - val_recall: 0.8459 - learning_rate: 1.0000e-05
# Epoch 26/30
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 0s 813ms/step - accuracy: 0.8103 - loss: 0.4703 - precision: 0.9595 - recall: 0.7216
# Epoch 26: val_accuracy did not improve from 0.84992
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 210s 859ms/step - accuracy: 0.8104 - loss: 0.4703 - precision: 0.9595 - recall: 0.7216 - val_accuracy: 0.8428 - val_loss: 0.7245 - val_precision: 0.8469 - val_recall: 0.8388 - learning_rate: 1.0000e-05
# Epoch 27/30
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 0s 813ms/step - accuracy: 0.8208 - loss: 0.4566 - precision: 0.9632 - recall: 0.7338
# Epoch 27: val_accuracy did not improve from 0.84992
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 211s 859ms/step - accuracy: 0.8208 - loss: 0.4566 - precision: 0.9632 - recall: 0.7338 - val_accuracy: 0.8474 - val_loss: 0.7127 - val_precision: 0.8509 - val_recall: 0.8423 - learning_rate: 1.0000e-05
# Epoch 28/30
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 0s 813ms/step - accuracy: 0.8321 - loss: 0.4333 - precision: 0.9659 - recall: 0.7477
# Epoch 28: val_accuracy did not improve from 0.84992
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 211s 859ms/step - accuracy: 0.8320 - loss: 0.4333 - precision: 0.9659 - recall: 0.7476 - val_accuracy: 0.8494 - val_loss: 0.7461 - val_precision: 0.8534 - val_recall: 0.8444 - learning_rate: 1.0000e-05
# Epoch 29/30
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 0s 812ms/step - accuracy: 0.8264 - loss: 0.4388 - precision: 0.9668 - recall: 0.7405
# Epoch 29: val_accuracy did not improve from 0.84992
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 210s 858ms/step - accuracy: 0.8264 - loss: 0.4388 - precision: 0.9668 - recall: 0.7405 - val_accuracy: 0.8408 - val_loss: 0.7520 - val_precision: 0.8445 - val_recall: 0.8373 - learning_rate: 1.0000e-05
# Epoch 30/30
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 0s 814ms/step - accuracy: 0.8212 - loss: 0.4483 - precision: 0.9644 - recall: 0.7379
# Epoch 30: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-07.
#
# Epoch 30: val_accuracy did not improve from 0.84992
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 211s 860ms/step - accuracy: 0.8212 - loss: 0.4483 - precision: 0.9644 - recall: 0.7379 - val_accuracy: 0.8454 - val_loss: 0.7547 - val_precision: 0.8483 - val_recall: 0.8423 - learning_rate: 1.0000e-05
#
#  Training completed in 6435.8875 seconds

# %% [markdown]
# ### **Save the model config**

# %%
# Save model history
history_df = pd.DataFrame(history.history)
history_df.to_csv(MODEL_HISTORY_PATH, index=False)
print(f"History has been saved at {MODEL_HISTORY_PATH}")
# Out:
# History has been saved at /content/drive/MyDrive/CP461/mainProject/models/ResNet50_Fine Tuned_Adam_1/ResNet50_history.csv

# %%
# Save model file and tensorboard
model.save(MODEL_KERAS_PATH) # Keras format
print(f"Model keras format has been saved to: {MODEL_KERAS_PATH}")
model.save(MODEL_H5_PATH) # h5 format
print(f"Model h5 format has been saved to: {MODEL_H5_PATH}")
#model = keras.models.load_model(MODEL_CHECKPOINT_PATH) # Load best weight model
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Model keras format has been saved to: /content/drive/MyDrive/CP461/mainProject/models/ResNet50_Fine Tuned_Adam_1/ResNet50.keras
# Model h5 format has been saved to: /content/drive/MyDrive/CP461/mainProject/models/ResNet50_Fine Tuned_Adam_1/ResNet50.h5

# %%
model = keras.models.load_model(MODEL_KERAS_PATH) # Load best weight model

# %%
converter = tf.lite.TFLiteConverter.from_keras_model(model)
converter.optimizations = [tf.lite.Optimize.DEFAULT]
tflite_model = converter.convert()

with open(MODEL_TFLITE_PATH, "wb") as f:
    f.write(tflite_model) # tflite format
    print(f"Model tflite format has been saved to: {MODEL_TFLITE_PATH}")

json_model = model.to_json() #Save as json format
with open(MODEL_JSON_PATH, "w") as json_file:
    json_file.write(json_model)
    print(f"Model json format has been saved to: {MODEL_JSON_PATH}")
# Out:
# Saved artifact at '/tmp/tmpl8ek9_hc'. The following endpoints are available:
#
# * Endpoint 'serve'
#   args_0 (POSITIONAL_ONLY

# Out:
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 7s 134ms/step - accuracy: 0.7405 - loss: 1.1981 - precision: 0.7465 - recall: 0.7383

# %%
results
# Out:
# {'accuracy': 0.8317995667457581,
#  'loss': 0.7685820460319519,
#  'precision': 0.8363355398178101,
#  'recall': 0.830777108669281}

# %%
loss = results['loss']
accuracy = results['accuracy']
precision = results['precision']
recall = results['recall']

print(f"--Final Test Results--")
print(f"Loss      : {loss:.4f}")
print(f"Accuracy  : {accuracy:.4f}")
print(f"Precision : {precision:.4f}")
print(f"Recall    : {recall:.4f}")
# Out:
# --Final Test Results--
# Loss      : 0.7686
# Accuracy  : 0.8318
# Precision : 0.8363
# Recall    : 0.8308

# %%
y_pred_prob = model.predict(ds_test)

y_pred = np.argmax(y_pred_prob, axis=1)
y_pred_onehot = keras.utils.to_categorical(y_pred, num_classes=NUM_CLASSES)

y_true_batches = []
for images, labels in ds_test:
    y_true_batches.append(labels.numpy())

y_true_onehot = np.concatenate(y_true_batches, axis=0)
y_true = np.argmax(y_true_onehot, axis=1)
# Out:
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 8s 189ms/step

# %%
print(f"y_pred shape: {y_pred.shape}")
print(f"y_true shape: {y_true.shape}")
print(f"y_pred_onehot shape: {y_pred_onehot.shape}")
print(f"y_true_onehot shape: {y_true_onehot.shape}")
# Out:
# y_pred shape: (1956,)
# y_true shape: (1956,)
# y_pred_onehot shape: (1956, 7)
# y_true_onehot shape: (1956, 7)

# %% [markdown]
# ### **Top-1 and Top-5 accuracy**

# %%
# Top-1 Accuracy and Error
top_1 = keras.metrics.TopKCategoricalAccuracy(k=1)
top_1.update_state(y_true_onehot, y_pred_prob)
top_1_acc = top_1.result().numpy()
top_1_err = 1 - top_1_acc
print(f"Top-1 Accuracy: {top_1_acc:.4f}")
print(f"Top-1 Error: {top_1_err:.4f}")

# Top-5 Accuracy and Error
top_5 = keras.metrics.TopKCategoricalAccuracy(k=5)
top_5.update_state(y_true_onehot, y_pred_prob)
top_5_acc = top_5.result().numpy()
top_5_err = 1 - top_5_acc
print(f"Top-5 Accuracy: {top_5_acc:.4f}")
print(f"Top-5 Error: {top_5_err:.4f}")
# Out:
# Top-1 Accuracy: 0.8318
# Top-1 Error: 0.1682
# Top-5 Accuracy: 0.9964
# Top-5 Error: 0.0036

# %% [markdown]
# ### **Classification Report**

# %%
report = sklearn.metrics.classification_report(
    y_true,
    y_pred,
    target_names=class_names,
    digits=4,
    zero_division=0,
    output_dict=True
)
report_df = pd.DataFrame(report).transpose()
report_df.to_csv(MODEL_REPORT_PATH, index=True)
report_df
# Out:
#               precision    recall  f1-score    support
# akiec          0.688889  0.500000  0.579439    62.0000
# bcc            0.732673  0.762887  0.747475    97.0000
# bkl            0.727723  0.665158  0.695035   221.0000
# df             0.789474  0.517241  0.625000    29.0000
# mel            0.630058  0.495455  0.554707   220.0000
# nv             0.882649  0.943803  0.912202  1299.0000
# vasc           0.925926  0.892857  0.909091    28.0000
# accuracy       0.831800  0.831800  0.831800     0.8318
# macro avg      0.768199  0.682486  0.717564  1956.0000
# weighted avg   0.822394  0.831800  0.824437  1956.0000

# %% [markdown]
# ### **Training and Validation curve**

# %%
def plot_history(history, save_path=None, fontsize=16, title=None):
    """
        สำหรับ Plot training and validation curve สำหรับ accuracy และ loss
        Args:
            history: ประวัติการ Train ที่ได้จาก model.fit()
            save_path: เซฟภาพเก็บไว้ที่ไหน (optional)
            fontsize: ขนาด font default 16
            title: สำหรับชื่อรูปภาพ (optional)
    """
    history_dict = history.history
    epochs = range(1, len(history_dict["accuracy"]) + 1)

    fig = plt.figure(figsize=(12, 5))

    # --Loss--
    plt.subplot(1, 2, 1)
    plt.plot(epochs, history_dict["loss"], "b-", label="Training loss")
    plt.plot(epochs, history_dict["val_loss"], "r-", label="Validation loss")
    plt.title("Training and validation loss", fontsize=fontsize)
    plt.xlabel("Epochs", fontsize=fontsize)
    plt.ylabel("Loss", fontsize=fontsize)
    plt.legend(fontsize=fontsize-2)

    # --Accuracy--
    plt.subplot(1, 2, 2)
    plt.plot(epochs, history_dict["accuracy"], "b-", label="Training accuracy")
    plt.plot(epochs, history_dict["val_accuracy"], "r-", label="Validation accuracy")
    plt.title("Training and validation accuracy", fontsize=fontsize)
    plt.xlabel("Epochs", fontsize=fontsize)
    plt.ylabel("Accuracy", fontsize=fontsize)
    plt.legend(fontsize=fontsize-2)

    plt.tight_layout()

    if title:
        fig.text(0.5, 0.01, f"{title}", ha='center', fontsize=fontsize)

    if save_path:
        plt.savefig(f"{save_path}/train_valid_curve.png", format="png", dpi=300, bbox_inches="tight")
        plt.savefig(f"{save_path}/train_valid_curve.svg", format="svg", bbox_inches="tight")

    plt.show()

# %%
plot_history(history, save_path=ASSETS_FOR_MODEL_PATH, fontsize=14, title=f"{MODEL_NAME} {TYPE}")

# %% [markdown]
# ### **Confusion Matrix**

# %%
def plot_confusion_matrix(cm, classes, normalize=False,
                          title=None, cmap=plt.cm.Blues,
                          save_path=None, fontsize=12):

    """
        สำหรับ Plot counfusion matrix
        Args:
            cm (array): ค่า confusion matrix ที่ต้องการ plot
            classes (list): รายชื่อคลาส (label names) สำหรับแกน X และ Y
            normalize (bool, default=False): ถ้า True จะทำ normalization ให้ค่าทุกแถวรวมเป็น 1
            title (str, optional): ชื่อกราฟที่จะแสดงด้านบน
            cmap (matplotlib colormap, default=plt.cm.Blues): โทนสีของ heatmap
            save_path (str, optional): โฟลเดอร์ที่จะบันทึกภาพ (ถ้าไม่กำหนดจะไม่บันทึก)
            fontsize (int, default=12): ขนาดตัวอักษรในกราฟ
    """
    correct_predictions = np.trace(cm)
    total_samples = np.sum(cm)
    accuracy = correct_predictions / total_samples
    misclassification_rate = 1 - accuracy

    if title:
        if normalize:
            pic_title = f"{title}\nConfusion Matrix (normalized)"
        else:
            pic_title = f"{title}\nConfusion Matrix"
    else:
        if normalize:
            pic_title = "Confusion Matrix (normalized)"
        else:
            pic_title = "Confusion Matrix"

    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]

    plt.figure(figsize=(10, 7))
    plt.imshow(cm, interpolation="nearest", cmap=cmap)
    plt.title(pic_title, fontsize=fontsize, ha="center")
    plt.colorbar()

    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45, fontsize=fontsize)
    plt.yticks(tick_marks, classes, fontsize=fontsize)

    fmt = ".2f" if normalize else "d"
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 verticalalignment="center",
                 fontsize=fontsize,
                 color="white" if cm[i, j] > thresh else "black")

    plt.ylabel('True label', fontsize=fontsize)
    metrics_text = (
        f"\nAccuracy: {accuracy:.4f}  |  Misclass: {misclassification_rate:.4f}"
    )
    plt.xlabel(f"Predicted label{metrics_text}", fontsize=fontsize)
    plt.tight_layout()

    if save_path:
        if normalize:
            plt.savefig(f"{save_path}/confusion_matrix_normalized.png", format="png", dpi=300, bbox_inches="tight")
            plt.savefig(f"{save_path}/confusion_matrix_normalized.svg", format="svg", bbox_inches="tight")
        else:
            plt.savefig(f"{save_path}/confusion_matrix.png", format="png", dpi=300, bbox_inches="tight")
            plt.savefig(f"{save_path}/confusion_matrix.svg", format="svg", bbox_inches="tight")

    plt.show()

# %%
cm = sklearn.metrics.confusion_matrix(y_true, y_pred, labels=range(NUM_CLASSES))
plot_confusion_matrix(cm, class_names, title=f"{MODEL_NAME} {TYPE}", normalize=False, save_path=ASSETS_FOR_MODEL_PATH)

# %%
plot_confusion_matrix(cm, class_names, title=f"{MODEL_NAME} {TYPE}", normalize=True, save_path=ASSETS_FOR_MODEL_PATH)

# %% [markdown]
# ### **Plot AUC-ROC Curve**

# %%
def plot_multi_class_roc(y_true_onehot, y_pred_prob, class_names, title=None, save_path=None, fontsize=14):
    """
        y_true_onehot (ndarray): ค่า ground truth ในรูปแบบ one-hot encoded (ขนาด n_samples × n_classes)
        y_pred_prob (ndarray): ค่าความน่าจะเป็นที่โมเดลทำนาย (ขนาดเดียวกันกับ y_true_onehot)
        class_names (list): รายชื่อคลาสแต่ละคลาสที่ใช้แสดงในกราฟ
        title (str, optional): ชื่อกราฟ (ถ้าไม่ระบุจะใช้ชื่อเริ่มต้น “Receiver Operating Characteristic (ROC) - Multiclass”)
        save_path (str, optional): โฟลเดอร์สำหรับบันทึกภาพ (.png และ .svg)
        fontsize (int, default=14): ขนาดตัวอักษรในกราฟ
    """
    n_classes = y_pred_prob.shape[1]
    plt.figure(figsize=(12, 7))

    if title:
        pic_title = f"{title}\nReceiver Operating Characteristic (ROC) - Multiclass"
    else:
        pic_title = "Receiver Operating Characteristic (ROC) - Multiclass"

    for i in range(n_classes):
        fpr, tpr, _ = sklearn.metrics.roc_curve(y_true_onehot[:, i], y_pred_prob[:, i])
        roc_auc = sklearn.metrics.auc(fpr, tpr)
        plt.plot(fpr, tpr, lw=2, label=f"{class_names[i]} (AUC = {roc_auc:.4f})")

    fpr_micro, tpr_micro, _ = sklearn.metrics.roc_curve(y_true_onehot.ravel(), y_pred_prob.ravel())
    roc_auc_micro = sklearn.metrics.auc(fpr_micro, tpr_micro)
    plt.plot(fpr_micro, tpr_micro, color="deeppink", linestyle="--", lw=2,
             label=f"Micro-average (AUC = {roc_auc_micro:.4f})")

    roc_auc_macro = sklearn.metrics.roc_auc_score(y_true_onehot, y_pred_prob, average='macro')
    plt.plot([0, 1], [0, 1], color="gray", lw=1, linestyle="--",
             label=f"Macro-average (AUC = {roc_auc_macro:.4f})")

    plt.plot([0, 1], [0, 1], color="black", lw=1, linestyle=":")

    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.05])
    plt.xlabel("False Positive Rate", fontsize=fontsize)
    plt.ylabel("True Positive Rate", fontsize=fontsize)
    plt.title(pic_title, fontsize=fontsize)
    plt.legend(loc="lower right", fontsize=fontsize)
    plt.grid(alpha=0.3)

    plt.xticks(fontsize=fontsize)
    plt.yticks(fontsize=fontsize)

    if save_path:
        plt.savefig(f"{save_path}/roc_auc_curve.png", format="png", dpi=300, bbox_inches="tight")
        plt.savefig(f"{save_path}/roc_auc_curve.svg", format="svg", bbox_inches="tight")

    plt.show()

# %%
plot_multi_class_roc(y_true_onehot, y_pred_prob, class_names, f"{MODEL_NAME} {TYPE}", ASSETS_FOR_MODEL_PATH)
