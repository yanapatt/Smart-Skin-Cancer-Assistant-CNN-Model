# %% [markdown]
# <a href="https://colab.research.google.com/github/yanapatt/Smart-Skin-Cancer-Assistant-CNN-Model/blob/main/Benchmark_Original_(MobileNetV3Large)_FineTuning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Benchmark CNN Model**
# ---
# **คำอธิบาย**
# ไฟล์ Jupyter notebook ใช้สำหรับการ Train CNN Model
#
# ---
# **Group Oscar Do Everything**
# **หัวข้อ Smart Skin Cancer Assistant CNN Model**
# **สมาชิก**
#
# * 66102010137	นายณัฐนนท์ หลิมเหล็ก
# * 66102010145	นายพชรดนัย กุระกนก
# * 66102010153	นายศิลายุชย์ โชติธรรมาภรณ์
# * 66102010236	นายญาณภัทร ปานเกษม
#
# **รายวิชา**
# **CP461 Introduction to Computer Vision**
#
# **Main Reference : An Interpretable Deep Learning Approach for Skin Cancer Categorization**
#
# **Paper Link:** https://arxiv.org/abs/2312.10696
# **GitHub:** https://github.com/Faysal-MD/An-Interpretable-Deep-Learning-Approach-for-Skin-Cancer-Categorization-IEEE2023?utm_source=chatgpt.com

# %% [markdown]
# ## **Section 0: Import important library**

# %%
import os
import itertools
import time
from psutil import virtual_memory

import pandas as pd
import numpy as np
import random as rd

import tensorflow as tf
import keras
os.environ["KERAS_BACKEND"] = "tensorflow"
import sklearn
import joblib

import matplotlib.pyplot as plt
import matplotlib.font_manager as fm
import seaborn as sns
import cv2
import albumentations as A

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ### **Setting a seed system environment**

# %%
def set_seed(seed):
    """
        ใช้สำหรับการตั้งค่า Seed Environment เพื่อให้ผลลัพธ์สามารถ Reproduce ได้
        Arg:
            seed คือ ค่า Integer สำหรับกำหนด Seed
    """
    tf.random.set_seed(seed)
    tf.config.experimental.enable_op_determinism()
    keras.utils.set_random_seed(seed)

    np.random.seed(seed)
    rd.seed(seed)

    os.environ["PYTHONHASHSEED"] = str(seed)
    os.environ["TF_DETERMINISTIC_OPS"] = "1"

    print(f"The seed number has been set at {seed}")

# %%
SEED = 42
set_seed(SEED)
# Out:
# The seed number has been set at 42

# %%
gpu_info = !nvidia-smi
gpu_info = "\n".join(gpu_info)
if gpu_info.find("failed") >= 0:
  print("Not connected to a GPU")
else:
  print(gpu_info)

ram_gb = virtual_memory().total / 1e9
print(f"Your runtime has {ram_gb:.1f} gigabytes of available RAM")
print(f"Tensorflow version: {tf.__version__}")
print(f"Keras version: {keras.__version__}")
# Out:
# Wed Oct 29 01:53:05 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.54.15              Driver Version: 550.54.15      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA L4                      Off |   00000000:00:03.0 Off |                    0 |
# | N/A   59C    P8             13W /   72W |       0MiB /  23034MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI        PID   Type   Process name                              GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |  No running processes found                                                             |
# +-----------------------------------------------------------------------------------------+
# Your runtime has 56.9 gigabytes of available RAM
# Tensorflow version: 2.19.0
# Keras version: 3.10.0

# %% [markdown]
# ## **Section 1: Preparing the directory for dataset and model**

# %% [markdown]
# ### **In G-Drive Directory**

# %%
DRIVE_DIR = "/content/drive/MyDrive/CP461/mainProject" # Drive Directory
ASSETS_PATH = f"{DRIVE_DIR}/assets" # Assets Path
DATASET_ZIP_PATH = f"{DRIVE_DIR}/datasets/ham10000Dataset.zip"
INDEX_SETTING = f"{DRIVE_DIR}/datasets/indexSetting"

# %%
# Setting font
fm.fontManager.addfont(f"{ASSETS_PATH}/fonts/OPTITimes-Roman.otf")
font_prop = fm.FontProperties(fname=f"{ASSETS_PATH}/fonts/OPTITimes-Roman.otf")
font_name = font_prop.get_name()
plt.rcParams["font.family"] = font_name

# %%
MODEL_PATH = f"{DRIVE_DIR}/models" # <= สำหรับเก็บ Log Model ต่าง ๆ
MODEL_NAME = "MobileNetV3Large Original" # <= Model อะไร
OPTIMIZER_NAME = "Adam" # <= Optimizer อะไร
TYPE = "Fine Tuned" # <= Fine-Tuned หรือ Feature Extraction
ROUND_NUM = 1 # <= รันครั้งที่เท่าไหร่
MODEL_FULL_PATH = f"{MODEL_PATH}/{MODEL_NAME}_{TYPE}_{OPTIMIZER_NAME}_{ROUND_NUM}"
ASSETS_FOR_MODEL_PATH = f"{MODEL_FULL_PATH}/assets" # <= สำหรับเก็บรูปภาพต่าง ๆ จากโมเดล

os.makedirs(MODEL_FULL_PATH, exist_ok=True)
os.makedirs(ASSETS_FOR_MODEL_PATH, exist_ok=True)

# %%
MODEL_KERAS_PATH = f"{MODEL_FULL_PATH}/{MODEL_NAME}.keras"
MODEL_H5_PATH = f"{MODEL_FULL_PATH}/{MODEL_NAME}.h5"
MODEL_TFLITE_PATH = f"{MODEL_FULL_PATH}/{MODEL_NAME}.tflite"
MODEL_CHECKPOINT_PATH = f"{MODEL_FULL_PATH}/{MODEL_NAME}_best.keras"
MODEL_TENSORBOARD_PATH = f"{MODEL_FULL_PATH}/{MODEL_NAME}_tensorboard.logs"
MODEL_HISTORY_PATH = f"{MODEL_FULL_PATH}/{MODEL_NAME}_history.csv"
MODEL_JSON_PATH = f"{MODEL_FULL_PATH}/{MODEL_NAME}_json.json"
MODEL_REPORT_PATH = f"{MODEL_FULL_PATH}/{MODEL_NAME}_report.csv"

# %% [markdown]
# ### **In Runtime Directory**

# %%
# !unzip /content/drive/MyDrive/CP461/mainProject/datasets/ham10000Dataset.zip -d /content/ham10000Dataset
# Out:
# เอาต์พุตของการสตรีมมีการตัดเหลือเพียง 5000 บรรทัดสุดท้าย
#   inflating: /content/ham10000Dataset/train/bkl/ISIC_0031766.jpg
#   inflating: /content/ham10000Dataset/train/bkl/ISIC_0031519.jpg
#   inflating: /content/ham10000Dataset/train/bkl/ISIC_0030965.jpg
#   inflating: /content/ham10000Dataset/train/bkl/ISIC_0027828.jpg
#   inflating: /content/ham10000Dataset/train/bkl/ISIC_0033635.jpg
#   inflating: /content/ham10000Dataset/train/bkl/ISIC_0029029.jpg
#   inflating: /content/ham10000Dataset/train/bkl/ISIC_0025716.jpg
#   inflating: /content/ham10000Dataset/train/bkl/ISIC_0034221.jpg
#   inflating: /content/ham10000Dataset/train/bkl/ISIC_0029301.jpg
#   inflating: /content/ham10000Dataset/train/bkl/ISIC_0029014.jpg
#   inflating: /content/ham10000Dataset/train/bkl/ISIC_0031037.jpg
#   inflating: /content/ham10000Dataset/train/bkl/ISIC_0027454.jpg
#   inflating: /content/ham10000Dataset/train/bkl/ISIC_0029741.jpg
#   inflating: /content/ham10000Dataset/train/bkl/ISIC_0029557.jpg
#   inflating: /content/ham10000Dataset/train/bkl/ISIC_0025388.jpg
#   inflating: /content/ham10000Dataset/train/bkl/ISIC_0034315.jpg
#   inflating: /content/ham10000Dataset/train/bkl/ISIC_0034165.jpg
#   inflating: /content/ham10000Dataset/train/bkl/ISIC_0033854.jpg
#   inflating: /content/ham10000Dataset/train/bkl/ISIC_0034037.jpg
#   inflating: /content/ham10000Dataset/train/bkl/ISIC_0033900.jpg
#   inflating: /content/ham10000Dataset/train/bkl/ISIC_0032804.jpg
#   inflating: /content/ham10000Dataset/train/bkl/ISIC_0026714.jpg
#   inflating: /content/ham10000Dataset/train/bkl/ISIC_0025529.jpg
#   inflating: /content/ham10000Dataset/train/bkl/ISIC_0029791.jpg
#   inflating: /content/ham10000Dataset/train/bkl/ISIC_0026576.jpg
#   inflating: /content/ham10000Dataset/train/bkl/ISIC_0029101.jpg
#   inflating: /content/ham10000Dataset/train/bkl/ISIC_0027027.jpg
#   inflating: /content/ham10000Dataset/train/bkl/ISIC_0028840.jpg
#   inflating: /content/ham10000Dataset/train/bkl/ISIC_0029060.jpg
#   inflating: /content/ham10000Dataset/train/bkl/ISIC_0033022.jpg
#   inflating: /content/ham10000Dataset/train/bkl/ISIC_0024839.jpg
#   inflating: /content/ham10000Dataset/train/bkl/ISIC_0028121.jpg
#   inflating: /content/ham10000Dataset/train/bkl/ISIC_0029418.jpg
#   inflating: /content/ham10000Dataset/train/bkl/ISIC_0025366.jpg
#   inflating: /content/ham10000Dataset/train/bkl/ISIC_0029420.jpg
#   inflating: /content/ham10000Dataset/train/bkl/ISIC_0029217.jpg
#   inflating: /content/ham10000Dataset/train/bkl/ISIC_0031961.jpg
#   inflating: /content/ham10000Dataset/train/bkl/ISIC_0024412.jpg
#   inflating: /content/ham10000Dataset/train/bkl/ISIC_0028294.jpg
#   inflating: /content/ham10000Dataset/train/bkl/ISIC_0028931.jpg
#   inflating: /content/ham10000Dataset/train/bkl/ISIC_0025777.jpg
#   inflating: /content/ham10000Dataset/train/bkl/ISIC_0027770.jpg
#   inflating: /content/ham10000Dataset/train/bkl/ISIC_0028640.jpg
#   inflating: /content/ham10000Dataset/train/bkl/ISIC_0031008.jpg
#   inflating: /content/ham10000Dataset/train/bkl/ISIC_0032330.jpg
#   inflating: /content/ham10000Dataset/train/bkl/ISIC_0031851.jpg
#   inflating: /content/ham10000Dataset/train/bkl/ISIC_0033629.jpg
#   inflating: /content/ham10000Dataset/train/bkl/ISIC_0031702.jpg
#   inflating: /content/ham10000Dataset/train/bkl/ISIC_0027068.jpg
#   inflating: /content/ham10000Dataset/train/bkl/ISIC_0030369.jpg
#   inflating: /content/ham10000Dataset/train/bkl/ISIC_0029195.jpg
#   inflating: /content/ham10000Dataset/train/bkl/ISIC_0034197.jpg
#   inflating: /content/ham10000Dataset/train/bkl/ISIC_0026511.jpg
#   inflating: /content/ham10000Dataset/train/bkl/ISIC_0032776.jpg
#   inflating: /content/ham10000Dataset/train/bkl/ISIC_0031876.jpg
#   inflating: /content/ham10000Dataset/train/bkl/ISIC_0025099.jpg
#   inflating: /content/ham10000Dataset/train/bkl/ISIC_0024786.jpg
#   inflating: /content/ham10000Dataset/train/bkl/ISIC_0025575.jpg
#   inflating: /content/ham10000Dataset/train/bkl/ISIC_0028842.jpg
#   inflating: /content/ham10000Dataset/train/bkl/ISIC_0029596.jpg
#   inflating: /content/ham10000Dataset/train/bkl/ISIC_0031168.jpg
#   inflating: /content/ham10000Dataset/train/bkl/ISIC_0025419.jpg
#   inflating: /content/ham10000Dataset/train/bkl/ISIC_0030189.jpg
#   inflating: /content/ham10000Dataset/train/bkl/ISIC_0024877.jpg
#   inflating: /content/ham10000Dataset/train/bkl/ISIC_0029585.jpg
#   inflating: /content/ham10000Dataset/train/bkl/ISIC_0025485.jpg
#   inflating: /content/ham10000Dataset/train/bkl/ISIC_0026444.jpg
#   inflating: /content/ham10000Dataset/train/bkl/ISIC_0027218.jpg
#   inflating: /content/ham10000Dataset/train/bkl/ISIC_0028388.jpg
#   inflating: /content/ham10000Dataset/train/bkl/ISIC_0026042.jpg
#   inflating: /content/ham10000Dataset/train/bkl/ISIC_0029100.jpg
#   inflating: /content/ham10000Dataset/train/bkl/ISIC_0033252.jpg
#   inflating: /content/ham10000Dataset/train/bkl/ISIC_0028124.jpg
#   inflating: /content/ham10000Dataset/train/bkl/ISIC_0028525.jpg
#   inflating: /content/ham10000Dataset/train/bkl/ISIC_0030241.jpg
#   inflating: /content/ham10000Dataset/train/bkl/ISIC_0028308.jpg
#   inflating: /content/ham10000Dataset/train/bkl/ISIC_0029206.jpg
#   inflating: /content/ham10000Dataset/train/bkl/ISIC_0026790.jpg
#   inflating: /content/ham10000Dataset/train/bkl/ISIC_0033438.jpg
#   inflating: /content/ham10000Dataset/train/bkl/ISIC_0030723.jpg
#   inflating: /content/ham10000Dataset/train/bkl/ISIC_0033307.jpg
#   inflating: /content/ham10000Dataset/train/bkl/ISIC_0030926.jpg
#   inflating: /content/ham10000Dataset/train/bkl/ISIC_0030365.jpg
#   inflating: /content/ham10000Dataset/train/bkl/ISIC_0028236.jpg
#   inflating: /content/ham10000Dataset/train/bkl/ISIC_0025627.jpg
#   inflating: /content/ham10000Dataset/train/bkl/ISIC_0032123.jpg
#   inflating: /content/ham10000Dataset/train/bkl/ISIC_0030005.jpg
#   inflating: /content/ham10000Dataset/train/bkl/ISIC_0026835.jpg
#   inflating: /content/ham10000Dataset/train/bkl/ISIC_0027953.jpg
#   inflating: /content/ham10000Dataset/train/bkl/ISIC_0027982.jpg
#   inflating: /content/ham10000Dataset/train/bkl/ISIC_0024408.jpg
#   inflating: /content/ham10000Dataset/train/bkl/ISIC_0025083.jpg
#   inflating: /content/ham10000Dataset/train/bkl/ISIC_0032983.jpg
#   inflating: /content/ham10000Dataset/train/bkl/ISIC_0028646.jpg
#   inflating: /content/ham10000Dataset/train/bkl/ISIC_0033449.jpg
#   inflating: /content/ham10000Dataset/train/bkl/ISIC_0026861.jpg
#   inflating: /content/ham10000Dataset/train/bkl/ISIC_0031218.jpg
#   inflating: /content/ham10000Dataset/train/bkl/ISIC_0027533.jpg
#   inflating: /content/ham10000Dataset/train/bkl/ISIC_0025719.jpg
#   inflating: /content/ham10000Dataset/train/bkl/ISIC_0031580.jpg
#   inflating: /content/ham10000Dataset/train/bkl/ISIC_0025276.jpg
#   inflating: /content/ham10000Dataset/train/bkl/ISIC_0027455.jpg
#   inflating: /content/ham10000Dataset/train/bkl/ISIC_0033041.jpg
#   inflating: /content/ham10000Dataset/train/bkl/ISIC_0029032.jpg
#   inflating: /content/ham10000Dataset/train/bkl/ISIC_0029687.jpg
#   inflating: /content/ham10000Dataset/train/bkl/ISIC_0025470.jpg
#   inflating: /content/ham10000Dataset/train/bkl/ISIC_0031061.jpg
#   inflating: /content/ham10000Dataset/train/bkl/ISIC_0034057.jpg
#   inflating: /content/ham10000Dataset/train/bkl/ISIC_0031485.jpg
#   inflating: /content/ham10000Dataset/train/bkl/ISIC_0031016.jpg
#   inflating: /content/ham10000Dataset/train/bkl/ISIC_0031770.jpg
#   inflating: /content/ham10000Dataset/train/bkl/ISIC_0034011.jpg
#   inflating: /content/ham10000Dataset/train/bkl/ISIC_0033270.jpg
#   inflating: /content/ham10000Dataset/train/bkl/ISIC_0031396.jpg
#   inflating: /content/ham10000Dataset/train/bkl/ISIC_0031130.jpg
#   inflating: /content/ham10000Dataset/train/bkl/ISIC_0033079.jpg
#   inflating: /content/ham10000Dataset/train/bkl/ISIC_0031159.jpg
#   inflating: /content/ham10000Dataset/train/bkl/ISIC_0030998.jpg
#   inflating: /content/ham10000Dataset/train/bkl/ISIC_0033828.jpg
#   inflating: /content/ham10000Dataset/train/bkl/ISIC_0027559.jpg
#   inflating: /content/ham10000Dataset/train/bkl/ISIC_0024814.jpg
#   inflating: /content/ham10000Dataset/train/bkl/ISIC_0027437.jpg
#   inflating: /content/ham10000Dataset/train/bkl/ISIC_0027815.jpg
#   inflating: /content/ham10000Dataset/train/bkl/ISIC_0025330.jpg
#   inflating: /content/ham10000Dataset/train/bkl/ISIC_0029991.jpg
#   inflating: /content/ham10000Dataset/train/bkl/ISIC_0033924.jpg
#   inflating: /content/ham10000Dataset/train/bkl/ISIC_0029924.jpg
#   inflating: /content/ham10000Dataset/train/bkl/ISIC_0027649.jpg
#   inflating: /content/ham10000Dataset/train/bkl/ISIC_0032099.jpg
#   inflating: /content/ham10000Dataset/train/bkl/ISIC_0024748.jpg
#   inflating: /content/ham10000Dataset/train/bkl/ISIC_0032111.jpg
#   inflating: /content/ham10000Dataset/train/bkl/ISIC_0025222.jpg
#   inflating: /content/ham10000Dataset/train/bkl/ISIC_0033770.jpg
#   inflating: /content/ham10000Dataset/train/bkl/ISIC_0032006.jpg
#   inflating: /content/ham10000Dataset/train/bkl/ISIC_0028094.jpg
#   inflating: /content/ham10000Dataset/train/bkl/ISIC_0033913.jpg
#   inflating: /content/ham10000Dataset/train/bkl/ISIC_0027905.jpg
#   inflating: /content/ham10000Dataset/train/bkl/ISIC_0028977.jpg
#   inflating: /content/ham10000Dataset/train/bkl/ISIC_0027463.jpg
#   inflating: /content/ham10000Dataset/train/bkl/ISIC_0024592.jpg
#   inflating: /content/ham10000Dataset/train/bkl/ISIC_0028876.jpg
#   inflating: /content/ham10000Dataset/train/bkl/ISIC_0025466.jpg
#   inflating: /content/ham10000Dataset/train/bkl/ISIC_0033056.jpg
#   inflating: /content/ham10000Dataset/train/bkl/ISIC_0030649.jpg
#   inflating: /content/ham10000Dataset/train/bkl/ISIC_0030258.jpg
#   inflating: /content/ham10000Dataset/train/bkl/ISIC_0031945.jpg
#   inflating: /content/ham10000Dataset/train/bkl/ISIC_0027167.jpg
#   inflating: /content/ham10000Dataset/train/bkl/ISIC_0031253.jpg
#   inflating: /content/ham10000Dataset/train/bkl/ISIC_0030542.jpg
#   inflating: /content/ham10000Dataset/train/bkl/ISIC_0027326.jpg
#   inflating: /content/ham10000Dataset/train/bkl/ISIC_0030137.jpg
#   inflating: /content/ham10000Dataset/train/bkl/ISIC_0027954.jpg
#   inflating: /content/ham10000Dataset/train/bkl/ISIC_0024981.jpg
#   inflating: /content/ham10000Dataset/train/bkl/ISIC_0034235.jpg
#   inflating: /content/ham10000Dataset/train/bkl/ISIC_0028972.jpg
#   inflating: /content/ham10000Dataset/train/bkl/ISIC_0029135.jpg
#   inflating: /content/ham10000Dataset/train/bkl/ISIC_0034031.jpg
#   inflating: /content/ham10000Dataset/train/bkl/ISIC_0032365.jpg
#   inflating: /content/ham10000Dataset/train/bkl/ISIC_0028503.jpg
#   inflating: /content/ham10000Dataset/train/bkl/ISIC_0029793.jpg
#   inflating: /content/ham10000Dataset/train/bkl/ISIC_0026893.jpg
#   inflating: /content/ham10000Dataset/train/bkl/ISIC_0025345.jpg
#   inflating: /content/ham10000Dataset/train/bkl/ISIC_0029291.jpg
#   inflating: /content/ham10000Dataset/train/bkl/ISIC_0026245.jpg
#   inflating: /content/ham10000Dataset/train/bkl/ISIC_0033088.jpg
#   inflating: /content/ham10000Dataset/train/bkl/ISIC_0031601.jpg
#   inflating: /content/ham10000Dataset/train/bkl/ISIC_0025937.jpg
#   inflating: /content/ham10000Dataset/train/bkl/ISIC_0024495.jpg
#   inflating: /content/ham10000Dataset/train/bkl/ISIC_0026843.jpg
#   inflating: /content/ham10000Dataset/train/bkl/ISIC_0032570.jpg
#   inflating: /content/ham10000Dataset/train/bkl/ISIC_0030118.jpg
#   inflating: /content/ham10000Dataset/train/bkl/ISIC_0026538.jpg
#   inflating: /content/ham10000Dataset/train/bkl/ISIC_0027969.jpg
#   inflating: /content/ham10000Dataset/train/bkl/ISIC_0027991.jpg
#   inflating: /content/ham10000Dataset/train/bkl/ISIC_0033581.jpg
#   inflating: /content/ham10000Dataset/train/bkl/ISIC_0033195.jpg
#   inflating: /content/ham10000Dataset/train/bkl/ISIC_0031078.jpg
#   inflating: /content/ham10000Dataset/train/bkl/ISIC_0026590.jpg
#   inflating: /content/ham10000Dataset/train/bkl/ISIC_0032618.jpg
#   inflating: /content/ham10000Dataset/train/bkl/ISIC_0026846.jpg
#   inflating: /content/ham10000Dataset/train/bkl/ISIC_0025642.jpg
#   inflating: /content/ham10000Dataset/train/bkl/ISIC_0028555.jpg
#   inflating: /content/ham10000Dataset/train/bkl/ISIC_0027710.jpg
#   inflating: /content/ham10000Dataset/train/bkl/ISIC_0032156.jpg
#   inflating: /content/ham10000Dataset/train/bkl/ISIC_0028701.jpg
#   inflating: /content/ham10000Dataset/train/bkl/ISIC_0032486.jpg
#   inflating: /content/ham10000Dataset/train/bkl/ISIC_0026907.jpg
#   inflating: /content/ham10000Dataset/train/bkl/ISIC_0029358.jpg
#   inflating: /content/ham10000Dataset/train/bkl/ISIC_0026827.jpg
#   inflating: /content/ham10000Dataset/train/bkl/ISIC_0030319.jpg
#   inflating: /content/ham10000Dataset/train/bkl/ISIC_0033736.jpg
#   inflating: /content/ham10000Dataset/train/bkl/ISIC_0027094.jpg
#   inflating: /content/ham10000Dataset/train/bkl/ISIC_0029249.jpg
#   inflating: /content/ham10000Dataset/train/bkl/ISIC_0025661.jpg
#   inflating: /content/ham10000Dataset/train/bkl/ISIC_0033305.jpg
#   inflating: /content/ham10000Dataset/train/bkl/ISIC_0027606.jpg
#   inflating: /content/ham10000Dataset/train/bkl/ISIC_0033378.jpg
#   inflating: /content/ham10000Dataset/train/bkl/ISIC_0026606.jpg
#   inflating: /content/ham10000Dataset/train/bkl/ISIC_0024761.jpg
#   inflating: /content/ham10000Dataset/train/bkl/ISIC_0033361.jpg
#   inflating: /content/ham10000Dataset/train/bkl/ISIC_0026607.jpg
#   inflating: /content/ham10000Dataset/train/bkl/ISIC_0033127.jpg
#   inflating: /content/ham10000Dataset/train/bkl/ISIC_0033124.jpg
#   inflating: /content/ham10000Dataset/train/bkl/ISIC_0031261.jpg
#   inflating: /content/ham10000Dataset/train/bkl/ISIC_0028856.jpg
#   inflating: /content/ham10000Dataset/train/bkl/ISIC_0027831.jpg
#   inflating: /content/ham10000Dataset/train/bkl/ISIC_0026737.jpg
#   inflating: /content/ham10000Dataset/train/bkl/ISIC_0027192.jpg
#   inflating: /content/ham10000Dataset/train/bkl/ISIC_0029302.jpg
#   inflating: /content/ham10000Dataset/train/bkl/ISIC_0029836.jpg
#   inflating: /content/ham10000Dataset/train/bkl/ISIC_0033130.jpg
#   inflating: /content/ham10000Dataset/train/bkl/ISIC_0026044.jpg
#   inflating: /content/ham10000Dataset/train/bkl/ISIC_0030203.jpg
#   inflating: /content/ham10000Dataset/train/bkl/ISIC_0024741.jpg
#   inflating: /content/ham10000Dataset/train/bkl/ISIC_0033583.jpg
#   inflating: /content/ham10000Dataset/train/bkl/ISIC_0026769.jpg
#   inflating: /content/ham10000Dataset/train/bkl/ISIC_0028846.jpg
#   inflating: /content/ham10000Dataset/train/bkl/ISIC_0025068.jpg
#   inflating: /content/ham10000Dataset/train/bkl/ISIC_0024445.jpg
#   inflating: /content/ham10000Dataset/train/bkl/ISIC_0029548.jpg
#   inflating: /content/ham10000Dataset/train/bkl/ISIC_0032456.jpg
#   inflating: /content/ham10000Dataset/train/bkl/ISIC_0025326.jpg
#   inflating: /content/ham10000Dataset/train/bkl/ISIC_0033322.jpg
#   inflating: /content/ham10000Dataset/train/bkl/ISIC_0033553.jpg
#   inflating: /content/ham10000Dataset/train/bkl/ISIC_0032283.jpg
#   inflating: /content/ham10000Dataset/train/bkl/ISIC_0028386.jpg
#   inflating: /content/ham10000Dataset/train/bkl/ISIC_0028710.jpg
#   inflating: /content/ham10000Dataset/train/bkl/ISIC_0026523.jpg
#   inflating: /content/ham10000Dataset/train/bkl/ISIC_0031537.jpg
#   inflating: /content/ham10000Dataset/train/bkl/ISIC_0032967.jpg
#   inflating: /content/ham10000Dataset/train/bkl/ISIC_0025140.jpg
#   inflating: /content/ham10000Dataset/train/bkl/ISIC_0031196.jpg
#   inflating: /content/ham10000Dataset/train/bkl/ISIC_0033437.jpg
#   inflating: /content/ham10000Dataset/train/bkl/ISIC_0029801.jpg
#   inflating: /content/ham10000Dataset/train/bkl/ISIC_0028622.jpg
#   inflating: /content/ham10000Dataset/train/bkl/ISIC_0027239.jpg
#   inflating: /content/ham10000Dataset/train/bkl/ISIC_0029243.jpg
#   inflating: /content/ham10000Dataset/train/bkl/ISIC_0025063.jpg
#   inflating: /content/ham10000Dataset/train/bkl/ISIC_0024498.jpg
#   inflating: /content/ham10000Dataset/train/bkl/ISIC_0031362.jpg
#   inflating: /content/ham10000Dataset/train/bkl/ISIC_0026378.jpg
#   inflating: /content/ham10000Dataset/train/bkl/ISIC_0030608.jpg
#   inflating: /content/ham10000Dataset/train/bkl/ISIC_0025507.jpg
#   inflating: /content/ham10000Dataset/train/bkl/ISIC_0030700.jpg
#   inflating: /content/ham10000Dataset/train/bkl/ISIC_0028376.jpg
#   inflating: /content/ham10000Dataset/train/bkl/ISIC_0031464.jpg
#   inflating: /content/ham10000Dataset/train/bkl/ISIC_0024782.jpg
#   inflating: /content/ham10000Dataset/train/bkl/ISIC_0030067.jpg
#   inflating: /content/ham10000Dataset/train/bkl/ISIC_0034296.jpg
#   inflating: /content/ham10000Dataset/train/bkl/ISIC_0026205.jpg
#   inflating: /content/ham10000Dataset/train/bkl/ISIC_0030329.jpg
#   inflating: /content/ham10000Dataset/train/bkl/ISIC_0025883.jpg
#   inflating: /content/ham10000Dataset/train/bkl/ISIC_0025392.jpg
#   inflating: /content/ham10000Dataset/train/bkl/ISIC_0028389.jpg
#   inflating: /content/ham10000Dataset/train/bkl/ISIC_0026961.jpg
#   inflating: /content/ham10000Dataset/train/bkl/ISIC_0026717.jpg
#   inflating: /content/ham10000Dataset/train/bkl/ISIC_0028490.jpg
#   inflating: /content/ham10000Dataset/train/bkl/ISIC_0024970.jpg
#   inflating: /content/ham10000Dataset/train/bkl/ISIC_0033701.jpg
#   inflating: /content/ham10000Dataset/train/bkl/ISIC_0032230.jpg
#   inflating: /content/ham10000Dataset/train/bkl/ISIC_0025879.jpg
#   inflating: /content/ham10000Dataset/train/bkl/ISIC_0028656.jpg
#   inflating: /content/ham10000Dataset/train/bkl/ISIC_0030812.jpg
#   inflating: /content/ham10000Dataset/train/bkl/ISIC_0029235.jpg
#   inflating: /content/ham10000Dataset/train/bkl/ISIC_0026446.jpg
#   inflating: /content/ham10000Dataset/train/bkl/ISIC_0030396.jpg
#   inflating: /content/ham10000Dataset/train/bkl/ISIC_0029929.jpg
#   inflating: /content/ham10000Dataset/train/bkl/ISIC_0034259.jpg
#   inflating: /content/ham10000Dataset/train/bkl/ISIC_0026046.jpg
#   inflating: /content/ham10000Dataset/train/bkl/ISIC_0031825.jpg
#   inflating: /content/ham10000Dataset/train/bkl/ISIC_0027850.jpg
#   inflating: /content/ham10000Dataset/train/bkl/ISIC_0024880.jpg
#   inflating: /content/ham10000Dataset/train/bkl/ISIC_0026844.jpg
#   inflating: /content/ham10000Dataset/train/bkl/ISIC_0031619.jpg
#   inflating: /content/ham10000Dataset/train/bkl/ISIC_0025292.jpg
#   inflating: /content/ham10000Dataset/train/bkl/ISIC_0028473.jpg
#   inflating: /content/ham10000Dataset/train/bkl/ISIC_0033587.jpg
#   inflating: /content/ham10000Dataset/train/bkl/ISIC_0028797.jpg
#   inflating: /content/ham10000Dataset/train/bkl/ISIC_0033465.jpg
#   inflating: /content/ham10000Dataset/train/bkl/ISIC_0025016.jpg
#   inflating: /content/ham10000Dataset/train/bkl/ISIC_0025928.jpg
#   inflating: /content/ham10000Dataset/train/bkl/ISIC_0030372.jpg
#   inflating: /content/ham10000Dataset/train/bkl/ISIC_0026286.jpg
#   inflating: /content/ham10000Dataset/train/bkl/ISIC_0029068.jpg
#   inflating: /content/ham10000Dataset/train/bkl/ISIC_0032024.jpg
#   inflating: /content/ham10000Dataset/train/bkl/ISIC_0032898.jpg
#   inflating: /content/ham10000Dataset/train/bkl/ISIC_0029527.jpg
#   inflating: /content/ham10000Dataset/train/bkl/ISIC_0033169.jpg
#   inflating: /content/ham10000Dataset/train/bkl/ISIC_0031496.jpg
#   inflating: /content/ham10000Dataset/train/bkl/ISIC_0025830.jpg
#   inflating: /content/ham10000Dataset/train/bkl/ISIC_0026409.jpg
#   inflating: /content/ham10000Dataset/train/bkl/ISIC_0026291.jpg
#   inflating: /content/ham10000Dataset/train/bkl/ISIC_0027760.jpg
#   inflating: /content/ham10000Dataset/train/bkl/ISIC_0028970.jpg
#   inflating: /content/ham10000Dataset/train/bkl/ISIC_0030822.jpg
#   inflating: /content/ham10000Dataset/train/bkl/ISIC_0027771.jpg
#   inflating: /content/ham10000Dataset/train/bkl/ISIC_0033531.jpg
#   inflating: /content/ham10000Dataset/train/bkl/ISIC_0025554.jpg
#   inflating: /content/ham10000Dataset/train/bkl/ISIC_0029474.jpg
#   inflating: /content/ham10000Dataset/train/bkl/ISIC_0032963.jpg
#   inflating: /content/ham10000Dataset/train/bkl/ISIC_0029232.jpg
#   inflating: /content/ham10000Dataset/train/bkl/ISIC_0024643.jpg
#   inflating: /content/ham10000Dataset/train/bkl/ISIC_0024825.jpg
#   inflating: /content/ham10000Dataset/train/bkl/ISIC_0029102.jpg
#   inflating: /content/ham10000Dataset/train/bkl/ISIC_0033246.jpg
#   inflating: /content/ham10000Dataset/train/bkl/ISIC_0032043.jpg
#   inflating: /content/ham10000Dataset/train/bkl/ISIC_0029308.jpg
#   inflating: /content/ham10000Dataset/train/bkl/ISIC_0024602.jpg
#   inflating: /content/ham10000Dataset/train/vasc/ISIC_0031648.jpg
#   inflating: /content/ham10000Dataset/train/vasc/ISIC_0027888.jpg
#   inflating: /content/ham10000Dataset/train/vasc/ISIC_0034196.jpg
#   inflating: /content/ham10000Dataset/train/vasc/ISIC_0031901.jpg
#   inflating: /content/ham10000Dataset/train/vasc/ISIC_0030770.jpg
#   inflating: /content/ham10000Dataset/train/vasc/ISIC_0032538.jpg
#   inflating: /content/ham10000Dataset/train/vasc/ISIC_0031093.jpg
#   inflating: /content/ham10000Dataset/train/vasc/ISIC_0029514.jpg
#   inflating: /content/ham10000Dataset/train/vasc/ISIC_0032409.jpg
#   inflating: /content/ham10000Dataset/train/vasc/ISIC_0024904.jpg
#   inflating: /content/ham10000Dataset/train/vasc/ISIC_0033591.jpg
#   inflating: /content/ham10000Dataset/train/vasc/ISIC_0026713.jpg
#   inflating: /content/ham10000Dataset/train/vasc/ISIC_0029486.jpg
#   inflating: /content/ham10000Dataset/train/vasc/ISIC_0030283.jpg
#   inflating: /content/ham10000Dataset/train/vasc/ISIC_0028163.jpg
#   inflating: /content/ham10000Dataset/train/vasc/ISIC_0025924.jpg
#   inflating: /content/ham10000Dataset/train/vasc/ISIC_0031090.jpg
#   inflating: /content/ham10000Dataset/train/vasc/ISIC_0026163.jpg
#   inflating: /content/ham10000Dataset/train/vasc/ISIC_0033565.jpg
#   inflating: /content/ham10000Dataset/train/vasc/ISIC_0025321.jpg
#   inflating: /content/ham10000Dataset/train/vasc/ISIC_0031201.jpg
#   inflating: /content/ham10000Dataset/train/vasc/ISIC_0025197.jpg
#   inflating: /content/ham10000Dataset/train/vasc/ISIC_0033458.jpg
#   inflating: /content/ham10000Dataset/train/vasc/ISIC_0025628.jpg
#   inflating: /content/ham10000Dataset/train/vasc/ISIC_0025249.jpg
#   inflating: /content/ham10000Dataset/train/vasc/ISIC_0025807.jpg
#   inflating: /content/ham10000Dataset/train/vasc/ISIC_0033608.jpg
#   inflating: /content/ham10000Dataset/train/vasc/ISIC_0032866.jpg
#   inflating: /content/ham10000Dataset/train/vasc/ISIC_0024706.jpg
#   inflating: /content/ham10000Dataset/train/vasc/ISIC_0033123.jpg
#   inflating: /content/ham10000Dataset/train/vasc/ISIC_0033762.jpg
#   inflating: /content/ham10000Dataset/train/vasc/ISIC_0024669.jpg
#   inflating: /content/ham10000Dataset/train/vasc/ISIC_0029608.jpg
#   inflating: /content/ham10000Dataset/train/vasc/ISIC_0025599.jpg
#   inflating: /content/ham10000Dataset/train/vasc/ISIC_0030104.jpg
#   inflating: /content/ham10000Dataset/train/vasc/ISIC_0032240.jpg
#   inflating: /content/ham10000Dataset/train/vasc/ISIC_0029404.jpg
#   inflating: /content/ham10000Dataset/train/vasc/ISIC_0030606.jpg
#   inflating: /content/ham10000Dataset/train/vasc/ISIC_0026490.jpg
#   inflating: /content/ham10000Dataset/train/vasc/ISIC_0025250.jpg
#   inflating: /content/ham10000Dataset/train/vasc/ISIC_0030275.jpg
#   inflating: /content/ham10000Dataset/train/vasc/ISIC_0028885.jpg
#   inflating: /content/ham10000Dataset/train/vasc/ISIC_0028431.jpg
#   inflating: /content/ham10000Dataset/train/vasc/ISIC_0032076.jpg
#   inflating: /content/ham10000Dataset/train/vasc/ISIC_0031276.jpg
#   inflating: /content/ham10000Dataset/train/vasc/ISIC_0033031.jpg
#   inflating: /content/ham10000Dataset/train/vasc/ISIC_0032775.jpg
#   inflating: /content/ham10000Dataset/train/vasc/ISIC_0033254.jpg
#   inflating: /content/ham10000Dataset/train/vasc/ISIC_0032614.jpg
#   inflating: /content/ham10000Dataset/train/vasc/ISIC_0025244.jpg
#   inflating: /content/ham10000Dataset/train/vasc/ISIC_0033135.jpg
#   inflating: /content/ham10000Dataset/train/vasc/ISIC_0032057.jpg
#   inflating: /content/ham10000Dataset/train/vasc/ISIC_0026876.jpg
#   inflating: /content/ham10000Dataset/train/vasc/ISIC_0025707.jpg
#   inflating: /content/ham10000Dataset/train/vasc/ISIC_0033349.jpg
#   inflating: /content/ham10000Dataset/train/vasc/ISIC_0029439.jpg
#   inflating: /content/ham10000Dataset/train/vasc/ISIC_0025452.jpg
#   inflating: /content/ham10000Dataset/train/vasc/ISIC_0033969.jpg
#   inflating: /content/ham10000Dataset/train/vasc/ISIC_0033450.jpg
#   inflating: /content/ham10000Dataset/train/vasc/ISIC_0032692.jpg
#   inflating: /content/ham10000Dataset/train/vasc/ISIC_0026349.jpg
#   inflating: /content/ham10000Dataset/train/vasc/ISIC_0031955.jpg
#   inflating: /content/ham10000Dataset/train/vasc/ISIC_0027269.jpg
#   inflating: /content/ham10000Dataset/train/vasc/ISIC_0026336.jpg
#   inflating: /content/ham10000Dataset/train/vasc/ISIC_0033230.jpg
#   inflating: /content/ham10000Dataset/train/vasc/ISIC_0027672.jpg
#   inflating: /content/ham10000Dataset/train/vasc/ISIC_0027665.jpg
#   inflating: /content/ham10000Dataset/train/vasc/ISIC_0031759.jpg
#   inflating: /content/ham10000Dataset/train/vasc/ISIC_0031950.jpg
#   inflating: /content/ham10000Dataset/train/vasc/ISIC_0024662.jpg
#   inflating: /content/ham10000Dataset/train/vasc/ISIC_0027790.jpg
#   inflating: /content/ham10000Dataset/train/vasc/ISIC_0027903.jpg
#   inflating: /content/ham10000Dataset/train/vasc/ISIC_0031217.jpg
#   inflating: /content/ham10000Dataset/train/vasc/ISIC_0031270.jpg
#   inflating: /content/ham10000Dataset/train/vasc/ISIC_0029099.jpg
#   inflating: /content/ham10000Dataset/train/vasc/ISIC_0026092.jpg
#   inflating: /content/ham10000Dataset/train/vasc/ISIC_0026068.jpg
#   inflating: /content/ham10000Dataset/train/vasc/ISIC_0024375.jpg
#   inflating: /content/ham10000Dataset/train/vasc/ISIC_0025425.jpg
#   inflating: /content/ham10000Dataset/train/vasc/ISIC_0025606.jpg
#   inflating: /content/ham10000Dataset/train/vasc/ISIC_0024370.jpg
#   inflating: /content/ham10000Dataset/train/vasc/ISIC_0028146.jpg
#   inflating: /content/ham10000Dataset/train/vasc/ISIC_0031197.jpg
#   inflating: /content/ham10000Dataset/train/vasc/ISIC_0032919.jpg
#   inflating: /content/ham10000Dataset/train/vasc/ISIC_0027210.jpg
#   inflating: /content/ham10000Dataset/train/vasc/ISIC_0033749.jpg
#   inflating: /content/ham10000Dataset/train/vasc/ISIC_0034214.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0026596.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0030795.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0024929.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0033440.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0032569.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0033678.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0027552.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0025941.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0026120.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0033872.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0033426.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0028003.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0033114.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0027144.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0028127.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0033595.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0033047.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0032592.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0027507.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0024733.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0027282.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0030211.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0027163.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0030798.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0033302.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0032687.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0033320.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0024496.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0033670.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0031386.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0033299.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0024537.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0033624.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0026604.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0033473.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0030360.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0029316.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0024940.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0034205.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0027904.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0025512.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0026113.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0032450.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0025265.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0025783.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0034100.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0032408.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0024729.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0026746.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0032662.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0028519.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0032511.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0032844.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0029480.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0032389.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0030031.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0031310.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0028565.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0026811.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0032921.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0032684.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0033607.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0032723.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0027616.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0030759.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0026976.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0032214.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0033174.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0025085.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0034074.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0028860.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0032265.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0025724.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0030183.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0028481.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0024516.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0030356.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0029495.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0025744.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0028352.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0027420.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0028228.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0030187.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0027277.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0033394.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0030014.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0027669.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0029606.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0025987.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0029819.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0027126.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0033874.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0029265.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0033120.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0033452.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0027352.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0028418.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0028306.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0033902.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0032699.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0029726.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0033654.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0034087.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0028582.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0032531.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0028929.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0032833.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0030238.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0032955.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0032602.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0034022.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0024732.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0024679.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0028075.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0027067.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0034202.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0033848.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0033834.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0026258.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0029538.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0026268.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0033024.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0032736.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0034117.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0029558.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0032970.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0033856.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0033081.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0033037.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0030324.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0027238.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0032981.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0033424.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0025188.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0033700.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0028898.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0024315.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0032790.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0033805.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0033272.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0033573.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0030255.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0032968.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0027620.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0024367.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0031479.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0029995.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0034170.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0030970.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0032927.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0032847.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0032982.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0033171.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0033812.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0024823.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0024767.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0030521.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0032653.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0033129.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0026150.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0031177.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0029370.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0027402.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0033977.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0024310.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0026664.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0029092.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0026558.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0033801.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0030564.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0030898.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0028760.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0026647.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0028109.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0032019.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0024700.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0032044.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0033089.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0033570.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0029642.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0033325.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0032535.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0034052.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0026247.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0031941.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0032430.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0024911.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0034118.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0026314.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0032190.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0024962.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0025489.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0033304.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0026506.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0027776.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0031844.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0033261.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0028965.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0029512.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0028543.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0033061.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0028410.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0032537.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0033166.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0025234.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0033885.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0029513.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0032603.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0034034.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0029000.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0033643.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0032017.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0028288.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0024647.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0024702.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0033245.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0033754.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0034236.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0026094.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0033820.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0027872.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0027964.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0028968.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0028508.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0033496.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0033267.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0026652.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0033843.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0032433.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0029914.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0033562.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0024967.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0031977.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0031972.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0025524.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0025313.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0027517.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0030110.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0032698.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0027622.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0026489.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0025153.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0030366.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0033055.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0024853.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0033125.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0033415.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0030929.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0034036.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0031368.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0027130.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0034222.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0029571.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0028215.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0034062.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0025472.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0028087.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0026690.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0034216.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0034287.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0028900.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0028219.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0032915.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0033416.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0031795.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0034006.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0033807.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0029013.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0027387.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0033362.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0030165.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0028493.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0029562.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0027604.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0027328.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0031711.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0033103.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0033206.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0026897.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0033779.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0031034.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0026105.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0028915.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0031087.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0034050.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0026738.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0025414.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0029884.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0030486.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0025195.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0024482.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0033947.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0032204.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0028460.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0027065.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0033518.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0026500.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0031408.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0026697.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0024552.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0033238.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0029172.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0032220.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0029363.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0033819.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0031670.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0031494.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0033074.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0033863.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0032925.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0028317.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0031746.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0027742.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0027190.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0027442.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0033630.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0026847.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0030440.jpg
#   inflating: /content/ham10000Dataset/train/mel/ISIC_0032245.jpg
# ...
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0025210.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0027377.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0025372.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0032832.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0024873.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0032202.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0024538.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0028700.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0031482.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0026180.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0029592.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0025796.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0032131.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0029169.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0029440.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0031120.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0026711.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0032075.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0028115.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0030495.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0025078.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0026137.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0026936.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0029511.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0026283.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0027542.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0028487.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0027674.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0025057.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0030551.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0033495.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0032041.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0026924.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0031879.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0032407.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0031328.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0025816.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0032753.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0027045.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0029110.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0024722.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0027799.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0030167.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0028811.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0030024.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0026665.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0034217.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0030438.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0031341.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0029993.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0034308.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0030179.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0025571.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0033940.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0028697.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0025090.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0030345.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0029442.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0027292.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0034220.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0024725.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0031306.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0025979.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0032705.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0031839.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0031414.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0026708.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0029994.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0030200.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0031785.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0026312.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0027661.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0032954.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0027687.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0026414.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0030505.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0027003.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0026285.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0031605.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0028944.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0028999.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0027411.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0028829.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0031213.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0033800.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0025974.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0031440.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0030068.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0026933.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0030193.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0027961.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0031582.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0027516.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0029038.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0031320.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0026979.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0027944.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0028706.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0027066.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0025673.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0029164.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0032942.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0031176.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0034192.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0024975.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0026093.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0025498.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0027510.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0027714.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0027644.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0030097.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0030958.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0028101.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0029497.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0028102.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0025447.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0030449.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0028130.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0032337.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0025522.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0029098.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0031067.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0033384.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0026758.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0032621.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0026550.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0030527.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0026863.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0028440.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0027153.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0029109.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0025555.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0033904.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0029411.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0033326.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0029142.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0028535.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0031297.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0030156.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0026184.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0026911.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0024441.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0033557.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0030127.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0026801.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0029287.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0028732.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0024600.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0028630.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0024818.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0029334.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0031425.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0026772.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0033989.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0028635.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0024821.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0026431.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0032228.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0027942.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0033194.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0032224.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0024854.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0025759.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0029090.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0027782.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0033694.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0033948.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0025956.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0029560.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0032052.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0032137.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0027443.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0027621.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0028461.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0025412.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0031612.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0031572.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0026385.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0027211.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0032020.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0031397.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0028740.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0032412.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0024920.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0029821.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0028761.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0024750.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0025284.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0027968.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0026633.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0025730.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0031509.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0030049.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0031899.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0024631.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0024421.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0033598.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0030484.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0030692.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0031227.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0029797.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0027200.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0033355.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0026401.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0027635.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0034226.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0033296.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0030132.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0026031.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0025460.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0027720.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0030968.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0032309.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0033425.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0030593.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0032212.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0032717.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0031315.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0030022.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0030762.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0032066.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0030239.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0028601.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0028896.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0030048.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0033917.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0027524.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0029529.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0027924.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0030724.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0026551.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0032125.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0028541.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0032328.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0024905.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0026338.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0026585.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0032784.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0030061.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0026910.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0024406.jpg
#   inflating: /content/ham10000Dataset/train/nv/ISIC_0030336.jpg

# %%
DATASET_DIR = "/content/ham10000Dataset"

# %% [markdown]
# ## **Section 2: Preprocessing and augmentaion images**

# %% [markdown]
# ### **Load dataset**

# %%
class MultiModelDatasetPipeline:
    def __init__(self,
                 transform=None,
                 rescale=None,
                 preprocess_input=None
                 ):
        self.transform = transform
        self.rescale = rescale
        self.preprocess_input = preprocess_input
        self.AUTOTUNE = tf.data.AUTOTUNE
        self.class_names = None

    def _transform_function(self, img_numpy):
        raw_img = {"image": img_numpy}
        transform_img = self.transform(**raw_img)
        return transform_img["image"].astype(np.float32)

    @tf.function
    def _apply_transform(self, img_tensor, img_size):
        transformed = tf.numpy_function(
            func=self._transform_function,
            inp=[img_tensor],
            Tout=tf.float32
        )
        transformed.set_shape([img_size[0], img_size[1], 3])
        return transformed

    def _load_and_resize(self, filepath, metadata, label, img_size):
        img = tf.io.read_file(filepath)
        img = tf.image.decode_jpeg(img, channels=3)
        img = tf.image.resize(img, img_size)
        return img, metadata, label

    def _finalize_data(self, img, metadata, label,
                    num_classes, img_size, meta_shape=17,
                    is_training=False, class_mode="categorical"):

        if is_training and self.transform:
            img = self._apply_transform(img, img_size)

        if self.preprocess_input:
            img = self.preprocess_input(img)
        elif self.rescale:
            img = img * self.rescale

        label = tf.cast(label, tf.int32)
        if class_mode == "categorical":
            label = tf.one_hot(label, num_classes)
        elif class_mode != "sparse":
            raise ValueError(f"Unknown class_mode: {class_mode}")

        if metadata is None:
            return img, label

        metadata = tf.cast(metadata, tf.float32)
        return ((img, metadata), label)

    def flow_from_dataframe(
            self,
            df,
            X_cols,
            X_meta=None,
            y_cols=None,
            num_classes=None,
            class_name_col=None,
            target_size=(224, 224),
            batch_size=32,
            is_training=False,
            seed=42,
            class_mode="categorical"
            ):

        num_files = len(df)

        if is_training and class_name_col and self.class_names is None:
            try:
                mapping_df = df[[y_cols, class_name_col]].drop_duplicates().sort_values(by=y_cols)
                self.class_names = mapping_df[class_name_col].tolist()
                if len(self.class_names) != num_classes:
                     print(f"Warning: Found {len(self.class_names)} unique names, but num_classes={num_classes}.")
            except Exception as e:
                print(f"Could not build class name list from '{class_name_col}': {e}. Defaulting to numeric names.")
                self.class_names = [str(i) for i in range(num_classes)]
        elif self.class_names is None:
             self.class_names = [str(i) for i in range(num_classes)]

        class_indices = dict(enumerate(self.class_names))
        print(f"Found {num_files} files belonging to {num_classes} classes.")
        print(f"Class indices: {class_indices}")

        if X_meta is None:
            X_meta_data = [None] * len(df)
        else:
            X_meta_data = X_meta

        dataset = tf.data.Dataset.from_tensor_slices(
            (df[X_cols].values, X_meta_data, df[y_cols].values)
        )

        dataset = dataset.map(
            lambda f, m, l: self._load_and_resize(f, m, l, target_size),
            num_parallel_calls=self.AUTOTUNE
        )
        dataset = dataset.cache()

        map_func = lambda img, m, l: self._finalize_data(
            img, m, l, num_classes, target_size,
            meta_shape=17,
            is_training=is_training,
            class_mode=class_mode
        )

        if is_training:
            dataset = dataset.shuffle(buffer_size=len(df), seed=seed, reshuffle_each_iteration=True)

        dataset = (
            dataset
            .map(map_func, num_parallel_calls=self.AUTOTUNE)
            .batch(batch_size)
            .prefetch(buffer_size=self.AUTOTUNE)
        )
        return dataset

# %%
df_train = pd.read_csv(f"{INDEX_SETTING}/metadata_train.csv")
df_val = pd.read_csv(f"{INDEX_SETTING}/metadata_val.csv")
df_test = pd.read_csv(f"{INDEX_SETTING}/metadata_test.csv")

# %%
def select_preprocess_input(model_name):
    if model_name == "ResNet50":
        preprocess_input = keras.applications.resnet50.preprocess_input
    elif model_name == "MobileNetV3Large" or model_name == "MobileNetV3Small":
        preprocess_input = keras.applications.mobilenet_v3.preprocess_input
    elif model_name == "Xception":
        preprocess_input = keras.applications.xception.preprocess_input
    else:
        preprocess_input = None
    return preprocess_input

# %%
preprocess_input = select_preprocess_input("MobileNetV3Large")
IMAGE_HEIGHT = 224
IMAGE_WIDTH = 224
IMAGE_SIZE = (IMAGE_HEIGHT, IMAGE_WIDTH)
INPUT_SHAPE = IMAGE_SIZE + (3, )
BATCH_SIZE = 64
EPOCHS = 30

# %%
class_names = ["akiec", "bcc", "bkl", "df", "mel", "nv", "vasc"]
idx_to_class = {idx: name for idx, name in enumerate(class_names)}
NUM_CLASSES = len(class_names)
print(f"Index to class: {idx_to_class}")
print(f"Number of classes: {NUM_CLASSES}")
# Out:
# Index to class: {0: 'akiec', 1: 'bcc', 2: 'bkl', 3: 'df', 4: 'mel', 5: 'nv', 6: 'vasc'}
# Number of classes: 7

# %%
pipeline = MultiModelDatasetPipeline(
    transform=None,
    rescale=None,
    preprocess_input=preprocess_input
)

# %%
ds_train = pipeline.flow_from_dataframe(
    df=df_train,
    X_cols="filepaths",
    X_meta=None,
    y_cols="cell_type_idx",
    num_classes=NUM_CLASSES,
    class_name_col="dx",
    is_training=True,
    batch_size=BATCH_SIZE,
    seed=SEED
)

ds_val = pipeline.flow_from_dataframe(
    df=df_val,
    X_cols="filepaths",
    X_meta=None,
    y_cols="cell_type_idx",
    num_classes=NUM_CLASSES,
    class_name_col="dx",
    is_training=False,
    batch_size=BATCH_SIZE
)

ds_test = pipeline.flow_from_dataframe(
    df=df_test,
    X_cols="filepaths",
    X_meta=None,
    y_cols="cell_type_idx",
    num_classes=NUM_CLASSES,
    class_name_col="dx",
    is_training=False,
    batch_size=BATCH_SIZE
)
# Out:
# Found 5836 files belonging to 7 classes.
# Class indices: {0: 'akiec', 1: 'bcc', 2: 'bkl', 3: 'df', 4: 'mel', 5: 'nv', 6: 'vasc'}
# Found 1979 files belonging to 7 classes.
# Class indices: {0: 'akiec', 1: 'bcc', 2: 'bkl', 3: 'df', 4: 'mel', 5: 'nv', 6: 'vasc'}
# Found 1956 files belonging to 7 classes.
# Class indices: {0: 'akiec', 1: 'bcc', 2: 'bkl', 3: 'df', 4: 'mel', 5: 'nv', 6: 'vasc'}

# %% [markdown]
# ## **Section 3: Preparing the model**

# %% [markdown]
# ### **Define callback function**

# %%
reduce_lr = keras.callbacks.ReduceLROnPlateau(
    monitor="val_accuracy",
    factor=0.1,
    patience=5,
    mode="max",
    min_lr=1e-08,
    verbose=1
) # Reduce learning rate callback

model_checkpoint = keras.callbacks.ModelCheckpoint(
    filepath=MODEL_CHECKPOINT_PATH,
    monitor="val_accuracy",
    mode="max",
    save_best_only=True,
    save_weights_only=False,
    verbose=1
) # Model checkpoint for save best model file

tensorboard = keras.callbacks.TensorBoard(
    log_dir=MODEL_TENSORBOARD_PATH,
    histogram_freq=1,
    write_graph=True,
    write_images=True
) # Tensorboard file

callback_list = [reduce_lr, model_checkpoint, tensorboard]

# %% [markdown]
# ### **Model parameters**

# %%
def build_model(input_shape, num_classes, trainable=False):
    image_input = keras.layers.Input(shape=input_shape, name="image_input")

    base_model = keras.applications.MobileNetV3Large(
        input_tensor=image_input,
        include_top=False,
        weights="imagenet"
    )
    for layer in base_model.layers:
        layer.trainable = trainable

    # ===== Head =====
    image_features = keras.layers.GlobalAveragePooling2D(name="avg_pool")(base_model.output)
    image_features = keras.layers.BatchNormalization(name="norm")(image_features)
    image_features = keras.layers.Dense(256, activation="relu", name="img_fc1")(image_features)
    image_features = keras.layers.Dropout(0.3, name="img_dropout")(image_features)
    image_features = keras.layers.Dense(128, activation="relu", name="img_fc2")(image_features)
    predictions = keras.layers.Dense(num_classes, activation="softmax", name="predictions")(image_features)

    model = keras.models.Model(inputs=image_input, outputs=predictions)
    return model

# %%
model = build_model(
    input_shape=INPUT_SHAPE,
    num_classes=NUM_CLASSES,
    trainable=True
)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet_v3/weights_mobilenet_v3_large_224_1.0_float_no_top_v2.h5
# 12683000/12683000 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step

# %%
model.compile(
    optimizer = keras.optimizers.AdamW(
        learning_rate=1e-04,
        weight_decay=1e-05,
        beta_1=0.9,
        beta_2=0.999,
        epsilon=1e-07,
        name="Adam"
    ),
    loss = keras.losses.CategoricalCrossentropy(name="loss"),
    metrics = [
        keras.metrics.CategoricalAccuracy(name="accuracy"),
        keras.metrics.Recall(name="recall"),
        keras.metrics.Precision(name="precision")
        ]
)

model.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ image_input         │ (None, 224, 224,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ rescaling           │ (None, 224, 224,  │          0 │ image_input[0][0] │
# │ (Rescaling)         │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv (Conv2D)       │ (None, 112, 112,  │        432 │ rescaling[0][0]   │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv_bn             │ (None, 112, 112,  │         64 │ conv[0][0]        │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation          │ (None, 112, 112,  │          0 │ conv_bn[0][0]     │
# │ (Activation)        │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_dept… │ (None, 112, 112,  │        144 │ activation[0][0]  │
# │ (DepthwiseConv2D)   │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_dept… │ (None, 112, 112,  │         64 │ expanded_conv_de… │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu (ReLU)        │ (None, 112, 112,  │          0 │ expanded_conv_de… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_proj… │ (None, 112, 112,  │        256 │ re_lu[0][0]       │
# │ (Conv2D)            │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_proj… │ (None, 112, 112,  │         64 │ expanded_conv_pr… │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_add   │ (None, 112, 112,  │          0 │ activation[0][0], │
# │ (Add)               │ 16)               │            │ expanded_conv_pr… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_1_ex… │ (None, 112, 112,  │      1,024 │ expanded_conv_ad… │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_1_ex… │ (None, 112, 112,  │        256 │ expanded_conv_1_… │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_1 (ReLU)      │ (None, 112, 112,  │          0 │ expanded_conv_1_… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_1_de… │ (None, 113, 113,  │          0 │ re_lu_1[0][0]     │
# │ (ZeroPadding2D)     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_1_de… │ (None, 56, 56,    │        576 │ expanded_conv_1_… │
# │ (DepthwiseConv2D)   │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_1_de… │ (None, 56, 56,    │        256 │ expanded_conv_1_… │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_2 (ReLU)      │ (None, 56, 56,    │          0 │ expanded_conv_1_… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_1_pr… │ (None, 56, 56,    │      1,536 │ re_lu_2[0][0]     │
# │ (Conv2D)            │ 24)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_1_pr… │ (None, 56, 56,    │         96 │ expanded_conv_1_… │
# │ (BatchNormalizatio… │ 24)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_2_ex… │ (None, 56, 56,    │      1,728 │ expanded_conv_1_… │
# │ (Conv2D)            │ 72)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_2_ex… │ (None, 56, 56,    │        288 │ expanded_conv_2_… │
# │ (BatchNormalizatio… │ 72)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_3 (ReLU)      │ (None, 56, 56,    │          0 │ expanded_conv_2_… │
# │                     │ 72)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_2_de… │ (None, 56, 56,    │        648 │ re_lu_3[0][0]     │
# │ (DepthwiseConv2D)   │ 72)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_2_de… │ (None, 56, 56,    │        288 │ expanded_conv_2_… │
# │ (BatchNormalizatio… │ 72)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_4 (ReLU)      │ (None, 56, 56,    │          0 │ expanded_conv_2_… │
# │                     │ 72)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_2_pr… │ (None, 56, 56,    │      1,728 │ re_lu_4[0][0]     │
# │ (Conv2D)            │ 24)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_2_pr… │ (None, 56, 56,    │         96 │ expanded_conv_2_… │
# │ (BatchNormalizatio… │ 24)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_2_add │ (None, 56, 56,    │          0 │ expanded_conv_1_… │
# │ (Add)               │ 24)               │            │ expanded_conv_2_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_3_ex… │ (None, 56, 56,    │      1,728 │ expanded_conv_2_… │
# │ (Conv2D)            │ 72)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_3_ex… │ (None, 56, 56,    │        288 │ expanded_conv_3_… │
# │ (BatchNormalizatio… │ 72)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_5 (ReLU)      │ (None, 56, 56,    │          0 │ expanded_conv_3_… │
# │                     │ 72)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_3_de… │ (None, 59, 59,    │          0 │ re_lu_5[0][0]     │
# │ (ZeroPadding2D)     │ 72)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_3_de… │ (None, 28, 28,    │      1,800 │ expanded_conv_3_… │
# │ (DepthwiseConv2D)   │ 72)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_3_de… │ (None, 28, 28,    │        288 │ expanded_conv_3_… │
# │ (BatchNormalizatio… │ 72)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_6 (ReLU)      │ (None, 28, 28,    │          0 │ expanded_conv_3_… │
# │                     │ 72)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_3_sq… │ (None, 1, 1, 72)  │          0 │ re_lu_6[0][0]     │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_3_sq… │ (None, 1, 1, 24)  │      1,752 │ expanded_conv_3_… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_3_sq… │ (None, 1, 1, 24)  │          0 │ expanded_conv_3_… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_3_sq… │ (None, 1, 1, 72)  │      1,800 │ expanded_conv_3_… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add (Add)           │ (None, 1, 1, 72)  │          0 │ expanded_conv_3_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_7 (ReLU)      │ (None, 1, 1, 72)  │          0 │ add[0][0]         │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multiply (Multiply) │ (None, 1, 1, 72)  │          0 │ re_lu_7[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_3_sq… │ (None, 28, 28,    │          0 │ re_lu_6[0][0],    │
# │ (Multiply)          │ 72)               │            │ multiply[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_3_pr… │ (None, 28, 28,    │      2,880 │ expanded_conv_3_… │
# │ (Conv2D)            │ 40)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_3_pr… │ (None, 28, 28,    │        160 │ expanded_conv_3_… │
# │ (BatchNormalizatio… │ 40)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_4_ex… │ (None, 28, 28,    │      4,800 │ expanded_conv_3_… │
# │ (Conv2D)            │ 120)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_4_ex… │ (None, 28, 28,    │        480 │ expanded_conv_4_… │
# │ (BatchNormalizatio… │ 120)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_8 (ReLU)      │ (None, 28, 28,    │          0 │ expanded_conv_4_… │
# │                     │ 120)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_4_de… │ (None, 28, 28,    │      3,000 │ re_lu_8[0][0]     │
# │ (DepthwiseConv2D)   │ 120)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_4_de… │ (None, 28, 28,    │        480 │ expanded_conv_4_… │
# │ (BatchNormalizatio… │ 120)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_9 (ReLU)      │ (None, 28, 28,    │          0 │ expanded_conv_4_… │
# │                     │ 120)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_4_sq… │ (None, 1, 1, 120) │          0 │ re_lu_9[0][0]     │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_4_sq… │ (None, 1, 1, 32)  │      3,872 │ expanded_conv_4_… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_4_sq… │ (None, 1, 1, 32)  │          0 │ expanded_conv_4_… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_4_sq… │ (None, 1, 1, 120) │      3,960 │ expanded_conv_4_… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_1 (Add)         │ (None, 1, 1, 120) │          0 │ expanded_conv_4_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_10 (ReLU)     │ (None, 1, 1, 120) │          0 │ add_1[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multiply_1          │ (None, 1, 1, 120) │          0 │ re_lu_10[0][0]    │
# │ (Multiply)          │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_4_sq… │ (None, 28, 28,    │          0 │ re_lu_9[0][0],    │
# │ (Multiply)          │ 120)              │            │ multiply_1[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_4_pr… │ (None, 28, 28,    │      4,800 │ expanded_conv_4_… │
# │ (Conv2D)            │ 40)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_4_pr… │ (None, 28, 28,    │        160 │ expanded_conv_4_… │
# │ (BatchNormalizatio… │ 40)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_4_add │ (None, 28, 28,    │          0 │ expanded_conv_3_… │
# │ (Add)               │ 40)               │            │ expanded_conv_4_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_5_ex… │ (None, 28, 28,    │      4,800 │ expanded_conv_4_… │
# │ (Conv2D)            │ 120)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_5_ex… │ (None, 28, 28,    │        480 │ expanded_conv_5_… │
# │ (BatchNormalizatio… │ 120)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_11 (ReLU)     │ (None, 28, 28,    │          0 │ expanded_conv_5_… │
# │                     │ 120)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_5_de… │ (None, 28, 28,    │      3,000 │ re_lu_11[0][0]    │
# │ (DepthwiseConv2D)   │ 120)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_5_de… │ (None, 28, 28,    │        480 │ expanded_conv_5_… │
# │ (BatchNormalizatio… │ 120)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_12 (ReLU)     │ (None, 28, 28,    │          0 │ expanded_conv_5_… │
# │                     │ 120)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_5_sq… │ (None, 1, 1, 120) │          0 │ re_lu_12[0][0]    │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_5_sq… │ (None, 1, 1, 32)  │      3,872 │ expanded_conv_5_… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_5_sq… │ (None, 1, 1, 32)  │          0 │ expanded_conv_5_… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_5_sq… │ (None, 1, 1, 120) │      3,960 │ expanded_conv_5_… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_2 (Add)         │ (None, 1, 1, 120) │          0 │ expanded_conv_5_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_13 (ReLU)     │ (None, 1, 1, 120) │          0 │ add_2[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multiply_2          │ (None, 1, 1, 120) │          0 │ re_lu_13[0][0]    │
# │ (Multiply)          │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_5_sq… │ (None, 28, 28,    │          0 │ re_lu_12[0][0],   │
# │ (Multiply)          │ 120)              │            │ multiply_2[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_5_pr… │ (None, 28, 28,    │      4,800 │ expanded_conv_5_… │
# │ (Conv2D)            │ 40)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_5_pr… │ (None, 28, 28,    │        160 │ expanded_conv_5_… │
# │ (BatchNormalizatio… │ 40)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_5_add │ (None, 28, 28,    │          0 │ expanded_conv_4_… │
# │ (Add)               │ 40)               │            │ expanded_conv_5_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_6_ex… │ (None, 28, 28,    │      9,600 │ expanded_conv_5_… │
# │ (Conv2D)            │ 240)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_6_ex… │ (None, 28, 28,    │        960 │ expanded_conv_6_… │
# │ (BatchNormalizatio… │ 240)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_1        │ (None, 28, 28,    │          0 │ expanded_conv_6_… │
# │ (Activation)        │ 240)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_6_de… │ (None, 29, 29,    │          0 │ activation_1[0][… │
# │ (ZeroPadding2D)     │ 240)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_6_de… │ (None, 14, 14,    │      2,160 │ expanded_conv_6_… │
# │ (DepthwiseConv2D)   │ 240)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_6_de… │ (None, 14, 14,    │        960 │ expanded_conv_6_… │
# │ (BatchNormalizatio… │ 240)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_2        │ (None, 14, 14,    │          0 │ expanded_conv_6_… │
# │ (Activation)        │ 240)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_6_pr… │ (None, 14, 14,    │     19,200 │ activation_2[0][… │
# │ (Conv2D)            │ 80)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_6_pr… │ (None, 14, 14,    │        320 │ expanded_conv_6_… │
# │ (BatchNormalizatio… │ 80)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_7_ex… │ (None, 14, 14,    │     16,000 │ expanded_conv_6_… │
# │ (Conv2D)            │ 200)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_7_ex… │ (None, 14, 14,    │        800 │ expanded_conv_7_… │
# │ (BatchNormalizatio… │ 200)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_3        │ (None, 14, 14,    │          0 │ expanded_conv_7_… │
# │ (Activation)        │ 200)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_7_de… │ (None, 14, 14,    │      1,800 │ activation_3[0][… │
# │ (DepthwiseConv2D)   │ 200)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_7_de… │ (None, 14, 14,    │        800 │ expanded_conv_7_… │
# │ (BatchNormalizatio… │ 200)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_4        │ (None, 14, 14,    │          0 │ expanded_conv_7_… │
# │ (Activation)        │ 200)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_7_pr… │ (None, 14, 14,    │     16,000 │ activation_4[0][… │
# │ (Conv2D)            │ 80)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_7_pr… │ (None, 14, 14,    │        320 │ expanded_conv_7_… │
# │ (BatchNormalizatio… │ 80)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_7_add │ (None, 14, 14,    │          0 │ expanded_conv_6_… │
# │ (Add)               │ 80)               │            │ expanded_conv_7_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_8_ex… │ (None, 14, 14,    │     14,720 │ expanded_conv_7_… │
# │ (Conv2D)            │ 184)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_8_ex… │ (None, 14, 14,    │        736 │ expanded_conv_8_… │
# │ (BatchNormalizatio… │ 184)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_5        │ (None, 14, 14,    │          0 │ expanded_conv_8_… │
# │ (Activation)        │ 184)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_8_de… │ (None, 14, 14,    │      1,656 │ activation_5[0][… │
# │ (DepthwiseConv2D)   │ 184)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_8_de… │ (None, 14, 14,    │        736 │ expanded_conv_8_… │
# │ (BatchNormalizatio… │ 184)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_6        │ (None, 14, 14,    │          0 │ expanded_conv_8_… │
# │ (Activation)        │ 184)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_8_pr… │ (None, 14, 14,    │     14,720 │ activation_6[0][… │
# │ (Conv2D)            │ 80)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_8_pr… │ (None, 14, 14,    │        320 │ expanded_conv_8_… │
# │ (BatchNormalizatio… │ 80)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_8_add │ (None, 14, 14,    │          0 │ expanded_conv_7_… │
# │ (Add)               │ 80)               │            │ expanded_conv_8_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_9_ex… │ (None, 14, 14,    │     14,720 │ expanded_conv_8_… │
# │ (Conv2D)            │ 184)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_9_ex… │ (None, 14, 14,    │        736 │ expanded_conv_9_… │
# │ (BatchNormalizatio… │ 184)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_7        │ (None, 14, 14,    │          0 │ expanded_conv_9_… │
# │ (Activation)        │ 184)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_9_de… │ (None, 14, 14,    │      1,656 │ activation_7[0][… │
# │ (DepthwiseConv2D)   │ 184)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_9_de… │ (None, 14, 14,    │        736 │ expanded_conv_9_… │
# │ (BatchNormalizatio… │ 184)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_8        │ (None, 14, 14,    │          0 │ expanded_conv_9_… │
# │ (Activation)        │ 184)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_9_pr… │ (None, 14, 14,    │     14,720 │ activation_8[0][… │
# │ (Conv2D)            │ 80)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_9_pr… │ (None, 14, 14,    │        320 │ expanded_conv_9_… │
# │ (BatchNormalizatio… │ 80)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_9_add │ (None, 14, 14,    │          0 │ expanded_conv_8_… │
# │ (Add)               │ 80)               │            │ expanded_conv_9_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_10_e… │ (None, 14, 14,    │     38,400 │ expanded_conv_9_… │
# │ (Conv2D)            │ 480)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_10_e… │ (None, 14, 14,    │      1,920 │ expanded_conv_10… │
# │ (BatchNormalizatio… │ 480)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_9        │ (None, 14, 14,    │          0 │ expanded_conv_10… │
# │ (Activation)        │ 480)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_10_d… │ (None, 14, 14,    │      4,320 │ activation_9[0][… │
# │ (DepthwiseConv2D)   │ 480)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_10_d… │ (None, 14, 14,    │      1,920 │ expanded_conv_10… │
# │ (BatchNormalizatio… │ 480)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_10       │ (None, 14, 14,    │          0 │ expanded_conv_10… │
# │ (Activation)        │ 480)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_10_s… │ (None, 1, 1, 480) │          0 │ activation_10[0]… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_10_s… │ (None, 1, 1, 120) │     57,720 │ expanded_conv_10… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_10_s… │ (None, 1, 1, 120) │          0 │ expanded_conv_10… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_10_s… │ (None, 1, 1, 480) │     58,080 │ expanded_conv_10… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_3 (Add)         │ (None, 1, 1, 480) │          0 │ expanded_conv_10… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_14 (ReLU)     │ (None, 1, 1, 480) │          0 │ add_3[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multiply_3          │ (None, 1, 1, 480) │          0 │ re_lu_14[0][0]    │
# │ (Multiply)          │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_10_s… │ (None, 14, 14,    │          0 │ activation_10[0]… │
# │ (Multiply)          │ 480)              │            │ multiply_3[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_10_p… │ (None, 14, 14,    │     53,760 │ expanded_conv_10… │
# │ (Conv2D)            │ 112)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_10_p… │ (None, 14, 14,    │        448 │ expanded_conv_10… │
# │ (BatchNormalizatio… │ 112)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_11_e… │ (None, 14, 14,    │     75,264 │ expanded_conv_10… │
# │ (Conv2D)            │ 672)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_11_e… │ (None, 14, 14,    │      2,688 │ expanded_conv_11… │
# │ (BatchNormalizatio… │ 672)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_11       │ (None, 14, 14,    │          0 │ expanded_conv_11… │
# │ (Activation)        │ 672)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_11_d… │ (None, 14, 14,    │      6,048 │ activation_11[0]… │
# │ (DepthwiseConv2D)   │ 672)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_11_d… │ (None, 14, 14,    │      2,688 │ expanded_conv_11… │
# │ (BatchNormalizatio… │ 672)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_12       │ (None, 14, 14,    │          0 │ expanded_conv_11… │
# │ (Activation)        │ 672)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_11_s… │ (None, 1, 1, 672) │          0 │ activation_12[0]… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_11_s… │ (None, 1, 1, 168) │    113,064 │ expanded_conv_11… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_11_s… │ (None, 1, 1, 168) │          0 │ expanded_conv_11… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_11_s… │ (None, 1, 1, 672) │    113,568 │ expanded_conv_11… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_4 (Add)         │ (None, 1, 1, 672) │          0 │ expanded_conv_11… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_15 (ReLU)     │ (None, 1, 1, 672) │          0 │ add_4[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multiply_4          │ (None, 1, 1, 672) │          0 │ re_lu_15[0][0]    │
# │ (Multiply)          │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_11_s… │ (None, 14, 14,    │          0 │ activation_12[0]… │
# │ (Multiply)          │ 672)              │            │ multiply_4[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_11_p… │ (None, 14, 14,    │     75,264 │ expanded_conv_11… │
# │ (Conv2D)            │ 112)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_11_p… │ (None, 14, 14,    │        448 │ expanded_conv_11… │
# │ (BatchNormalizatio… │ 112)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_11_a… │ (None, 14, 14,    │          0 │ expanded_conv_10… │
# │ (Add)               │ 112)              │            │ expanded_conv_11… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_12_e… │ (None, 14, 14,    │     75,264 │ expanded_conv_11… │
# │ (Conv2D)            │ 672)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_12_e… │ (None, 14, 14,    │      2,688 │ expanded_conv_12… │
# │ (BatchNormalizatio… │ 672)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_13       │ (None, 14, 14,    │          0 │ expanded_conv_12… │
# │ (Activation)        │ 672)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_12_d… │ (None, 17, 17,    │          0 │ activation_13[0]… │
# │ (ZeroPadding2D)     │ 672)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_12_d… │ (None, 7, 7, 672) │     16,800 │ expanded_conv_12… │
# │ (DepthwiseConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_12_d… │ (None, 7, 7, 672) │      2,688 │ expanded_conv_12… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_14       │ (None, 7, 7, 672) │          0 │ expanded_conv_12… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_12_s… │ (None, 1, 1, 672) │          0 │ activation_14[0]… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_12_s… │ (None, 1, 1, 168) │    113,064 │ expanded_conv_12… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_12_s… │ (None, 1, 1, 168) │          0 │ expanded_conv_12… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_12_s… │ (None, 1, 1, 672) │    113,568 │ expanded_conv_12… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_5 (Add)         │ (None, 1, 1, 672) │          0 │ expanded_conv_12… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_16 (ReLU)     │ (None, 1, 1, 672) │          0 │ add_5[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multiply_5          │ (None, 1, 1, 672) │          0 │ re_lu_16[0][0]    │
# │ (Multiply)          │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_12_s… │ (None, 7, 7, 672) │          0 │ activation_14[0]… │
# │ (Multiply)          │                   │            │ multiply_5[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_12_p… │ (None, 7, 7, 160) │    107,520 │ expanded_conv_12… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_12_p… │ (None, 7, 7, 160) │        640 │ expanded_conv_12… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_13_e… │ (None, 7, 7, 960) │    153,600 │ expanded_conv_12… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_13_e… │ (None, 7, 7, 960) │      3,840 │ expanded_conv_13… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_15       │ (None, 7, 7, 960) │          0 │ expanded_conv_13… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_13_d… │ (None, 7, 7, 960) │     24,000 │ activation_15[0]… │
# │ (DepthwiseConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_13_d… │ (None, 7, 7, 960) │      3,840 │ expanded_conv_13… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_16       │ (None, 7, 7, 960) │          0 │ expanded_conv_13… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_13_s… │ (None, 1, 1, 960) │          0 │ activation_16[0]… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_13_s… │ (None, 1, 1, 240) │    230,640 │ expanded_conv_13… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_13_s… │ (None, 1, 1, 240) │          0 │ expanded_conv_13… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_13_s… │ (None, 1, 1, 960) │    231,360 │ expanded_conv_13… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_6 (Add)         │ (None, 1, 1, 960) │          0 │ expanded_conv_13… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_17 (ReLU)     │ (None, 1, 1, 960) │          0 │ add_6[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multiply_6          │ (None, 1, 1, 960) │          0 │ re_lu_17[0][0]    │
# │ (Multiply)          │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_13_s… │ (None, 7, 7, 960) │          0 │ activation_16[0]… │
# │ (Multiply)          │                   │            │ multiply_6[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_13_p… │ (None, 7, 7, 160) │    153,600 │ expanded_conv_13… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_13_p… │ (None, 7, 7, 160) │        640 │ expanded_conv_13… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_13_a… │ (None, 7, 7, 160) │          0 │ expanded_conv_12… │
# │ (Add)               │                   │            │ expanded_conv_13… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_14_e… │ (None, 7, 7, 960) │    153,600 │ expanded_conv_13… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_14_e… │ (None, 7, 7, 960) │      3,840 │ expanded_conv_14… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_17       │ (None, 7, 7, 960) │          0 │ expanded_conv_14… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_14_d… │ (None, 7, 7, 960) │     24,000 │ activation_17[0]… │
# │ (DepthwiseConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_14_d… │ (None, 7, 7, 960) │      3,840 │ expanded_conv_14… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_18       │ (None, 7, 7, 960) │          0 │ expanded_conv_14… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_14_s… │ (None, 1, 1, 960) │          0 │ activation_18[0]… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_14_s… │ (None, 1, 1, 240) │    230,640 │ expanded_conv_14… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_14_s… │ (None, 1, 1, 240) │          0 │ expanded_conv_14… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_14_s… │ (None, 1, 1, 960) │    231,360 │ expanded_conv_14… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_7 (Add)         │ (None, 1, 1, 960) │          0 │ expanded_conv_14… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_18 (ReLU)     │ (None, 1, 1, 960) │          0 │ add_7[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multiply_7          │ (None, 1, 1, 960) │          0 │ re_lu_18[0][0]    │
# │ (Multiply)          │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_14_s… │ (None, 7, 7, 960) │          0 │ activation_18[0]… │
# │ (Multiply)          │                   │            │ multiply_7[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_14_p… │ (None, 7, 7, 160) │    153,600 │ expanded_conv_14… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_14_p… │ (None, 7, 7, 160) │        640 │ expanded_conv_14… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ expanded_conv_14_a… │ (None, 7, 7, 160) │          0 │ expanded_conv_13… │
# │ (Add)               │                   │            │ expanded_conv_14… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv_1 (Conv2D)     │ (None, 7, 7, 960) │    153,600 │ expanded_conv_14… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv_1_bn           │ (None, 7, 7, 960) │      3,840 │ conv_1[0][0]      │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_19       │ (None, 7, 7, 960) │          0 │ conv_1_bn[0][0]   │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ avg_pool            │ (None, 960)       │          0 │ activation_19[0]… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ norm                │ (None, 960)       │      3,840 │ avg_pool[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ img_fc1 (Dense)     │ (None, 256)       │    246,016 │ norm[0][0]        │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ img_dropout         │ (None, 256)       │          0 │ img_fc1[0][0]     │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ img_fc2 (Dense)     │ (None, 128)       │     32,896 │ img_dropout[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ predictions (Dense) │ (None, 7)         │        903 │ img_fc2[0][0]     │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 3,280,007 (12.51 MB)
#  Trainable params: 3,253,687 (12.41 MB)
#  Non-trainable params: 26,320 (102.81 KB)

# %% [markdown]
# ## **Section 4: Training the model**

# %%
training_start = time.time()

history = model.fit(
    ds_train,
    validation_data=ds_val,
    epochs=EPOCHS,
    callbacks=callback_list,
    verbose=1
)

training_end = time.time()
training_time = training_end - training_start
print(f"\n Training completed in {training_time:.4f} seconds")
# Out:
# Epoch 1/30
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 261ms/step - accuracy: 0.4290 - loss: 1.6081 - precision: 0.6338 - recall: 0.2642
# Epoch 1: val_accuracy improved from -inf to 0.66599, saving model to /content/drive/MyDrive/CP461/mainProject/models/MobileNetV3Large Original_Fine Tuned_Adam_1/MobileNetV3Large Original_best.keras
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 70s 351ms/step - accuracy: 0.4308 - loss: 1.6037 - precision: 0.6355 - recall: 0.2662 - val_accuracy: 0.6660 - val_loss: 1.3225 - val_precision: 0.6750 - val_recall: 0.6549 - learning_rate: 1.0000e-04
# Epoch 2/30
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 256ms/step - accuracy: 0.7695 - loss: 0.6605 - precision: 0.8661 - recall: 0.6684
# Epoch 2: val_accuracy improved from 0.66599 to 0.66852, saving model to /content/drive/MyDrive/CP461/mainProject/models/MobileNetV3Large Original_Fine Tuned_Adam_1/MobileNetV3Large Original_best.keras
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 29s 319ms/step - accuracy: 0.7696 - loss: 0.6602 - precision: 0.8661 - recall: 0.6686 - val_accuracy: 0.6685 - val_loss: 1.6313 - val_precision: 0.6714 - val_recall: 0.6680 - learning_rate: 1.0000e-04
# Epoch 3/30
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 256ms/step - accuracy: 0.8420 - loss: 0.4675 - precision: 0.9080 - recall: 0.7797
# Epoch 3: val_accuracy did not improve from 0.66852
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 29s 311ms/step - accuracy: 0.8420 - loss: 0.4674 - precision: 0.9080 - recall: 0.7797 - val_accuracy: 0.6685 - val_loss: 2.0523 - val_precision: 0.6700 - val_recall: 0.6680 - learning_rate: 1.0000e-04
# Epoch 4/30
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 257ms/step - accuracy: 0.9011 - loss: 0.3125 - precision: 0.9392 - recall: 0.8566
# Epoch 4: val_accuracy improved from 0.66852 to 0.66953, saving model to /content/drive/MyDrive/CP461/mainProject/models/MobileNetV3Large Original_Fine Tuned_Adam_1/MobileNetV3Large Original_best.keras
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 29s 320ms/step - accuracy: 0.9011 - loss: 0.3125 - precision: 0.9391 - recall: 0.8566 - val_accuracy: 0.6695 - val_loss: 1.9645 - val_precision: 0.6723 - val_recall: 0.6685 - learning_rate: 1.0000e-04
# Epoch 5/30
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 256ms/step - accuracy: 0.9304 - loss: 0.2250 - precision: 0.9543 - recall: 0.9003
# Epoch 5: val_accuracy improved from 0.66953 to 0.67155, saving model to /content/drive/MyDrive/CP461/mainProject/models/MobileNetV3Large Original_Fine Tuned_Adam_1/MobileNetV3Large Original_best.keras
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 30s 325ms/step - accuracy: 0.9304 - loss: 0.2249 - precision: 0.9543 - recall: 0.9004 - val_accuracy: 0.6716 - val_loss: 2.1146 - val_precision: 0.6739 - val_recall: 0.6705 - learning_rate: 1.0000e-04
# Epoch 6/30
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 257ms/step - accuracy: 0.9582 - loss: 0.1476 - precision: 0.9719 - recall: 0.9385
# Epoch 6: val_accuracy improved from 0.67155 to 0.67458, saving model to /content/drive/MyDrive/CP461/mainProject/models/MobileNetV3Large Original_Fine Tuned_Adam_1/MobileNetV3Large Original_best.keras
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 29s 321ms/step - accuracy: 0.9582 - loss: 0.1475 - precision: 0.9719 - recall: 0.9386 - val_accuracy: 0.6746 - val_loss: 2.0737 - val_precision: 0.6794 - val_recall: 0.6716 - learning_rate: 1.0000e-04
# Epoch 7/30
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 257ms/step - accuracy: 0.9733 - loss: 0.1009 - precision: 0.9817 - recall: 0.9623
# Epoch 7: val_accuracy did not improve from 0.67458
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 29s 312ms/step - accuracy: 0.9733 - loss: 0.1009 - precision: 0.9817 - recall: 0.9623 - val_accuracy: 0.6731 - val_loss: 2.2595 - val_precision: 0.6775 - val_recall: 0.6721 - learning_rate: 1.0000e-04
# Epoch 8/30
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 257ms/step - accuracy: 0.9867 - loss: 0.0624 - precision: 0.9908 - recall: 0.9816
# Epoch 8: val_accuracy improved from 0.67458 to 0.67610, saving model to /content/drive/MyDrive/CP461/mainProject/models/MobileNetV3Large Original_Fine Tuned_Adam_1/MobileNetV3Large Original_best.keras
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 29s 321ms/step - accuracy: 0.9867 - loss: 0.0624 - precision: 0.9908 - recall: 0.9816 - val_accuracy: 0.6761 - val_loss: 2.2720 - val_precision: 0.6808 - val_recall: 0.6746 - learning_rate: 1.0000e-04
# Epoch 9/30
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 257ms/step - accuracy: 0.9922 - loss: 0.0390 - precision: 0.9939 - recall: 0.9902
# Epoch 9: val_accuracy improved from 0.67610 to 0.68317, saving model to /content/drive/MyDrive/CP461/mainProject/models/MobileNetV3Large Original_Fine Tuned_Adam_1/MobileNetV3Large Original_best.keras
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 29s 320ms/step - accuracy: 0.9922 - loss: 0.0391 - precision: 0.9939 - recall: 0.9902 - val_accuracy: 0.6832 - val_loss: 2.3287 - val_precision: 0.6876 - val_recall: 0.6806 - learning_rate: 1.0000e-04
# Epoch 10/30
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 257ms/step - accuracy: 0.9928 - loss: 0.0333 - precision: 0.9941 - recall: 0.9899
# Epoch 10: val_accuracy improved from 0.68317 to 0.68671, saving model to /content/drive/MyDrive/CP461/mainProject/models/MobileNetV3Large Original_Fine Tuned_Adam_1/MobileNetV3Large Original_best.keras
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 29s 321ms/step - accuracy: 0.9928 - loss: 0.0333 - precision: 0.9941 - recall: 0.9899 - val_accuracy: 0.6867 - val_loss: 2.4309 - val_precision: 0.6917 - val_recall: 0.6837 - learning_rate: 1.0000e-04
# Epoch 11/30
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 256ms/step - accuracy: 0.9951 - loss: 0.0221 - precision: 0.9958 - recall: 0.9943
# Epoch 11: val_accuracy improved from 0.68671 to 0.70237, saving model to /content/drive/MyDrive/CP461/mainProject/models/MobileNetV3Large Original_Fine Tuned_Adam_1/MobileNetV3Large Original_best.keras
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 29s 319ms/step - accuracy: 0.9950 - loss: 0.0221 - precision: 0.9958 - recall: 0.9942 - val_accuracy: 0.7024 - val_loss: 2.1609 - val_precision: 0.7047 - val_recall: 0.6958 - learning_rate: 1.0000e-04
# Epoch 12/30
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 256ms/step - accuracy: 0.9925 - loss: 0.0278 - precision: 0.9930 - recall: 0.9919
# Epoch 12: val_accuracy improved from 0.70237 to 0.71854, saving model to /content/drive/MyDrive/CP461/mainProject/models/MobileNetV3Large Original_Fine Tuned_Adam_1/MobileNetV3Large Original_best.keras
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 29s 319ms/step - accuracy: 0.9925 - loss: 0.0278 - precision: 0.9930 - recall: 0.9919 - val_accuracy: 0.7185 - val_loss: 1.8505 - val_precision: 0.7269 - val_recall: 0.7155 - learning_rate: 1.0000e-04
# Epoch 13/30
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 256ms/step - accuracy: 0.9949 - loss: 0.0216 - precision: 0.9959 - recall: 0.9932
# Epoch 13: val_accuracy improved from 0.71854 to 0.72713, saving model to /content/drive/MyDrive/CP461/mainProject/models/MobileNetV3Large Original_Fine Tuned_Adam_1/MobileNetV3Large Original_best.keras
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 29s 318ms/step - accuracy: 0.9949 - loss: 0.0216 - precision: 0.9959 - recall: 0.9932 - val_accuracy: 0.7271 - val_loss: 1.9012 - val_precision: 0.7334 - val_recall: 0.7216 - learning_rate: 1.0000e-04
# Epoch 14/30
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 256ms/step - accuracy: 0.9979 - loss: 0.0146 - precision: 0.9981 - recall: 0.9965
# Epoch 14: val_accuracy improved from 0.72713 to 0.73775, saving model to /content/drive/MyDrive/CP461/mainProject/models/MobileNetV3Large Original_Fine Tuned_Adam_1/MobileNetV3Large Original_best.keras
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 29s 319ms/step - accuracy: 0.9979 - loss: 0.0146 - precision: 0.9981 - recall: 0.9965 - val_accuracy: 0.7377 - val_loss: 1.7885 - val_precision: 0.7441 - val_recall: 0.7347 - learning_rate: 1.0000e-04
# Epoch 15/30
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 256ms/step - accuracy: 0.9987 - loss: 0.0110 - precision: 0.9987 - recall: 0.9978
# Epoch 15: val_accuracy improved from 0.73775 to 0.73977, saving model to /content/drive/MyDrive/CP461/mainProject/models/MobileNetV3Large Original_Fine Tuned_Adam_1/MobileNetV3Large Original_best.keras
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 29s 319ms/step - accuracy: 0.9987 - loss: 0.0110 - precision: 0.9987 - recall: 0.9978 - val_accuracy: 0.7398 - val_loss: 1.7205 - val_precision: 0.7445 - val_recall: 0.7362 - learning_rate: 1.0000e-04
# Epoch 16/30
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 256ms/step - accuracy: 0.9971 - loss: 0.0140 - precision: 0.9974 - recall: 0.9968
# Epoch 16: val_accuracy improved from 0.73977 to 0.74583, saving model to /content/drive/MyDrive/CP461/mainProject/models/MobileNetV3Large Original_Fine Tuned_Adam_1/MobileNetV3Large Original_best.keras
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 29s 319ms/step - accuracy: 0.9971 - loss: 0.0141 - precision: 0.9974 - recall: 0.9968 - val_accuracy: 0.7458 - val_loss: 1.6598 - val_precision: 0.7499 - val_recall: 0.7408 - learning_rate: 1.0000e-04
# Epoch 17/30
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 256ms/step - accuracy: 0.9959 - loss: 0.0166 - precision: 0.9959 - recall: 0.9948
# Epoch 17: val_accuracy improved from 0.74583 to 0.74886, saving model to /content/drive/MyDrive/CP461/mainProject/models/MobileNetV3Large Original_Fine Tuned_Adam_1/MobileNetV3Large Original_best.keras
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 29s 319ms/step - accuracy: 0.9959 - loss: 0.0166 - precision: 0.9959 - recall: 0.9948 - val_accuracy: 0.7489 - val_loss: 1.6756 - val_precision: 0.7549 - val_recall: 0.7453 - learning_rate: 1.0000e-04
# Epoch 18/30
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 255ms/step - accuracy: 0.9965 - loss: 0.0116 - precision: 0.9965 - recall: 0.9965
# Epoch 18: val_accuracy improved from 0.74886 to 0.75240, saving model to /content/drive/MyDrive/CP461/mainProject/models/MobileNetV3Large Original_Fine Tuned_Adam_1/MobileNetV3Large Original_best.keras
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 29s 318ms/step - accuracy: 0.9965 - loss: 0.0116 - precision: 0.9965 - recall: 0.9965 - val_accuracy: 0.7524 - val_loss: 1.5912 - val_precision: 0.7618 - val_recall: 0.7499 - learning_rate: 1.0000e-04
# Epoch 19/30
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 256ms/step - accuracy: 0.9948 - loss: 0.0222 - precision: 0.9951 - recall: 0.9948
# Epoch 19: val_accuracy improved from 0.75240 to 0.75644, saving model to /content/drive/MyDrive/CP461/mainProject/models/MobileNetV3Large Original_Fine Tuned_Adam_1/MobileNetV3Large Original_best.keras
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 29s 319ms/step - accuracy: 0.9948 - loss: 0.0222 - precision: 0.9951 - recall: 0.9948 - val_accuracy: 0.7564 - val_loss: 1.6006 - val_precision: 0.7624 - val_recall: 0.7554 - learning_rate: 1.0000e-04
# Epoch 20/30
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 255ms/step - accuracy: 0.9977 - loss: 0.0095 - precision: 0.9977 - recall: 0.9977
# Epoch 20: val_accuracy improved from 0.75644 to 0.76554, saving model to /content/drive/MyDrive/CP461/mainProject/models/MobileNetV3Large Original_Fine Tuned_Adam_1/MobileNetV3Large Original_best.keras
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 29s 319ms/step - accuracy: 0.9977 - loss: 0.0095 - precision: 0.9977 - recall: 0.9977 - val_accuracy: 0.7655 - val_loss: 1.5533 - val_precision: 0.7719 - val_recall: 0.7625 - learning_rate: 1.0000e-04
# Epoch 21/30
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 256ms/step - accuracy: 0.9945 - loss: 0.0186 - precision: 0.9945 - recall: 0.9942
# Epoch 21: val_accuracy did not improve from 0.76554
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 29s 310ms/step - accuracy: 0.9945 - loss: 0.0186 - precision: 0.9945 - recall: 0.9942 - val_accuracy: 0.7650 - val_loss: 1.4650 - val_precision: 0.7710 - val_recall: 0.7605 - learning_rate: 1.0000e-04
# Epoch 22/30
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 255ms/step - accuracy: 0.9968 - loss: 0.0111 - precision: 0.9970 - recall: 0.9968
# Epoch 22: val_accuracy improved from 0.76554 to 0.76857, saving model to /content/drive/MyDrive/CP461/mainProject/models/MobileNetV3Large Original_Fine Tuned_Adam_1/MobileNetV3Large Original_best.keras
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 29s 318ms/step - accuracy: 0.9968 - loss: 0.0111 - precision: 0.9970 - recall: 0.9968 - val_accuracy: 0.7686 - val_loss: 1.6589 - val_precision: 0.7730 - val_recall: 0.7655 - learning_rate: 1.0000e-04
# Epoch 23/30
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 256ms/step - accuracy: 0.9894 - loss: 0.0307 - precision: 0.9897 - recall: 0.9889
# Epoch 23: val_accuracy improved from 0.76857 to 0.77413, saving model to /content/drive/MyDrive/CP461/mainProject/models/MobileNetV3Large Original_Fine Tuned_Adam_1/MobileNetV3Large Original_best.keras
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 29s 319ms/step - accuracy: 0.9894 - loss: 0.0307 - precision: 0.9897 - recall: 0.9889 - val_accuracy: 0.7741 - val_loss: 1.5214 - val_precision: 0.7794 - val_recall: 0.7696 - learning_rate: 1.0000e-04
# Epoch 24/30
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 256ms/step - accuracy: 0.9967 - loss: 0.0106 - precision: 0.9972 - recall: 0.9964
# Epoch 24: val_accuracy improved from 0.77413 to 0.78373, saving model to /content/drive/MyDrive/CP461/mainProject/models/MobileNetV3Large Original_Fine Tuned_Adam_1/MobileNetV3Large Original_best.keras
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 29s 320ms/step - accuracy: 0.9967 - loss: 0.0106 - precision: 0.9972 - recall: 0.9964 - val_accuracy: 0.7837 - val_loss: 1.2539 - val_precision: 0.7907 - val_recall: 0.7787 - learning_rate: 1.0000e-04
# Epoch 25/30
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 256ms/step - accuracy: 0.9944 - loss: 0.0190 - precision: 0.9944 - recall: 0.9938
# Epoch 25: val_accuracy improved from 0.78373 to 0.79080, saving model to /content/drive/MyDrive/CP461/mainProject/models/MobileNetV3Large Original_Fine Tuned_Adam_1/MobileNetV3Large Original_best.keras
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 29s 319ms/step - accuracy: 0.9944 - loss: 0.0189 - precision: 0.9944 - recall: 0.9938 - val_accuracy: 0.7908 - val_loss: 1.3226 - val_precision: 0.7979 - val_recall: 0.7842 - learning_rate: 1.0000e-04
# Epoch 26/30
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 256ms/step - accuracy: 0.9974 - loss: 0.0083 - precision: 0.9974 - recall: 0.9973
# Epoch 26: val_accuracy improved from 0.79080 to 0.79636, saving model to /content/drive/MyDrive/CP461/mainProject/models/MobileNetV3Large Original_Fine Tuned_Adam_1/MobileNetV3Large Original_best.keras
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 29s 318ms/step - accuracy: 0.9974 - loss: 0.0083 - precision: 0.9974 - recall: 0.9973 - val_accuracy: 0.7964 - val_loss: 1.3575 - val_precision: 0.8017 - val_recall: 0.7928 - learning_rate: 1.0000e-04
# Epoch 27/30
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 256ms/step - accuracy: 0.9957 - loss: 0.0128 - precision: 0.9965 - recall: 0.9957
# Epoch 27: val_accuracy did not improve from 0.79636
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 28s 310ms/step - accuracy: 0.9957 - loss: 0.0128 - precision: 0.9965 - recall: 0.9957 - val_accuracy: 0.7913 - val_loss: 1.3184 - val_precision: 0.7973 - val_recall: 0.7852 - learning_rate: 1.0000e-04
# Epoch 28/30
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 255ms/step - accuracy: 0.9984 - loss: 0.0054 - precision: 0.9984 - recall: 0.9984
# Epoch 28: val_accuracy did not improve from 0.79636
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 28s 309ms/step - accuracy: 0.9984 - loss: 0.0054 - precision: 0.9984 - recall: 0.9984 - val_accuracy: 0.7847 - val_loss: 1.4092 - val_precision: 0.7880 - val_recall: 0.7812 - learning_rate: 1.0000e-04
# Epoch 29/30
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 255ms/step - accuracy: 0.9997 - loss: 0.0038 - precision: 0.9997 - recall: 0.9997
# Epoch 29: val_accuracy did not improve from 0.79636
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 29s 309ms/step - accuracy: 0.9997 - loss: 0.0038 - precision: 0.9997 - recall: 0.9997 - val_accuracy: 0.7923 - val_loss: 1.2801 - val_precision: 0.7942 - val_recall: 0.7878 - learning_rate: 1.0000e-04
# Epoch 30/30
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 0s 255ms/step - accuracy: 0.9993 - loss: 0.0024 - precision: 0.9993 - recall: 0.9993
# Epoch 30: val_accuracy did not improve from 0.79636
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 28s 309ms/step - accuracy: 0.9993 - loss: 0.0024 - precision: 0.9993 - recall: 0.9993 - val_accuracy: 0.7938 - val_loss: 1.2489 - val_precision: 0.8011 - val_recall: 0.7898 - learning_rate: 1.0000e-04
#
#  Training completed in 914.9796 seconds

# %% [markdown]
# ### **Save the model config**

# %%
# Save model history
history_df = pd.DataFrame(history.history)
history_df.to_csv(MODEL_HISTORY_PATH, index=False)
print(f"History has been saved at {MODEL_HISTORY_PATH}")
# Out:
# History has been saved at /content/drive/MyDrive/CP461/mainProject/models/MobileNetV3Large Original_Fine Tuned_Adam_1/MobileNetV3Large Original_history.csv

# %%
# Save model file and tensorboard
model.save(MODEL_KERAS_PATH) # Keras format
print(f"Model keras format has been saved to: {MODEL_KERAS_PATH}")
model.save(MODEL_H5_PATH) # h5 format
print(f"Model h5 format has been saved to: {MODEL_H5_PATH}")
#model = keras.models.load_model(MODEL_CHECKPOINT_PATH) # Load best weight model
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Model keras format has been saved to: /content/drive/MyDrive/CP461/mainProject/models/MobileNetV3Large Original_Fine Tuned_Adam_1/MobileNetV3Large Original.keras
# Model h5 format has been saved to: /content/drive/MyDrive/CP461/mainProject/models/MobileNetV3Large Original_Fine Tuned_Adam_1/MobileNetV3Large Original.h5

# %%
model = keras.models.load_model(MODEL_KERAS_PATH) # Load best weight model

# %%
converter = tf.lite.TFLiteConverter.from_keras_model(model)
converter.optimizations = [tf.lite.Optimize.DEFAULT]
tflite_model = converter.convert()

with open(MODEL_TFLITE_PATH, "wb") as f:
    f.write(tflite_model) # tflite format
    print(f"Model tflite format has been saved to: {MODEL_TFLITE_PATH}")

json_model = model.to_json() #Save as json format
with open(MODEL_JSON_PATH, "w") as json_file:
    json_file.write(json_model)
    print(f"Model json format has been saved to: {MODEL_JSON_PATH}")
# Out:
# Saved artifact at '/tmp/tmpf0w737_1'. The following endpoints are available:
#
# * Endpoint 'serve'
#   args_0 (POSITIONAL_ONLY): TensorSpec(shape=(None, 224, 224, 3), dtype=tf.float32, name='image_input')
# Output Type:
#   TensorSpec(shape=(None, 7), dtype=tf.float32, name=None)
# Captures:
#   133110702199376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133110702206864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133110702210704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133110702207632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133110702210128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133110702201488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133110702205712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133110702203408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133110702201104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133110702204944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133110702206288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133110702203792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133110702208400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133110702202640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133110702210896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133110702206672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133110702206480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133110702207824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133110702209168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133110702207440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133110702202448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133110702207248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133110702204560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133110702209552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133110702195344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133110702210512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133110702207056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133110702204368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133110702205136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133110702208976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133110702209360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133110702204176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133110702202832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133110702197456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133110702206096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133110702208208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133110702196112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133110702209744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133110702208016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133110702210320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133110702205520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133110702209936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133110702208592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133110702203600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133110702202256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133110702205904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133110702200912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133110702205328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133110702204752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133110702208784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133110702203216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133111404053520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133111404053328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133110702203984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133111404054096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133111404052752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133111404052944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133111404054864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133111404054288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133111404054672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133111404055632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133111404053136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133111404052560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133111404056208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133111404055056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133111404055824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133111404056016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133111404054480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133111404057168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133111404056592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133111404056784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133111404056976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133111404055440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133111404058128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133111404057552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133111404053712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133111404058896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133111404058320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133111404058704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133111404059664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133111404057360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133111404056400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133111404060240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133111404059088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133115161808528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133111404060432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133111404058512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133111404061200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133111404057744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133111404060816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133111404061008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133111404059856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133111404062160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133111404061584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133111404060624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133111404062928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133111404062352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133111404063312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133111404061776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133111404059472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133111404063120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133111404063888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133111404062544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133111404061392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133111404063696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133111404061968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133111404064848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133111404064272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133111404064464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133111404064656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133111404062736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133111404065808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133111404065232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133111404065424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133111404065616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133111404063504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133111404066768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133111404066192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133111404066384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133111404066576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133111404064080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133111404067728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133111404067152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133111404067344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133111404068112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133111404065040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133111404068688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133111404067536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133111404068304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133111404066000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133111404068496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133111404067920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133111404066960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133111404709456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133111404709648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133111404708880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133111404708304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133111404708112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133111404709264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133111404709072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133111404708688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133111404710608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133111404710032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133111404710224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133111404710416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133111404707920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133111404711568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133111404710992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133111404711184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133111404711376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133111404708496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133111404712528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133111404711952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133111404712144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133111404712336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133111404709840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133111404713488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133111404712912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133111404713104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133111404713296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133111404710800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133111404714448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133111404713872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133111404714064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133111404714256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133111404711760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133111404715408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133111404714832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133111404715024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133111404715216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133111404712720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133111404716368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133111404715792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133111404713680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133111404717136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133111404716560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133111404717520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133111404715984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133111404714640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133111404717328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133111404718096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133111404716752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133111404715600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133111404717904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133111404716176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133111404719056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133111404718480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133111404718672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133111404718864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133111404716944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133111404720016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133111404719440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133111404717712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133111404720784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133111404720208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133111404721168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133111404719632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133111404718288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133111404720976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133111404721744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133111404720400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133111404719248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133111404721552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133111404719824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133111404722704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133111404722128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133111404722320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133111404722512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133111404720592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133111404723664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133111404723088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133111404723280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133111404721360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133111404722896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133111404724048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133111404723856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133111403528656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133111404723472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133111404721936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133111403528464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133111403529232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133111403529424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133111403529040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133111403530384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133111403529808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133111403530000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133111403530192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133111403528272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133111403531344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133111403530768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133111403528848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133111403532112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133111403531536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133111403532496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133111403530960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133111403529616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133111403532304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133111403533072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133111403531728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133111403530576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133111403532880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133111403531152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133111403534032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133111403533456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133111403533648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133111403533840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133111403531920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133111403534992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133111403534416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133111403532688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133111403535760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133111403535184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133111403536144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133111403534608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133111403533264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133111403535952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133111403536720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133111403535376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133111403534224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133111403536528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133111403534800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133111403537680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133111403538256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133111403538448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133111403537872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133111403538064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133111403537104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133111403535568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133111403537296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133111403536912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133111403539984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133111403538832: TensorSpec(shape=(), dtype=tf.resource, name=None)
# Model tflite format has been saved to: /content/drive/MyDrive/CP461/mainProject/models/MobileNetV3Large Original_Fine Tuned_Adam_1/MobileNetV3Large Original.tflite
# Model json format has been saved to: /content/drive/MyDrive/CP461/mainProject/models/MobileNetV3Large Original_Fine Tuned_Adam_1/MobileNetV3Large Original_json.json

# %% [markdown]
# ## **Section 5: Evaluation the model**

# %%
results = model.evaluate(ds_test, return_dict=True)
# Out:
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 4s 54ms/step - accuracy: 0.6327 - loss: 2.5606 - precision: 0.6370 - recall: 0.6276

# %%
results
# Out:
# {'accuracy': 0.7990797758102417,
#  'loss': 1.3046544790267944,
#  'precision': 0.8042355179786682,
#  'recall': 0.796012282371521}

# %%
loss = results['loss']
accuracy = results['accuracy']
precision = results['precision']
recall = results['recall']

print(f"--Final Test Results--")
print(f"Loss      : {loss:.4f}")
print(f"Accuracy  : {accuracy:.4f}")
print(f"Precision : {precision:.4f}")
print(f"Recall    : {recall:.4f}")
# Out:
# --Final Test Results--
# Loss      : 1.3047
# Accuracy  : 0.7991
# Precision : 0.8042
# Recall    : 0.7960

# %%
y_pred_prob = model.predict(ds_test)

y_pred = np.argmax(y_pred_prob, axis=1)
y_pred_onehot = keras.utils.to_categorical(y_pred, num_classes=NUM_CLASSES)

y_true_batches = []
for images, labels in ds_test:
    y_true_batches.append(labels.numpy())

y_true_onehot = np.concatenate(y_true_batches, axis=0)
y_true = np.argmax(y_true_onehot, axis=1)
# Out:
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 4s 84ms/step

# %%
print(f"y_pred shape: {y_pred.shape}")
print(f"y_true shape: {y_true.shape}")
print(f"y_pred_onehot shape: {y_pred_onehot.shape}")
print(f"y_true_onehot shape: {y_true_onehot.shape}")
# Out:
# y_pred shape: (1956,)
# y_true shape: (1956,)
# y_pred_onehot shape: (1956, 7)
# y_true_onehot shape: (1956, 7)

# %% [markdown]
# ### **Top-1 and Top-5 accuracy**

# %%
# Top-1 Accuracy and Error
top_1 = keras.metrics.TopKCategoricalAccuracy(k=1)
top_1.update_state(y_true_onehot, y_pred_prob)
top_1_acc = top_1.result().numpy()
top_1_err = 1 - top_1_acc
print(f"Top-1 Accuracy: {top_1_acc:.4f}")
print(f"Top-1 Error: {top_1_err:.4f}")

# Top-5 Accuracy and Error
top_5 = keras.metrics.TopKCategoricalAccuracy(k=5)
top_5.update_state(y_true_onehot, y_pred_prob)
top_5_acc = top_5.result().numpy()
top_5_err = 1 - top_5_acc
print(f"Top-5 Accuracy: {top_5_acc:.4f}")
print(f"Top-5 Error: {top_5_err:.4f}")
# Out:
# Top-1 Accuracy: 0.7991
# Top-1 Error: 0.2009
# Top-5 Accuracy: 0.9939
# Top-5 Error: 0.0061

# %% [markdown]
# ### **Classification Report**

# %%
report = sklearn.metrics.classification_report(
    y_true,
    y_pred,
    target_names=class_names,
    digits=4,
    zero_division=0,
    output_dict=True
)
report_df = pd.DataFrame(report).transpose()
report_df.to_csv(MODEL_REPORT_PATH, index=True)
report_df
# Out:
#               precision    recall  f1-score     support
# akiec          0.547170  0.467742  0.504348    62.00000
# bcc            0.666667  0.701031  0.683417    97.00000
# bkl            0.794393  0.384615  0.518293   221.00000
# df             0.600000  0.206897  0.307692    29.00000
# mel            0.550505  0.495455  0.521531   220.00000
# nv             0.851195  0.959969  0.902315  1299.00000
# vasc           0.904762  0.678571  0.775510    28.00000
# accuracy       0.799080  0.799080  0.799080     0.79908
# macro avg      0.702099  0.556326  0.601872  1956.00000
# weighted avg   0.789212  0.799080  0.781997  1956.00000

# %% [markdown]
# ### **Training and Validation curve**

# %%
def plot_history(history, save_path=None, fontsize=16, title=None):
    """
        สำหรับ Plot training and validation curve สำหรับ accuracy และ loss
        Args:
            history: ประวัติการ Train ที่ได้จาก model.fit()
            save_path: เซฟภาพเก็บไว้ที่ไหน (optional)
            fontsize: ขนาด font default 16
            title: สำหรับชื่อรูปภาพ (optional)
    """
    history_dict = history.history
    epochs = range(1, len(history_dict["accuracy"]) + 1)

    fig = plt.figure(figsize=(12, 5))

    # --Loss--
    plt.subplot(1, 2, 1)
    plt.plot(epochs, history_dict["loss"], "b-", label="Training loss")
    plt.plot(epochs, history_dict["val_loss"], "r-", label="Validation loss")
    plt.title("Training and validation loss", fontsize=fontsize)
    plt.xlabel("Epochs", fontsize=fontsize)
    plt.ylabel("Loss", fontsize=fontsize)
    plt.legend(fontsize=fontsize-2)

    # --Accuracy--
    plt.subplot(1, 2, 2)
    plt.plot(epochs, history_dict["accuracy"], "b-", label="Training accuracy")
    plt.plot(epochs, history_dict["val_accuracy"], "r-", label="Validation accuracy")
    plt.title("Training and validation accuracy", fontsize=fontsize)
    plt.xlabel("Epochs", fontsize=fontsize)
    plt.ylabel("Accuracy", fontsize=fontsize)
    plt.legend(fontsize=fontsize-2)

    plt.tight_layout()

    if title:
        fig.text(0.5, 0.01, f"{title}", ha='center', fontsize=fontsize)

    if save_path:
        plt.savefig(f"{save_path}/train_valid_curve.png", format="png", dpi=300, bbox_inches="tight")
        plt.savefig(f"{save_path}/train_valid_curve.svg", format="svg", bbox_inches="tight")

    plt.show()

# %%
plot_history(history, save_path=ASSETS_FOR_MODEL_PATH, fontsize=14, title=f"{MODEL_NAME} {TYPE}")

# %% [markdown]
# ### **Confusion Matrix**

# %%
def plot_confusion_matrix(cm, classes, normalize=False,
                          title=None, cmap=plt.cm.Blues,
                          save_path=None, fontsize=12):

    """
        สำหรับ Plot counfusion matrix
        Args:
            cm (array): ค่า confusion matrix ที่ต้องการ plot
            classes (list): รายชื่อคลาส (label names) สำหรับแกน X และ Y
            normalize (bool, default=False): ถ้า True จะทำ normalization ให้ค่าทุกแถวรวมเป็น 1
            title (str, optional): ชื่อกราฟที่จะแสดงด้านบน
            cmap (matplotlib colormap, default=plt.cm.Blues): โทนสีของ heatmap
            save_path (str, optional): โฟลเดอร์ที่จะบันทึกภาพ (ถ้าไม่กำหนดจะไม่บันทึก)
            fontsize (int, default=12): ขนาดตัวอักษรในกราฟ
    """
    correct_predictions = np.trace(cm)
    total_samples = np.sum(cm)
    accuracy = correct_predictions / total_samples
    misclassification_rate = 1 - accuracy

    if title:
        if normalize:
            pic_title = f"{title}\nConfusion Matrix (normalized)"
        else:
            pic_title = f"{title}\nConfusion Matrix"
    else:
        if normalize:
            pic_title = "Confusion Matrix (normalized)"
        else:
            pic_title = "Confusion Matrix"

    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]

    plt.figure(figsize=(10, 7))
    plt.imshow(cm, interpolation="nearest", cmap=cmap)
    plt.title(pic_title, fontsize=fontsize, ha="center")
    plt.colorbar()

    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45, fontsize=fontsize)
    plt.yticks(tick_marks, classes, fontsize=fontsize)

    fmt = ".2f" if normalize else "d"
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 verticalalignment="center",
                 fontsize=fontsize,
                 color="white" if cm[i, j] > thresh else "black")

    plt.ylabel('True label', fontsize=fontsize)
    metrics_text = (
        f"\nAccuracy: {accuracy:.4f}  |  Misclass: {misclassification_rate:.4f}"
    )
    plt.xlabel(f"Predicted label{metrics_text}", fontsize=fontsize)
    plt.tight_layout()

    if save_path:
        if normalize:
            plt.savefig(f"{save_path}/confusion_matrix_normalized.png", format="png", dpi=300, bbox_inches="tight")
            plt.savefig(f"{save_path}/confusion_matrix_normalized.svg", format="svg", bbox_inches="tight")
        else:
            plt.savefig(f"{save_path}/confusion_matrix.png", format="png", dpi=300, bbox_inches="tight")
            plt.savefig(f"{save_path}/confusion_matrix.svg", format="svg", bbox_inches="tight")

    plt.show()

# %%
cm = sklearn.metrics.confusion_matrix(y_true, y_pred, labels=range(NUM_CLASSES))
plot_confusion_matrix(cm, class_names, title=f"{MODEL_NAME} {TYPE}", normalize=False, save_path=ASSETS_FOR_MODEL_PATH)

# %%
plot_confusion_matrix(cm, class_names, title=f"{MODEL_NAME} {TYPE}", normalize=True, save_path=ASSETS_FOR_MODEL_PATH)

# %% [markdown]
# ### **Plot AUC-ROC Curve**

# %%
def plot_multi_class_roc(y_true_onehot, y_pred_prob, class_names, title=None, save_path=None, fontsize=14):
    """
        y_true_onehot (ndarray): ค่า ground truth ในรูปแบบ one-hot encoded (ขนาด n_samples × n_classes)
        y_pred_prob (ndarray): ค่าความน่าจะเป็นที่โมเดลทำนาย (ขนาดเดียวกันกับ y_true_onehot)
        class_names (list): รายชื่อคลาสแต่ละคลาสที่ใช้แสดงในกราฟ
        title (str, optional): ชื่อกราฟ (ถ้าไม่ระบุจะใช้ชื่อเริ่มต้น “Receiver Operating Characteristic (ROC) - Multiclass”)
        save_path (str, optional): โฟลเดอร์สำหรับบันทึกภาพ (.png และ .svg)
        fontsize (int, default=14): ขนาดตัวอักษรในกราฟ
    """
    n_classes = y_pred_prob.shape[1]
    plt.figure(figsize=(12, 7))

    if title:
        pic_title = f"{title}\nReceiver Operating Characteristic (ROC) - Multiclass"
    else:
        pic_title = "Receiver Operating Characteristic (ROC) - Multiclass"

    for i in range(n_classes):
        fpr, tpr, _ = sklearn.metrics.roc_curve(y_true_onehot[:, i], y_pred_prob[:, i])
        roc_auc = sklearn.metrics.auc(fpr, tpr)
        plt.plot(fpr, tpr, lw=2, label=f"{class_names[i]} (AUC = {roc_auc:.4f})")

    fpr_micro, tpr_micro, _ = sklearn.metrics.roc_curve(y_true_onehot.ravel(), y_pred_prob.ravel())
    roc_auc_micro = sklearn.metrics.auc(fpr_micro, tpr_micro)
    plt.plot(fpr_micro, tpr_micro, color="deeppink", linestyle="--", lw=2,
             label=f"Micro-average (AUC = {roc_auc_micro:.4f})")

    roc_auc_macro = sklearn.metrics.roc_auc_score(y_true_onehot, y_pred_prob, average='macro')
    plt.plot([0, 1], [0, 1], color="gray", lw=1, linestyle="--",
             label=f"Macro-average (AUC = {roc_auc_macro:.4f})")

    plt.plot([0, 1], [0, 1], color="black", lw=1, linestyle=":")

    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.05])
    plt.xlabel("False Positive Rate", fontsize=fontsize)
    plt.ylabel("True Positive Rate", fontsize=fontsize)
    plt.title(pic_title, fontsize=fontsize)
    plt.legend(loc="lower right", fontsize=fontsize)
    plt.grid(alpha=0.3)

    plt.xticks(fontsize=fontsize)
    plt.yticks(fontsize=fontsize)

    if save_path:
        plt.savefig(f"{save_path}/roc_auc_curve.png", format="png", dpi=300, bbox_inches="tight")
        plt.savefig(f"{save_path}/roc_auc_curve.svg", format="svg", bbox_inches="tight")

    plt.show()

# %%
plot_multi_class_roc(y_true_onehot, y_pred_prob, class_names, f"{MODEL_NAME} {TYPE}", ASSETS_FOR_MODEL_PATH)
